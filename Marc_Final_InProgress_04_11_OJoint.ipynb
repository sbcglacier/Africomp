# %%
from py_post import *

# %% [markdown]
# # [Change](#change)

# %%
from py_mentat import *

# %%
pressure = float(60000)
max_load_case = 0.5

# %%
import math

# %%
# *loadcase_value maxfraction 0.02

# %%
# print("\"")

# %%
# print("\\")

# %%
# print("*import nastran \"C:\\Users\\SBCgl\\Documents\\PhD\\Apex\\MeshPneu\\Thinner\\Mesh 1.bdf\"")

# %%
# !jupyter kernelspec list

# %%
# import os

# %%
# os.system("some_command < input_file | another_command > output_file")

# %%
# print subprocess.Popen("echo Hello World", shell=True, stdout=subprocess.PIPE).stdout.read()

# %% [markdown]
# # This is  try using system shell scripting

# %%
# import os

# os.system("echo Hello from the other side!")

# %% [markdown]
# # Interesting read: pip install subprocess
#     # https://docs.python.org/3/library/subprocess.html#subprocess.Popen

# %%
# import subprocess
# from subprocess import Popen, PIPE
# subprocess.run(["ls", "-l"],shell = True)

# %%
# a1 = subprocess.run(['dir','-la'],shell = True, capture_output= True)
# #print(a1.stdout.decode())
# print(a1.stderr) # find error

# %%
# p = subprocess.Popen(some_cmd, stdout=subprocess.PIPE)
# # Grab stdout line by line as it becomes available.  This will loop until 
# # p terminates.
# while p.poll() is None:
#     l = p.stdout.readline() # This blocks until it receives a newline.
#     print(l)
# # When the subprocess terminates there might be unconsumed output 
# # that still needs to be processed.
# print(p.stdout.read())

# %% [markdown]
# # This following was done watching the link: https://www.youtube.com/watch?v=_XjKfuH7VXY

# %%
# results = subprocess.Popen(['ping','-n','10','google.com'],stdout =subprocess.PIPE, stderr=subprocess.PIPE, text = True)

# %%
# results.poll()

# %%
# stdout,stderr = results.communicate()

# %%
# print(stdout)

# %%
# import subprocess

# subprocess.call(['echo $HOME'], shell=True)

# %%
# import subprocess
# process = subprocess.Popen(['echo'],
#                      stdout=subprocess.PIPE, 
#                      stderr=subprocess.PIPE)
# stdout, stderr = process.communicate()
# stdout, stderr

# %%
import subprocess
import sys

#result = subprocess.run([sys.executable, "-c", "print('ocean')"])

# %% [markdown]
# # AMAZING LOOK BELOW IT WORKS

# %%
#subprocess.Popen(["C:\\Program Files\\MSC.Software\\Marc\\2021.4.0\\mentat2021.4\\bin\\mentat.bat",'Tools','Python...'])

# %%
# process = subprocess.Popen(["C:\\Program Files\\MSC.Software\\Marc\\2021.4.0\\mentat2021.4\\bin\\mentat.bat"], 
#                  stdout=subprocess.PIPE, stderr=subprocess.PIPE)

# stdout, stderr, stdin = process.communicate()
# stdout, stderr, stdin

# %%
# process = subprocess.Popen(["C:\\Program Files\\MSC.Software\\Marc\\2021.4.0\\mentat2021.4\\bin\\mentat.bat"], 
#                   text = True)
# output = process.communicate()[0]
# print(output.decode("utf-8"))

# %% [markdown]
# # So as it turns out I need more info so I am referring to the following link:
# https://linuxhint.com/python-subprocess-example/

# %%
# import subprocess
# import sys
# result = subprocess.run([sys.executable,"-c","import time; time.sleep(2)"], timeout = 1)

# %%
# ## I processed 5 % haha
#  https://www.youtube.com/watch?v=dYynIgbGZSk
#         cmd = 'dir'
#         cmd = 'ls -lrt'
#         shell = true
        
#         cmd = ['ls','-lrt']
#         shell = false

# %%
# out = os.system('dirasdf')
# print(out)

# %%
# # I dont know try this:
# https://www.analyticsvidhya.com/blog/2021/09/automate-windows-applications-using-python/

# %%
# print (subprocess.Popen("echo %s " % user_input, stdout=PIPE,shell = True).stdout.read())

# %%
# ["C:\\Program Files\\MSC.Software\\Marc\\2021.4.0\\mentat2021.4\\bin\\mentat.bat"]

# %%
# print (subprocess.Popen(["C:\\Program Files\\MSC.Software\\Marc\\2021.4.0\\mentat2021.4\\bin\\mentat.bat", "echo"], stdout=PIPE,shell = False).stdout.read())

# %%
# import subprocess
# process = subprocess.call(["C:\\Users\\SBCgl\\Documents\\PhD\\MarcProcFiles\\Recreate2.proc"],shell = True)

# %%
# import os
# os.system(r"C:\Users\SBCgl\Documents\PhD\MarcProcFiles\Recreate.proc")

# %% [markdown]
# # Note the following code is to try and create code to select the faces for pressure

# %%
# with open('test.proc', 'w') as f:
#     f.write('weird\nreadme\ntest')
#     f.close()
# # https://www.pythontutorial.net/python-basics/python-write-text-file/

# %%
file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\width.txt","r")
width = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\height.txt","r")
height = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\bredth.txt","r")
bredth = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\no_ch.txt","r")
no_ch = int(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ac_th_up.txt","r")
ac_th_up = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ac_th_side.txt","r")
ac_th_side = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ac_th_for.txt","r")
ac_th_for = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\gap.txt","r")
gap = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\air_vent.txt","r")
air_vent = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\gap_height.txt","r")
gap_height = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ends_ext.txt","r")
ends_ext = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\L0.txt","r")
SL0 = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\L1.txt","r")
SL1 = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\L2.txt","r")
SL2 = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\L3.txt","r")
SL3 = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\fin_rad.txt","r")
fin_rad = float(file1.read())
file1.close

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\meshsize.txt","r")
meshsize = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ch_var1.txt","r")
ch_var1 = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ch_var2.txt","r")
ch_var2 = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ch_var3.txt","r")
ch_var3 = float(file1.read())
file1.close()



file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\gap_height.txt","r")
gap_height = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\meshing_size.txt","r")
meshing_size = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\paper_width.txt","r")
paper_width = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\cham_end.txt","r")
cham_end = float(file1.read())
file1.close()

# %% [markdown]
# <a id = 'change'></a>

# %%
rotstiff = 0.001

# # B Joint
# L0= SL0-(SL1-SL0)/4 
# Origin_start = L0+2e-3
# L1 = SL0+(SL1-SL0)/2
# L2 = SL1+(SL2-SL1)/2
# L3 = SL3

# # A Joint
# L0= SL0-(SL1-SL0)/4
# Origin_start = L0+2e-3
# L1 = SL1
# L2 = SL2
# L3 = SL3+(SL1-SL0)/2

L0= SL0
Origin_start = L0+2e-3
L1 = SL1
L2 = SL2
L3 = SL3

e_width = 0.02 #0.02
e_height = 0.015 # 0.015
e_bredth= 0.008 # 0.008
e_no_ch= 11 # 11
e_ac_th_up= 0.002 # 0.002
e_ac_th_for= 0.0025 # 0.0025 #change this
e_ac_th_side= 0.003 # 0.003
e_gap= 0.001 #0.001
e_air_vent= 0.002 #0.002
e_gap_height= 0.001 #0.001
e_ends_ext= 0.002 #0.002
e_SL0= -0.006 #-0.006
e_SL1= 0.026 #0.026
e_SL2= 0.052 #0.052
e_SL3= 0.07 #0.07
e_fin_rad= 0.006 # 0.006
e_meshsize= 0.002 #0.001
e_paper_width = 1e-3

if meshing_size > min(ac_th_for,width,height,bredth,no_ch,ac_th_up,ac_th_for,ac_th_side,gap,air_vent,gap_height,ends_ext,fin_rad,e_paper_width):
    meshing_size = min(ac_th_for,width,height,bredth,no_ch,ac_th_up,ac_th_for,ac_th_side,gap,air_vent,gap_height,ends_ext,fin_rad,e_paper_width)
    mesh_size = min(ac_th_for,width,height,bredth,no_ch,ac_th_up,ac_th_for,ac_th_side,gap,air_vent,gap_height,ends_ext,fin_rad,e_paper_width)

# %%
# width = 20e-3 # 20e-3
# height = 15e-3 # 15e-3
# bredth = 8e-3 # 8e-3
# no_ch = 11 # 11

# ac_th_up = 2e-3 # actuator thickness top 2e-3
# ac_th_side = 3e-3 # actuator thickness side 3e-3
# ac_th_for = 2.5e-3 # forward dwidth of actuator 2.5e-3

ch_width = width-2*ac_th_side
ch_height = height-ac_th_up
#ch_bredth = bredth-2*ac_th_for

# gap = 1e-3 # 1e-3
# air_vent = 2e-3 # 2e-3
# gap_height = 1e-3 # 1e-3

# ends_ext = 2e-3 # 2e-3

# use the following for a for loop
#for a in range(no_ch):
#    print(a)

# parameters for fingers:
# L0 = -6e-3
# L1 = 26e-3
# L2 = 52e-3
# L3 = 70e-3
# fin_rad = 6e-3 # note centre point starts 5 mils lower

# %% [markdown]
# # Important code this code selects the chamber faces where pressure is applied
# <a id = 'start'></a>
# [2nd](#2nd)
# [2nd](#2nd)

# %%
tcp = ''

# %%
ch_sel_1 = ch_var1
ch_width_1 = (L1-L0-0.002-0.002)/ch_sel_1 - 2*ac_th_for-gap 
rem_n = round(ch_sel_1-math.floor(ch_sel_1),9)

# %%
print(tcp)

# %%
copy_text = "*select_method_user_box\n*select_filter_surface\n*select_faces "
text_comb_1 = ''
for a in range(math.floor(ch_sel_1)):
    x_min = str(round(Origin_start+(2*ac_th_for+ch_width_1+gap)*(a)+ac_th_for-meshing_size/2,6))
    x_max = str(round(Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(a)-ac_th_for+meshing_size/2,6))
    y_min = str(-ch_width/2-meshing_size/2) 
    y_max = str(ch_width/2+meshing_size/2)
    z_min = str(-meshing_size/2)
    z_max = str(height-ac_th_up+meshing_size/2)
    text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
    temp = copy_text+text_temp
    text_comb_1 = text_comb_1 + temp 
#print(text_comb_1)
vara = Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
varb = Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))
varc = Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n)
vard = Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_side
vare = Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap
    

if varc <= vara:
    print('nothing')
elif varc > vara:
    if varc > varb:
        x_min = str(round(Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for-meshing_size/2,6))
        x_max = str(round(Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for+meshing_size/2,6))
        y_min = str(-ch_width/2-meshing_size/2) 
        y_max = str(ch_width/2+meshing_size/2)
        z_min = str(-meshing_size/2)
        z_max = str(height-ac_th_up+meshing_size/2)
        text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
        temp = copy_text+text_temp
        text_comb_1 = text_comb_1 + temp
    elif varc <= varb:
        x_min = str(round(Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for-meshing_size/2,6))
        x_max = str(round(varc+meshing_size/2,6))
        y_min = str(-ch_width/2-meshing_size/2) 
        y_max = str(ch_width/2+meshing_size/2)
        z_min = str(-meshing_size/2)
        z_max = str(height-ac_th_up+meshing_size/2)
        text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
        temp = copy_text+text_temp
        text_comb_1 = text_comb_1 + temp 
        
if varc <= vara:
    print('nothing')
elif varc > vara:
    if varc <= vard:
        ca = Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
        cb = varc
        x_min = str(round(ca-meshing_size/2,6))
        x_max = str(round(cb+meshing_size/2,6))
        y_min = str(-ch_width/2-meshing_size/2) 
        y_max = str(ch_width/2+meshing_size/2)
        z_min = str(-meshing_size/2)
        z_max = str(height-ac_th_up+meshing_size/2)
        text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
        temp = copy_text+text_temp
        text_comb_1 = text_comb_1 + temp
    elif varc > vard:
        
        if varc <= varb:
            ca = Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
            cb = Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for
            x_min = str(round(ca-meshing_size/2,6))
            x_max = str(round(cb+meshing_size/2,6))
            y_min = str(-ch_width/2-meshing_size/2) 
            y_max = str(ch_width/2+meshing_size/2)
            z_min = str(-meshing_size/2)
            z_max = str(height-ac_th_up+meshing_size/2)
            text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
            temp = copy_text+text_temp
            text_comb_1 = text_comb_1 + temp
            
        elif varc > varb:
            ca = Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
            cb = Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for
            x_min = str(round(ca-meshing_size/2,6))
            x_max = str(round(cb+meshing_size/2,6))
            y_min = str(-ch_width/2-meshing_size/2) 
            y_max = str(ch_width/2+meshing_size/2)
            z_min = str(-meshing_size/2)
            z_max = str(height-ac_th_up+meshing_size/2)
            text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
            temp = copy_text+text_temp
            text_comb_1 = text_comb_1 + temp
            
tcp = tcp + text_comb_1
# Out:
# nothing
# nothing

# %% [markdown]
# # 2ND

# %%
ch_sel_1 = ch_var2
ch_width_1 = (L2-L1-0.002-gap)/ch_sel_1 - 2*ac_th_for-gap 
rem_n = round(ch_sel_1-math.floor(ch_sel_1),6)

# %%
st_p = L1+gap
copy_text = "*select_method_user_box\n*select_filter_surface\n*select_faces "
text_comb_1 = ''
for a in range(math.floor(ch_sel_1)):
    x_min = str(round(st_p+(2*ac_th_for+ch_width_1+gap)*(a)+ac_th_for-meshing_size/2,6))
    x_max = str(round(st_p+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(a)-ac_th_for+meshing_size/2,6))
    y_min = str(-ch_width/2-meshing_size/2) 
    y_max = str(ch_width/2+meshing_size/2)
    z_min = str(-meshing_size/2)
    z_max = str(height-ac_th_up+meshing_size/2)
    text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
    temp = copy_text+text_temp
    text_comb_1 = text_comb_1 + temp 
#print(text_comb_1)
vara = st_p+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
varb = st_p+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))
varc = st_p+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n)
vard = st_p+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_side
vare = st_p+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap
    

if varc <= vara:
    print('nothing')
elif varc > vara:
    if varc > varb:
        x_min = str(round(st_p+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for-meshing_size/2,6))
        x_max = str(round(st_p+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for+meshing_size/2,6))
        y_min = str(-ch_width/2-meshing_size/2) 
        y_max = str(ch_width/2+meshing_size/2)
        z_min = str(-meshing_size/2)
        z_max = str(height-ac_th_up+meshing_size/2)
        text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
        temp = copy_text+text_temp
        text_comb_1 = text_comb_1 + temp
    elif varc <= varb:
        x_min = str(round(st_p+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for-meshing_size/2,6))
        x_max = str(round(varc+meshing_size/2,6))
        y_min = str(-ch_width/2-meshing_size/2) 
        y_max = str(ch_width/2+meshing_size/2)
        z_min = str(-meshing_size/2)
        z_max = str(height-ac_th_up+meshing_size/2)
        text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
        temp = copy_text+text_temp
        text_comb_1 = text_comb_1 + temp 
        
if varc <= vara:
    print('nothing')
elif varc > vara:
    if varc <= vard:
        ca = st_p+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
        cb = varc
        x_min = str(round(ca-meshing_size/2,6))
        x_max = str(round(cb+meshing_size/2,6))
        y_min = str(-ch_width/2-meshing_size/2) 
        y_max = str(ch_width/2+meshing_size/2)
        z_min = str(-meshing_size/2)
        z_max = str(height-ac_th_up+meshing_size/2)
        text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
        temp = copy_text+text_temp
        text_comb_1 = text_comb_1 + temp
    elif varc > vard:
        if varc <= varb:
            ca = st_p+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
            cb = st_p+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for
            x_min = str(round(ca-meshing_size/2,6))
            x_max = str(round(cb+meshing_size/2,6))
            y_min = str(-ch_width/2-meshing_size/2) 
            y_max = str(ch_width/2+meshing_size/2)
            z_min = str(-meshing_size/2)
            z_max = str(height-ac_th_up+meshing_size/2)
            text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
            temp = copy_text+text_temp
            text_comb_1 = text_comb_1 + temp
            
        elif varc > varb:
            ca = st_p+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
            cb = st_p+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for
            x_min = str(round(ca-meshing_size/2,6))
            x_max = str(round(cb+meshing_size/2,6))
            y_min = str(-ch_width/2-meshing_size/2) 
            y_max = str(ch_width/2+meshing_size/2)
            z_min = str(-meshing_size/2)
            z_max = str(height-ac_th_up+meshing_size/2)
            text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
            temp = copy_text+text_temp
            text_comb_1 = text_comb_1 + temp
            
tcp = tcp + text_comb_1
# Out:
# nothing
# nothing

# %% [markdown]
# # Third

# %%
ch_sel_1 = ch_var3#3.31666666666666665#3.8
ch_width_1 = (L3-L2-0.002-gap)/ch_sel_1 - 2*ac_th_for-gap 
rem_n = round(ch_sel_1-math.floor(ch_sel_1),6)

# %%
st_p = L2+gap
copy_text = "*select_method_user_box\n*select_filter_surface\n*select_faces "
text_comb_1 = ''
for a in range(math.floor(ch_sel_1)):
    x_min = str(round(st_p+(2*ac_th_for+ch_width_1+gap)*(a)+ac_th_for-meshing_size/2,6))
    x_max = str(round(st_p+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(a)-ac_th_for+meshing_size/2,6))
    y_min = str(-ch_width/2-meshing_size/2) 
    y_max = str(ch_width/2+meshing_size/2)
    z_min = str(-meshing_size/2)
    z_max = str(height-ac_th_up+meshing_size/2)
    text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
    temp = copy_text+text_temp
    text_comb_1 = text_comb_1 + temp 
#print(text_comb_1)
vara = st_p+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
varb = st_p+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))
varc = st_p+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n)
vard = st_p+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_side
vare = st_p+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap
    

if varc <= vara:
    print('nothing')
elif varc > vara:
    if varc > varb:
        x_min = str(round(st_p+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for-meshing_size/2,6))
        x_max = str(round(st_p+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for+meshing_size/2,6))
        y_min = str(-ch_width/2-meshing_size/2) 
        y_max = str(ch_width/2+meshing_size/2)
        z_min = str(-meshing_size/2)
        z_max = str(height-ac_th_up+meshing_size/2)
        text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
        temp = copy_text+text_temp
        text_comb_1 = text_comb_1 + temp
    elif varc <= varb:
        x_min = str(round(st_p+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for-meshing_size/2,6))
        x_max = str(round(varc+meshing_size/2,6))
        y_min = str(-ch_width/2-meshing_size/2) 
        y_max = str(ch_width/2+meshing_size/2)
        z_min = str(-meshing_size/2)
        z_max = str(height-ac_th_up+meshing_size/2)
        text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
        temp = copy_text+text_temp
        text_comb_1 = text_comb_1 + temp 
        
if varc <= vara:
    print('nothing')
elif varc > vara:
    if varc <= vard:
        ca = st_p+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
        cb = varc
        x_min = str(round(ca-meshing_size/2,6))
        x_max = str(round(cb+meshing_size/2,6))
        y_min = str(-ch_width/2-meshing_size/2) 
        y_max = str(ch_width/2+meshing_size/2)
        z_min = str(-meshing_size/2)
        z_max = str(height-ac_th_up+meshing_size/2)
        text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
        temp = copy_text+text_temp
        text_comb_1 = text_comb_1 + temp
    elif varc > vard:
        if varc <= varb:
            ca = st_p+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
            cb = st_p+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for
            x_min = str(round(ca-meshing_size/2,6))
            x_max = str(round(cb+meshing_size/2,6))
            y_min = str(-ch_width/2-meshing_size/2) 
            y_max = str(ch_width/2+meshing_size/2)
            z_min = str(-meshing_size/2)
            z_max = str(height-ac_th_up+meshing_size/2)
            text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
            temp = copy_text+text_temp
            text_comb_1 = text_comb_1 + temp
            
        elif varc > varb:
            ca = st_p+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
            cb = st_p+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for
            x_min = str(round(ca-meshing_size/2,6))
            x_max = str(round(cb+meshing_size/2,6))
            y_min = str(-ch_width/2-meshing_size/2) 
            y_max = str(ch_width/2+meshing_size/2)
            z_min = str(-meshing_size/2)
            z_max = str(height-ac_th_up+meshing_size/2)
            text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
            temp = copy_text+text_temp
            text_comb_1 = text_comb_1 + temp
            
tcp = tcp + text_comb_1
# Out:
# nothing
# nothing

# %%
# this is for the vent
text_comb_1 = ''
copy_text = "*select_method_user_box\n*select_filter_surface\n*select_faces "
ch_sel_1 = ch_var1
ch_width_1 = (L1-L0-0.002-0.002)/ch_sel_1 - 2*ac_th_for-gap 
rem_n = round(ch_sel_1-math.floor(ch_sel_1),9)
ca = Origin_start+(2*ac_th_for+ch_width_1+gap)*(0)+ac_th_for

cb = L3
x_min = str(round(ca-meshing_size/2,6))
x_max = str(round(cb+meshing_size/2,6))
y_min = str(-air_vent/2-meshing_size/2) 
y_max = str(air_vent/2+meshing_size/2)
z_min = str(-meshing_size/2)
z_max = str(air_vent+meshing_size/2)
text_temp = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
temp = copy_text+text_temp
text_comb_1 = text_comb_1 + temp

tcp = tcp + text_comb_1

# %%
text_fin = tcp
print(text_fin)
# Out:
# *select_method_user_box
# *select_filter_surface
# *select_faces -0.0025 0.0075 -0.0075 0.0075 -0.0005 0.0135
# *select_method_user_box
# *select_filter_surface
# *select_faces 0.0115 0.0215 -0.0075 0.0075 -0.0005 0.0135
# *select_method_user_box
# *select_filter_surface
# *select_faces 0.0285 0.036 -0.0075 0.0075 -0.0005 0.0135
# *select_method_user_box
# *select_filter_surface
# *select_faces 0.04 0.0475 -0.0075 0.0075 -0.0005 0.0135
# *select_method_user_box
# *select_filter_surface
# *select_faces 0.0545 0.058 -0.0075 0.0075 -0.0005 0.0135
# *select_method_user_box
# *select_filter_surface
# *select_faces 0.062 0.0655 -0.0075 0.0075 -0.0005 0.0135
# *select_method_user_box
# *select_filter_surface
# *select_faces -0.0025 0.0705 -0.0015 0.0015 -0.0005 0.0025

# %% [markdown]
# [start](#start)
#     <a id = '2nd'></a>

# %% [markdown]
# # Thirds
# [start](#start)
#
# <a id = '3nd'></a>

# %%
meshsize = meshing_size

# %% [markdown]
# # End
# [start](#start)

# %%
# This is to remove half of the actuator
copy_text = "*select_clear\n*select_method_user_box\n*select_filter_surface\n*select_elements "
text_comb_remove = ''
x_min = str(round(Origin_start-2e-3-meshsize/2,6))
x_max = str(round( L3+2e-3+meshsize/2,6))# act_end
y_min = str(round(-width/2-meshsize/2,6))
y_max = str(round(meshsize/2,6))
z_min = str(round(-5e-3-meshsize/2,6))
z_max = str(round(height+meshsize/2,6))
text_remove_fin = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
fintext = "*remove_elements\nall_selected\n# | End of List\n\n"
temp = copy_text+text_remove_fin+fintext
text_comb_remove =  temp 
#print([text_comb_2])
#print(text_comb_2)

# This is to remove half of the actuator nodes
copy_text = "*select_clear\n*select_method_user_box\n*select_filter_none\n*select_nodes "
text_comb_remove2 = ''
x_min = str(round(Origin_start-2e-3-meshsize/2,6))
x_max = str(round( L3+2e-3+meshsize/2,6)) # act_end
y_min = str(round(-width/2-meshsize/2,6))
y_max = str(round(-meshsize/2,6))
z_min = str(round(-5e-3-meshsize/2,6))
z_max = str(round(height+meshsize/2,6))
text_remove_fin = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
fintext = "*remove_nodes\nall_selected\n# | End of List\n\n"
temp = copy_text+text_remove_fin+fintext
text_comb_remove2 =  temp 
#print([text_comb_2])
#print(text_comb_2)
# This is to select nodes to apply 
copy_text = "*select_clear\n*select_method_user_box\n*select_filter_none\n*select_nodes "
text_comb_remove3 = ''
x_min = str(round(Origin_start-2e-3-meshsize/2,6))
x_max = str(round( L3+2e-3+meshsize/2,6)) #act_end
y_min = str(round(-width/2-meshsize/2,6))
y_max = str(round(+meshsize/2,6))
z_min = str(round(-5e-3-meshsize/2,6))
z_max = str(round(height+meshsize/2,6))
text_remove_fin = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
fintext = "*new_apply *apply_type fixed_displacement\n*apply_name Symmetry\n*apply_dof y *apply_dof_value y\n*add_apply_nodes\nall_selected\n# | End of List\n*add_loadcase_loads Symmetry\n*add_job_applys Symmetry\n"
extratext= "*loadcase_option converge:resid_or_disp\n*loadcase_value force 0.01\n*loadcase_value displacement 0.01\n*loadcase_value maxfraction "+ str(round(max_load_case,6) )+" \n"
temp = copy_text+text_remove_fin+fintext
text_comb_remove3 =  temp 
#print([text_comb_2])
#print(text_comb_2)
final_sym_text = text_comb_remove + text_comb_remove2+text_comb_remove3+extratext

# %%
print(final_sym_text)
# Out:
# *select_clear
# *select_method_user_box
# *select_filter_surface
# *select_elements -0.0065 0.0725 -0.0105 0.0005 -0.0055 0.0155
# *remove_elements
# all_selected
# # | End of List
#
# *select_clear
# *select_method_user_box
# *select_filter_none
# *select_nodes -0.0065 0.0725 -0.0105 -0.0005 -0.0055 0.0155
# *remove_nodes
# all_selected
# # | End of List
#
# *select_clear
# *select_method_user_box
# *select_filter_none
# *select_nodes -0.0065 0.0725 -0.0105 0.0005 -0.0055 0.0155
# *new_apply *apply_type fixed_displacement
# *apply_name Symmetry
# *apply_dof y *apply_dof_value y
# *add_apply_nodes
# all_selected
# # | End of List
# *add_loadcase_loads Symmetry
# *add_job_applys Symmetry
# *loadcase_option converge:resid_or_disp
# *loadcase_value force 0.01
# *loadcase_value displacement 0.01
# *loadcase_value maxfraction 0.5

# %% [markdown]
# # Following code is used to change to herman formulation

# %%
copy_text = "*select_clear\n*select_method_user_box\n*select_filter_surface\n*select_elements "
text_comb_herman = ''
x_min = str(round(Origin_start-2e-3-meshsize/2,6))
x_max = str(round( L3+2e-3+meshsize/2,6))
y_min = str(round(-width/2-meshsize/2,6))
y_max = str(round(width/2+meshsize/2,6))
z_min = str(round(-5e-3-meshsize/2,6))
z_max = str(round(height+meshsize/2,6))
text_remove_fin = x_min + ' '+ x_max + ' ' + y_min + ' '+y_max + ' '+z_min + ' '+z_max + '\n'
fintext = "*element_type 84\nall_selected\n*edit_geometry Elements_and_Element_Properties_for_Part:_Part_1_1\n*add_geometry_elements\nall_selected\n# | End of List\n*select_clear\n"
temp = copy_text+text_remove_fin+fintext
text_comb_herman =  temp

# %%
print(text_comb_herman)
# Out:
# *select_clear
# *select_method_user_box
# *select_filter_surface
# *select_elements -0.0065 0.0725 -0.0105 0.0105 -0.0055 0.0155
# *element_type 84
# all_selected
# *edit_geometry Elements_and_Element_Properties_for_Part:_Part_1_1
# *add_geometry_elements
# all_selected
# # | End of List
# *select_clear

# %% [markdown]
# # NOTE FOLLOWING IS CODE till boundary condition end fixed WORKING

# %%
# # *set_undo off
# # *set_update off
# # *model_navigator_update off
# # *py_connect

# # was originally:
# *set_undo off
# *set_update off
# *model_navigator_update off
# *prog_option import_nastran:show_log:off
# *import nastran \"C:\\Users\\18507522\\Downloads\\SB\\Mesh\\Mesh1.bdf\"\n

# %%
text_hold_fin = """| Created by Marc Mentat 2021.4 (64bit)
*prog_option compatibility:prog_version:ment2021.4
*prog_analysis_class structural
*prog_use_current_job on
*set_default_length_unit meter
*set_model_length_unit meter
|
*theme dark
*set_save_formatted off *save_as_model \"C:\\Users\\18507522\\Downloads\\SB\\CODE\\FinalOpt\\Marc\\Model1.mud\" yes
*change_directory "."
C:\\Users\\18507522\\Downloads\\SB\\CODE\\FinalOpt\\Marc
*py_separate_process on
*set_undo off
*set_update off
*model_navigator_update off
*prog_option import_nastran:show_log:off
*import nastran \"C:\\Users\\18507522\\Downloads\\SB\\Mesh\\Mesh1.bdf\"\n
*edit_geometry Elements_and_Element_Properties_for_Part:_Part_1 *remove_current_geometry
*edit_mater Description:_NULL_Material_Created *remove_current_mater
yes
*new_pre_defined_table linear_ramp_time
*table_name linear_ramp
*new_pre_defined_table linear_ramp_up_down_time
*table_name linear_ramp_up_down
*current_graphics_window model:1
*fill_view
*grid_u_min -0.02
*grid_u_max 0.02
*grid_u_spacing 0.02
*grid_u_min -0.1
*grid_u_max 0.1
*grid_v_min -0.1
*grid_v_max 0.1
*grid_v_spacing 0.02
*system_grid_display_on
@popup(set_control_pm,0)
*store_nodes
Nodes_Actuator
all_visible
# | End of List
*store_elements
Elem_Actuator
all_visible
# | End of List
@popdown(set_control_pm,0)
@main(geometric_properties)
*new_geometry *geometry_type mech_three_solid
*geometry_name geometry_actuator
*edit_geometry geometry_actuator
*add_geometry_elements
all_visible
# | End of List
*geometry_option assumedstrn:on
*new_mater standard *mater_option general:state:solid *mater_option general:skip_structural:off
*mater_option structural:type:mooney
*mater_name Mooney
*mater_param structural:mooney_c10 260500
*mater_param structural:mooney_c01 97550
*mater_param structural:mooney_c20 57500
*add_mater_elements
all_visible
# | End of List
*import nastran \"C:\\Users\\18507522\\Downloads\\SB\\Mesh\\Mesh3.bdf\"\n
*edit_geometry Elements_and_Element_Properties_for_Part:_Part_3 *remove_current_geometry
*edit_mater Description:_NULL_Material_Created *remove_current_mater
yes
*invisible_set Elem_Actuator *redraw
*store_nodes
Nodes_Bottom_Sil
all_visible
# | End of List
*store_elements
Elem_Bottom_Sil
all_visible
# | End of List
*add_geometry_elements
all_visible
*add_mater_elements
all_visible
*invisible_set Elem_Bottom_Sil *redraw
*import nastran \"C:\\Users\\18507522\\Downloads\\SB\\Mesh\\Mesh2.bdf\"\n
*edit_geometry Elements_and_Element_Properties_for_Part:_Part_2 *remove_current_geometry
*edit_mater Description:_NULL_Material_Created *remove_current_mater
yes
*store_nodes
Nodes_Paper
all_visible
# | End of List
*store_elements
Elem_Paper
all_visible
# | End of List
*add_geometry_elements
all_visible
# | End of List
*new_mater standard *mater_option general:state:solid *mater_option general:skip_structural:off
*mater_name Paper
*mater_param structural:youngs_modulus 0.3e9
*mater_param structural:poissons_ratio 0.33
*edit_mater Paper
*add_mater_elements
all_visible
# | End of List
*visible_set Elem_Actuator *redraw
*visible_set Elem_Bottom_Sil *redraw
*new_cbody mesh *contact_option state:solid *contact_option skip_structural:off
*contact_body_name Silicon_base
*invisible_set Elem_Actuator *redraw
*visible_set Elem_Bottom_Sil *redraw
*invisible_set Elem_Paper *redraw
*add_contact_body_elements
all_visible
# | End of List
*new_cbody mesh *contact_option state:solid *contact_option skip_structural:off
*contact_body_name Actuator
*visible_set Elem_Actuator *redraw
*invisible_set Elem_Bottom_Sil *redraw
*invisible_set Elem_Paper *redraw
*add_contact_body_elements
all_visible
# | End of List
*new_cbody mesh *contact_option state:solid *contact_option skip_structural:off
*contact_body_name Paper
*invisible_set Elem_Actuator *redraw
*invisible_set Elem_Bottom_Sil *redraw
*visible_set Elem_Paper *redraw
*add_contact_body_elements
all_visible
# | End of List
*new_interact mesh:mesh *interact_option state_1:solid *interact_option state_2:solid
*interact_name interact_MD_to_MD_Glued
*interact_option contact_type:glue
*interact_option delay_slide_off:on
*interact_option project_stress_free:on
*new_interact mesh:mesh *interact_option state_1:solid *interact_option state_2:solid
*interact_name interact_MD_to_MD_Touch
*new_contact_table
*visible_set Elem_Actuator *redraw
*visible_set Elem_Bottom_Sil *redraw
*visible_set Elem_Paper *redraw
*ctable_entry Paper Actuator
*contact_table_option Actuator Paper contact:on
*prog_string ctable:old_interact interact_MD_to_MD_Glued *ctable_entry_interact Actuator Paper

*ctable_entry Silicon_base Paper
*contact_table_option Silicon_base Paper contact:on
*prog_string ctable:old_interact interact_MD_to_MD_Glued *ctable_entry_interact Silicon_base Paper
*ctable_entry Actuator Actuator
*contact_table_option Actuator Actuator contact:on
*prog_string ctable:old_interact interact_MD_to_MD_Touch *ctable_entry_interact Actuator Actuator
*new_apply *apply_type fixed_displacement
*apply_name Fixed_side
*apply_dof x *apply_dof_value x
*apply_dof y *apply_dof_value y
*apply_dof z *apply_dof_value z
*apply_dof rx *apply_dof_value rx
*apply_dof ry *apply_dof_value ry
*apply_dof rz *apply_dof_value rz
*select_method_user_box
*select_filter_none
*select_nodes """ +str(round(Origin_start-2e-3-0.5e-3,6))+ " " + str(round(Origin_start-2e-3+0.5e-3,6))+ " " + str(round(-(width/2)-0.5e-3,6))+ " " + str(round((width/2)+0.5e-3,6))+ " " + str(round(-5.500000000000e-03,6)) + " " + str(round(height + 0.5e-3,6)) + """
*add_apply_nodes
all_selected
# | End of List
*select_clear_nodes
*model_orientation_bottom
*fill_view
*auto_arrow_length 0.03
*redraw
*draw_clipped on
*set_clip_plane_normal_comp y -1
*set_clip_plane_normal_comp x 0"""

# %%
text_fin_2 = """*new_apply *apply_type face_load
*apply_name
Pressure_loading
*apply_dof p *apply_dof_value p """+str(pressure)+"""
*edit_apply Pressure_loading
*apply_dof_table p
linear_ramp
*add_apply_faces
all_selected

*new_loadcase *loadcase_type struc:static
*loadcase_ctable
ctable1
*edit_loadcase lcase1
*loadcase_option stepping:multicriteria
*loadcase_value desired 15

*prog_use_current_job on *new_job structural
*add_job_loadcases lcase1
*job_contact_table
ctable1
*job_option follow:on
*job_option restart_mode:write
*job_option restart_write:last

*point_display_on
*node_display_on
*redraw
*add_nodes
"""+str(SL0)+" "+str(0)+" "+str(round(-(fin_rad+4e-3+paper_width),6))+"""
*add_points
"""+str(SL0)+" "+str(0)+" "+str(round(-(fin_rad+4e-3+paper_width),6))+"""
*add_points
"""+str(SL1)+" "+str(0)+" "+str(round(-(fin_rad+4e-3+paper_width),6))+"""
*add_points
"""+str(SL2)+" "+str(0)+" "+str(round(-(fin_rad+4e-3+paper_width),6))+"""
*add_points
"""+str(SL3)+" "+str(0)+" "+str(round(-(fin_rad+4e-3+paper_width),6))+"""
*select_mode_and
*select_method_user_box
*select_filter_none
*select_nodes """+str(SL0-0.5e-3)+" "+str(SL0+0.5e-3)+" "+"-0.500000000000e-03 0.500000000000e-03 "+str(-(fin_rad+4e-3+paper_width)-0.5e-3)+" "+str(-(fin_rad+4e-3+paper_width)+0.5e-3)+ """
*add_apply_nodes
all_selected
# | End of List
*store_nodes
G1
all_selected
*select_clear
*add_curves
1
2
# | End of List
*set_convert_uvdiv u 1
*convert_curves
1
# | End of List
 
*select_mode_and
*select_method_user_box
*select_filter_none
*select_nodes """+str(SL0-0.5e-3)+" "+str(SL0+0.5e-3)+" "+"-0.500000000000e-03 0.500000000000e-03 "+str(-(fin_rad+4e-3+paper_width)-0.5e-3)+" "+str(-(fin_rad+4e-3+paper_width)+0.5e-3)+ """
*select_mode_except
*select_sets G1
*store_nodes
G2
all_selected
*select_clear

*select_mode_and
*select_method_user_box
*select_filter_none
*select_nodes """+str(SL1-0.5e-3)+" "+str(SL1+0.5e-3)+" "+"-0.500000000000e-03 0.500000000000e-03 "+str(-(fin_rad+4e-3+paper_width)-0.5e-3)+" "+str(-(fin_rad+4e-3+paper_width)+0.5e-3)+ """
*add_apply_nodes
all_selected
# | End of List
*store_nodes
G3
all_selected
*select_clear
*add_curves
2
3
# | End of List
*set_convert_uvdiv u 1
*convert_curves
2
# | End of List

*select_mode_and
*select_method_user_box
*select_filter_none
*select_nodes """+str(SL1-0.5e-3)+" "+str(SL1+0.5e-3)+" "+"-0.500000000000e-03 0.500000000000e-03 "+str(-(fin_rad+4e-3+paper_width)-0.5e-3)+" "+str(-(fin_rad+4e-3+paper_width)+0.5e-3)+ """
*select_mode_except
*select_sets G3
*store_nodes
G4
all_selected
*select_clear

*select_mode_and
*select_method_user_box
*select_filter_none
*select_nodes """+str(SL2-0.5e-3)+" "+str(SL2+0.5e-3)+" "+"-0.500000000000e-03 0.500000000000e-03 "+str(-(fin_rad+4e-3+paper_width)-0.5e-3)+" "+str(-(fin_rad+4e-3+paper_width)+0.5e-3)+ """
*add_apply_nodes
all_selected
# | End of List
*store_nodes
G5
all_selected
*select_clear
*add_curves
3
4
# | End of List
*set_convert_uvdiv u 1
*convert_curves
3
# | End of List

*select_mode_and
*select_method_user_box
*select_filter_none
*select_nodes """+str(SL2-0.5e-3)+" "+str(SL2+0.5e-3)+" "+"-0.500000000000e-03 0.500000000000e-03 "+str(-(fin_rad+4e-3+paper_width)-0.5e-3)+" "+str(-(fin_rad+4e-3+paper_width)+0.5e-3)+ """
*select_mode_except
*select_sets G5
*store_nodes
G6
all_selected
*select_clear

*select_mode_and
*select_method_user_box
*select_filter_none
*select_nodes """+str(SL3-0.5e-3)+" "+str(SL3+0.5e-3)+" "+"-0.500000000000e-03 0.500000000000e-03 "+str(-(fin_rad+4e-3+paper_width)-0.5e-3)+" "+str(-(fin_rad+4e-3+paper_width)+0.5e-3)+ """
*add_apply_nodes
all_selected
# | End of List
*store_nodes
G7
all_selected
*select_clear
*new_rbe2
*rbe2_name link1
*rbe2_ret_node
node_id(-7)
*select_clear
*select_sets G2
*add_rbe2_tied_nodes
all_selected
#
*select_clear

*new_rbe2
*rbe2_name link2
*rbe2_ret_node
node_id(-5)
*select_clear
*select_sets G4
*add_rbe2_tied_nodes
all_selected
#
*select_clear

*new_rbe2
*rbe2_name link3
*rbe2_ret_node
node_id(-3)
*select_clear
*select_sets G6
*add_rbe2_tied_nodes
all_selected
#
*select_clear

*select_sets Elem_Actuator
*select_sets Elem_Bottom_Sil
*select_sets Nodes_Actuator
*select_sets Nodes_Bottom_Sil
*invisible_selected

*new_rbe2
*rbe2_name con_1
*rbe2_ret_node
node_id(-5)

*select_clear
*select_mode_and
*select_method_user_box
*select_filter_none
*select_nodes """+str(SL1-meshing_size/2)+" "+str(SL1+meshing_size/2)+" "+str(-meshing_size/2)+" "+str(meshing_size/2)+" "+str(-(2e-3+paper_width)-paper_width/2)+" "+str(-(2e-3+paper_width)+paper_width/2)+ """
*add_rbe2_tied_nodes
all_selected
# | End of List

*edit_rbe2 con_1
*rbe2_tied_dof y
*rbe2_tied_dof z
*rbe2_tied_dof rx
*rbe2_tied_dof rz

*new_rbe2
*rbe2_name con_2
*rbe2_ret_node
node_id(-3)

*select_clear
*select_mode_and
*select_method_user_box
*select_filter_none
*select_nodes """+str(SL2-meshing_size/2)+" "+str(SL2+meshing_size/2)+" "+str(-meshing_size/2)+" "+str(meshing_size/2)+" "+str(-(2e-3+paper_width)-paper_width/2)+" "+str(-(2e-3+paper_width)+paper_width/2)+ """
*add_rbe2_tied_nodes
all_selected
# | End of List

*edit_rbe2 con_2
*rbe2_tied_dof y
*rbe2_tied_dof z
*rbe2_tied_dof rx
*rbe2_tied_dof rz

*new_rbe2
*rbe2_name con_3
*rbe2_ret_node
node_id(-1)

*select_clear
*select_mode_and
*select_method_user_box
*select_filter_none
*select_nodes """+str(SL3-meshing_size/2)+" "+str(SL3+meshing_size/2)+" "+str(-meshing_size/2)+" "+str(meshing_size/2)+" "+str(-(2e-3+paper_width)-paper_width/2)+" "+str(-(2e-3+paper_width)+paper_width/2)+ """
*add_rbe2_tied_nodes
all_selected
# | End of List

*edit_rbe2 con_3
*rbe2_tied_dof y
*rbe2_tied_dof z
*rbe2_tied_dof rx
*rbe2_tied_dof rz

*invisible_selected

*new_link *link_class spring *spring_option spring_type:fixed_dof
*link_name spring1
*link_class spring *spring_param rot_stiff """+str(round(rotstiff,9)) +"""
*link_class spring *spring_beg_dof ry
*link_class spring *spring_end_dof ry
*link_class spring *spring_node 0
node_id(-7)
*link_class spring *spring_node 1
node_id(-6)

*new_link *link_class spring *spring_option spring_type:fixed_dof
*link_name spring2
*link_class spring *spring_param rot_stiff """+str(round(rotstiff,9))+"""
*link_class spring *spring_beg_dof ry
*link_class spring *spring_end_dof ry
*link_class spring *spring_node 0
node_id(-5)
*link_class spring *spring_node 1
node_id(-4)

*new_link *link_class spring *spring_option spring_type:fixed_dof
*link_name spring3
*link_class spring *spring_param rot_stiff """+str(round(rotstiff,9))+"""
*link_class spring *spring_beg_dof ry
*link_class spring *spring_end_dof ry
*link_class spring *spring_node 0
node_id(-3)
*link_class spring *spring_node 1
node_id(-2)

*new_geometry *geometry_type mech_three_beam_ela
*geometry_name beam_1
*geometry_param diameter """+str(round(fin_rad*2,6)) +"""
*geometry_option material_behavior:linear_elastic
*select_clear
*select_mode_and
*select_method_user_box
*select_filter_none
*select_elements """+str(SL0-0.5e-3)+" "+str(SL1+0.5e-3)+" "+"-0.500000000000e-03 0.500000000000e-03 "+str(-(fin_rad+4e-3+paper_width)-0.5e-3)+" "+str(-(fin_rad+4e-3+paper_width)+0.5e-3)+ """
*add_geometry_elements
all_selected
# | End of List

*new_geometry *geometry_type mech_three_beam_ela
*geometry_name beam_2
*geometry_param diameter """+str(round(fin_rad*2,6)) +"""
*geometry_option material_behavior:linear_elastic
*select_clear
*select_mode_and
*select_method_user_box
*select_filter_none
*select_elements """+str(SL1-0.5e-3)+" "+str(SL2+0.5e-3)+" "+"-0.500000000000e-03 0.500000000000e-03 "+str(-(fin_rad+4e-3+paper_width)-0.5e-3)+" "+str(-(fin_rad+4e-3+paper_width)+0.5e-3)+ """
*add_geometry_elements
all_selected
# | End of List

*new_geometry *geometry_type mech_three_beam_ela
*geometry_name beam_3
*geometry_param diameter """+str(round(fin_rad*2,6)) +"""
*geometry_option material_behavior:linear_elastic
*select_clear
*select_mode_and
*select_method_user_box
*select_filter_none
*select_elements """+str(SL2-0.5e-3)+" "+str(SL3+0.5e-3)+" "+"-0.500000000000e-03 0.500000000000e-03 "+str(-(fin_rad+4e-3+paper_width)-0.5e-3)+" "+str(-(fin_rad+4e-3+paper_width)+0.5e-3)+ """
*add_geometry_elements
all_selected
# | End of List

*new_mater standard *mater_option general:state:solid *mater_option general:skip_structural:off
*mater_name Beams
*mater_param structural:youngs_modulus 2e10
*mater_param structural:poissons_ratio 0.42
*edit_mater Beams
*select_clear
*select_mode_and
*select_method_user_box
*select_filter_none
*select_elements """+str(SL0-0.5e-3)+" "+str(SL3+0.5e-3)+" "+"-0.500000000000e-03 0.500000000000e-03 "+str(-(fin_rad+4e-3+paper_width)-0.5e-3)+" "+str(-(fin_rad+4e-3+paper_width)+0.5e-3)+ """
*add_mater_elements
all_selected
# | End of List

*new_apply *apply_type fixed_displacement
*apply_name Finger_fixed
*apply_dof x *apply_dof_value x
*apply_dof y *apply_dof_value y
*apply_dof z *apply_dof_value z
*apply_dof rx *apply_dof_value rx
*apply_dof ry *apply_dof_value ry
*apply_dof rz *apply_dof_value rz
*select_clear
*select_sets G1
*add_apply_nodes
all_selected
#
*draw_clipped off
*node_display_off *redraw
*wire_element_display_style_expanded
*wire_element_coord_system_display_on
*redraw
*create_procedure Recorded_User_2.proc yes
*new_cbody mesh *contact_option state:solid *contact_option skip_structural:off
*contact_body_name Finger
*select_clear
*select_mode_and
*select_method_user_box
*select_filter_none
*select_elements """+str(SL0-0.5e-3)+" "+str(SL3+0.5e-3)+" "+"-0.500000000000e-03 0.500000000000e-03 "+str(-(fin_rad+4e-3+paper_width)-0.5e-3)+" "+str(-(fin_rad+4e-3+paper_width)+0.5e-3)+ """
*add_contact_body_elements
all_selected
# | End of List

*edit_contact_table ctable1
*contact_table_option Silicon_base Finger contact:on
*ctable_entry Finger Silicon_base
*prog_string ctable:old_interact interact_MD_to_MD_Touch *ctable_entry_interact Silicon_base Finger
*contact_table_option Silicon_base Finger detection:second_first
*add_job_applys Finger_fixed
*add_loadcase_loads Finger_fixed
*job_option contact_method:segment_segment
*job_option restart_mode:write
*job_option restart_write:last

*edit_rbe2 link1
*rbe2_tied_dof x
*rbe2_tied_dof y
*rbe2_tied_dof z
*rbe2_tied_dof rx
*rbe2_tied_dof rz

*edit_rbe2 link2
*rbe2_tied_dof x
*rbe2_tied_dof y
*rbe2_tied_dof z
*rbe2_tied_dof rx
*rbe2_tied_dof rz

*edit_rbe2 link3
*rbe2_tied_dof x
*rbe2_tied_dof y
*rbe2_tied_dof z
*rbe2_tied_dof rx
*rbe2_tied_dof rz
*edit_job job1
*job_option write_cont_post_file:on

"""+final_sym_text+text_comb_herman+"""

# *md_table_read_any \"C:\\Users\\18507522\\Downloads\\SB\\CODE\\ExampleResultsForMarc\\Final_radVsT_DIP.data\"
# *table_fit
# *set_md_table_type 1
# rotation

# *edit_spring spring3
# *link_class spring *spring_option static_type:force
# *link_class spring *spring_param_table rot_stiff_moment
# Final_radVsT_DIP
# *link_class spring *spring_param rot_stiff_moment 1

# *md_table_read_any \"C:\\Users\\18507522\\Downloads\\SB\\CODE\\ExampleResultsForMarc\\Final_radVsT_MCP.data\"
# *set_md_table_type 1
# rotation
# *table_fit
# *edit_spring spring1
# *link_class spring *spring_option static_type:force
# *link_class spring *spring_param_table rot_stiff_moment
# Final_radVsT_MCP
# *link_class spring *spring_param rot_stiff_moment 1


# *md_table_read_any \"C:\\Users\\18507522\\Downloads\\SB\\CODE\\ExampleResultsForMarc\\Final_radVsT_PIP.data\"
# *table_fit
# *set_md_table_type 1
# rotation
# *table_fit
# *edit_spring spring2
# *link_class spring *spring_option static_type:force
# *link_class spring *spring_param_table rot_stiff_moment
# Final_radVsT_PIP
# *link_class spring *spring_param rot_stiff_moment 1

*edit_job job1
*add_post_tensor stress

*edit_loadcase lcase1
*loadcase_value maxrec 30 
*update_job
*job_option assem_recov_multi_threading:on
*job_option nsolver_procs_serial:on
*job_option solver:pardiso
*job_param assem_recov_nthreads 6
*job_option pardiso_multi_threading:on
*job_param nthreads 6
*job_option seg_seg_contact_presets:version_2
*job_submit_reset
*save_as_model \"C:\\Users\\18507522\\Downloads\\SB\\CODE\\FinalOpt\\Marc\\Model1.mud\" yes
*job_write_input
yes
*submit_job 1 
@popup(job_run_popmenu,0)
*monitor_job
*edit_job job1
*update_job

*set_undo on
*set_update on
*model_navigator_update on
*redraw
@popdown(job_properties_pm) @main(results) @popup(modelplot_pm) *post_open_binary

*select_clear
*select_sets G2
*set_history_locations
all_selected
*post_open_binary
*history_collect 0 999999999 1
*prog_option history_plot:data_carrier_type_y:location
*set_history_location_variable_y
Rotation Y
*history_add_curve
*history_fit
history_write MCP yes
*history_remove

*select_clear
*select_sets G4
*set_history_locations
all_selected
*post_open_binary
*history_collect 0 999999999 1
*prog_option history_plot:data_carrier_type_y:location
*set_history_location_variable_y
Rotation Y
*history_add_curve
*history_fit
history_write PIP yes
*history_remove

*select_clear
*select_sets G6
*set_history_locations
all_selected
*post_open_binary
*history_collect 0 999999999 1
*prog_option history_plot:data_carrier_type_y:location
*set_history_location_variable_y
Rotation Y
*history_add_curve
*history_fit
history_write DIP yes
*history_remove
*quit
yes
"""

# %%
# # *quit
# # yes
# # *post_open_con_default
# *set_undo on
# *set_update on
# *model_navigator_update on
# *redraw
# @popdown(job_properties_pm) @main(results) @popup(modelplot_pm) *post_open_binary

# %%
# *history_collect 0 999999999 1
# *set_history_global_variable_y
# Spring Load 1
# *history_add_curve
# *set_history_global_variable_y
# Spring Load 2
# *history_add_curve
# *set_history_global_variable_y
# Spring Load 3
# *history_add_curve
# *history_fit
# *history_write Marc\Torque_Val yes
# *history_clear
# *history_remove

# %% [markdown]
# # if you want moment spring curves add below:
# """+final_sym_text+text_comb_herman+"""

# %%
# *md_table_read_any \"C:\\Users\\18507522\\Downloads\\SB\\CODE\\ExampleResultsForMarc\\Final_radVsT_DIP.data\"
# *table_fit
# *set_md_table_type 1
# rotation

# *edit_spring spring3
# *link_class spring *spring_option static_type:force
# *link_class spring *spring_param_table rot_stiff_moment
# Final_radVsT_DIP
# *link_class spring *spring_param rot_stiff_moment 1

# *md_table_read_any \"C:\\Users\\18507522\\Downloads\\SB\\CODE\\ExampleResultsForMarc\\Final_radVsT_MCP.data\"
# *set_md_table_type 1
# rotation
# *table_fit
# *edit_spring spring1
# *link_class spring *spring_option static_type:force
# *link_class spring *spring_param_table rot_stiff_moment
# Final_radVsT_MCP
# *link_class spring *spring_param rot_stiff_moment 1


# *md_table_read_any \"C:\\Users\\18507522\\Downloads\\SB\\CODE\\ExampleResultsForMarc\\Final_radVsT_PIP.data\"
# *table_fit
# *set_md_table_type 1
# rotation
# *table_fit
# *edit_spring spring2
# *link_class spring *spring_option static_type:force
# *link_class spring *spring_param_table rot_stiff_moment
# Final_radVsT_PIP
# *link_class spring *spring_param rot_stiff_moment 1

# %% [markdown]
# # ------------------------------------

# %%
# # *py_disconnect
# originally was the following
# *edit_job job1
# *job_option nod_quantities:manual
# *add_post_nodal_quantity Displacement
# *add_post_nodal_quantity Rotation
# *add_post_nodal_quantity Rea_Moment
# *add_post_nodal_quantity Rea_Force
# *add_post_nodal_quantity R_Velocity
# *remove_post_nodal_quantity R_Velocity
# *add_post_nodal_quantity Cont_Status
# *add_post_nodal_quantity Herrmann_Var
# *add_post_var bm_tor_mom
# *add_post_var bm_orient
# *add_post_tensor stress
# *add_post_tensor log_strain
# *remove_post_tensor stress
# *add_post_tensor cauchy
# *add_post_var spring_dp_for
# *add_post_var spring_dp_gen_for
# *add_post_var spring_dp_mom
# *add_post_nodal_quantity Ext_Moment


# last part included:
#*post_open_binary

# %%
print(text_comb_remove)

# %%
# # NOTE NB THIS PRINTS THE FINAL CODE TILL 
# text_hold_fin
with open(r'C:\Users\18507522\Downloads\SB\CODE\final_con.proc', 'w') as f:
    f.write(text_hold_fin+'\n'+text_fin+'\n'+text_fin_2)
    f.close()

# %%
# *post_open_binary
#!mentat final_code.proc -bg
import sys
sys.path

# %%
# # NB THIS STARTS IT
# import subprocess
# process = subprocess.Popen(r'C:\Users\18507522\Downloads\SB\CODE\final_con.proc',shell =  True)

# %%
# import subprocess
# process = subprocess.Popen(r'C:\Users\SBCgl\code_meeting.proc',shell =  True)

# %% [markdown]
# # Temporary code holder
