# %% [markdown]
# # To go to links:
# [edit](#edit)
# [marc](#Marc)
# [apex](#Apex)
# <a id = 'home'></a>

# %%
# remoting.shutdownApplication()

# %%
## NOTE USEFUL CODE TO CONVERT FROM STRING BACK TO NUMPY UNIT
# x  = nm.empty(3, float)
# print(x)
# # NOTE NB THIS PRINTS THE FINAL CODE TILL 
# with open('MyFile.txt', 'w') as f:
#     f.write(str(x))
#     f.close()
# file1 = open("MyFile.txt","r")
# testvar = str(file1.read())
# file1.close()   

# path1 = filepaths("main_dir")
# filen = "MyFile.txt"
# filp = os.path.join(path1,filen)

# # This was not working and was too complicated so the answers are as follows:

# #https://numpy.org/doc/stable/reference/generated/numpy.array2string.html
# a = nm.array2string(x,separator=' ')
# a1 = a[1:len(a)-1]
# print(a1)
# b = nm.fromstring(a1, dtype=float, sep=' ')
# print(b*2)
import math as m
import numpy as nm
import dot11 as dot
from py_mentat import *
from py_post import *
import os
import subprocess
import pandas as pd
import csv
import sys
import time
from functions import material2d, material3d
from File_paths2 import filepaths
from pathlib import Path
import shutil


file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\gap_height.txt","r")
gap_height = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\meshing_size.txt","r")
meshing_size = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ch_var1.txt","r")
ch_var1 = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ch_var2.txt","r")
ch_var2 = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ch_var3.txt","r")
ch_var3 = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ac_th_for.txt","r")
ac_th_for = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\gap.txt","r")
gap = float(file1.read())
file1.close()

# %% [markdown]
# # This is preset

# %%
file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\L0.txt","r")
SL0 = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\L1.txt","r")
SL1 = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\L2.txt","r")
SL2 = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\L3.txt","r")
SL3 = float(file1.read())
file1.close()

L0= SL0
Origin_start = L0+2e-3
L1 = SL1
L2 = SL2
L3 = SL3

#-----------------------NOTE--------------------------
#*****************************************************
            #If you lose vars go to code/savevarsbackup>2nd
#*****************************************************
#-----------------------------------------------------

#pipeline to edit values
# NOTE NB THIS PRINTS THE FINAL CODE TILL 
e_ch_var1 =  2#5.714
e_ch_var2 = 2#3.761
e_ch_var3 = 2#2.492

ch_sel_1 = e_ch_var1#3.31666666666666665#3.8
no_ch_max_1 = (L1-L0-0.002-0.002)/(2*ac_th_for+0.001+gap) # NB CORRECT
if ch_sel_1>no_ch_max_1:
    ch_sel_1 = no_ch_max_1

ch_sel_2 = e_ch_var2#3.31666666666666665#3.8
no_ch_max_2 = (L2-L1-0.002-gap)/(2*ac_th_for+0.001+gap) # NB CORRECT
if ch_sel_2>no_ch_max_2:
    ch_sel_2 = no_ch_max_2

ch_sel_3 = e_ch_var3#3.31666666666666665#3.8
no_ch_max_3 = (L1-L0-0.002-0.002)/(2*ac_th_for+0.001+gap) # NB CORRECT
if ch_sel_3>no_ch_max_3:
    ch_sel_3 = no_ch_max_3
    
e_width = 0.02 #0.02
e_height = 0.015 # 0.015
e_bredth= 0.008 # 0.008
e_no_ch= 11 # 11
e_ac_th_up= 0.002 # 0.002
e_ac_th_for= 0.002 # 0.0025 #change this
e_ac_th_side= 0.003 # 0.003
e_gap= 0.001 #0.001
e_air_vent= 0.002 #0.002
e_gap_height= 0.001 #0.001
e_ends_ext= 0.002 #0.002
e_SL0= -0.006 #-0.006
e_SL1= 0.026 #0.026
e_SL2= 0.052 #0.052
e_SL3= 0.07 #0.07
e_fin_rad= 0.006 # 0.006
e_meshsize= 0.001 #0.001
e_paper_width = 1e-3
#f.write(str(e_))

#--------------------------section of code for max min values for channels


with open(r"C:\Users\18507522\Downloads\SB\CODE\paper_width.txt", 'w') as f:
    f.write(str(e_paper_width))
    f.close()   
with open(r"C:\Users\18507522\Downloads\SB\CODE\ch_var1.txt", 'w') as f:
    f.write(str(e_ch_var1))
    f.close()

with open(r"C:\Users\18507522\Downloads\SB\CODE\ch_var2.txt", 'w') as f:
    f.write(str(e_ch_var2))
    f.close()

with open(r"C:\Users\18507522\Downloads\SB\CODE\ch_var3.txt", 'w') as f:
    f.write(str(e_ch_var3))
    f.close()
    
with open(r"C:\Users\18507522\Downloads\SB\CODE\width.txt", 'w') as f:
    f.write(str(e_width))
    f.close()   
        
with open(r"C:\Users\18507522\Downloads\SB\CODE\height.txt", 'w') as f:
    f.write(str(e_height))
    f.close()

with open(r"C:\Users\18507522\Downloads\SB\CODE\bredth.txt", 'w') as f:
    f.write(str(e_bredth))
    f.close()

with open(r"C:\Users\18507522\Downloads\SB\CODE\no_ch.txt", 'w') as f:
    f.write(str(e_no_ch))
    f.close()

with open(r"C:\Users\18507522\Downloads\SB\CODE\ac_th_up.txt", 'w') as f:
    f.write(str(e_ac_th_up))
    f.close()

with open(r"C:\Users\18507522\Downloads\SB\CODE\ac_th_side.txt", 'w') as f:
    f.write(str(e_ac_th_side))
    f.close()

with open(r"C:\Users\18507522\Downloads\SB\CODE\ac_th_for.txt", 'w') as f:
    f.write(str(e_ac_th_for))
    f.close()

with open(r"C:\Users\18507522\Downloads\SB\CODE\gap.txt", 'w') as f:
    f.write(str(e_gap))
    f.close()

with open(r"C:\Users\18507522\Downloads\SB\CODE\air_vent.txt", 'w') as f:
    f.write(str(e_air_vent))
    f.close()
    
with open(r"C:\Users\18507522\Downloads\SB\CODE\gap_height.txt", 'w') as f:
    f.write(str(e_gap_height))
    f.close()

with open(r"C:\Users\18507522\Downloads\SB\CODE\ends_ext.txt", 'w') as f:
    f.write(str(e_ends_ext))
    f.close()

with open(r"C:\Users\18507522\Downloads\SB\CODE\L0.txt", 'w') as f:
    f.write(str(e_SL0))
    f.close()
with open(r"C:\Users\18507522\Downloads\SB\CODE\L1.txt", 'w') as f:
    f.write(str(e_SL1))
    f.close()
with open(r"C:\Users\18507522\Downloads\SB\CODE\L2.txt", 'w') as f:
    f.write(str(e_SL2))
    f.close()
with open(r"C:\Users\18507522\Downloads\SB\CODE\L3.txt", 'w') as f:
    f.write(str(e_SL3))
    f.close()
with open(r"C:\Users\18507522\Downloads\SB\CODE\fin_rad.txt", 'w') as f:
    f.write(str(e_fin_rad))
    f.close()
with open(r"C:\Users\18507522\Downloads\SB\CODE\meshsize.txt", 'w') as f:
    f.write(str(e_meshsize))
    f.close()
with open(r"C:\Users\18507522\Downloads\SB\CODE\meshing_size.txt", 'w') as f:
    f.write(str(e_meshsize))
    f.close()

pressure = float(100000)

# This section of the code will print the 

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\gap_height.txt","r")
gap_height = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\meshing_size.txt","r")
meshing_size = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ch_var1.txt","r")
ch_var1 = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ch_var2.txt","r")
ch_var2 = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ch_var3.txt","r")
ch_var3 = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ac_th_for.txt","r")
ac_th_for = float(file1.read())
file1.close()

file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\gap.txt","r")
gap = float(file1.read())
file1.close()

ch_sel_1 = ch_var1#3.31666666666666665#3.8
no_ch_max_1 = (L1-L0-0.002-0.002)/(2*ac_th_for+0.001+gap) # NB CORRECT

ch_sel_2 = ch_var2#3.31666666666666665#3.8
no_ch_max_2 = (L2-L1-0.002-gap)/(2*ac_th_for+0.001+gap) # NB CORRECT

ch_sel_3 = ch_var3#3.31666666666666665#3.8
no_ch_max_3 = (L3-L2-0.002-gap)/(2*ac_th_for+0.001+gap) # NB CORRECT

print("ch1:"+str(ch_var1))
print("ch2:"+str(ch_var2))
print("ch3:"+str(ch_var3))
print("ch1Max:" +str(no_ch_max_1))
print("ch2Max:"+str(no_ch_max_2))
print("ch3Max:"+str(no_ch_max_3))

# Note look at ch1Max and input below to e_ch_var1 then rerun
# dic sdtrain window
# what  interpolent of system is
# Out:
# ch1:2.0
# ch2:2.0
# ch3:2.0
# ch1Max:4.666666666666666
# ch2Max:3.833333333333333
# ch3Max:2.500000000000001

# %%
# Print the DOT return values, this will be the final Objective function value,
# the worst constaint value at the optimum and the optimum design variable 
# values.  This is returned as a numpy array.

# %% [markdown]
# # End of create and folder

# %%
# Search for ***ApexStart*** 
#***ApexEnd***
# This file provides an example problem for testing the DOT wrapper provided
# in dot.py.  The example problem contained in this file is the first
# example problem from the dot.pdf manual.
#
# Gerhard Venter
# August 21, 2019
#------------------------------------------------------------------------------
import dot2 as dot
import math as m
import numpy as nm
import remoting
import apex
from apex.construct import Point3D,  Point2D
import sys
import math
import numpy as np


file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\count.txt", "w")
content = 0
file.write(str(content))
file.close()

#-------------------------------
#*******************************

file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\var1.txt", "a")
# Content to be added
content = "iteration"+'\n'
# Writing the file
file.write(content)
# Closing the opened file
file.close()

file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\var2.txt", "a")
# Content to be added
content = "iteration"+'\n'
# Writing the file
file.write(content)
# Closing the opened file
file.close()

file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\var3.txt", "a")
# Content to be added
content = "iteration"+'\n'
# Writing the file
file.write(content)
# Closing the opened file
file.close()


# Opening the file with append mode
file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\exitcode.txt", "a")
content = "iteration"+'\n'
file.write(content)
file.close()

#-------------------------
# Opening the file with append mode
file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\mcp_t.txt", "a")
content = "iteration"+'\n'
file.write(content)
file.close()

file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\mcp_rot.txt", "a")
content = "iteration"+'\n'
file.write(content)
file.close()

# Opening the file with append mode
file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\pip_t.txt", "a")
content = "iteration"+'\n'
file.write(content)
file.close()

file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\pip_rot.txt", "a")
content = "iteration"+'\n'
file.write(content)
file.close()

# Opening the file with append mode
file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\dip_t.txt", "a")
content = "iteration"+'\n'
file.write(content)
file.close()

file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\dip_rot.txt", "a")
content = "iteration"+'\n'
file.write(content)
file.close()


file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\obj_val.txt", "a")
content = "iteration"+'\n'
file.write(content)
file.close()

#*******************************
#-------------------------------

#------------------------------------------------------------------------------
# Define your own function to evaluate the objective function and constraints
# This function can be name anything, but the arguments must be as shown below.
#
# Input:  x     - The current design variable vector obtained from DOT to 
#               evaluate.  This is a numpy array of length nDvar.
#         obj   - The objective function value that will be evaluated and set 
#               here.
#         g     - The constraint vector that will be evaluated and set here.
#               This is a numpy array of length nCon.
#         param - An optional numpy array with parameter values that the user
#               can specify when setting up the DOT parameters.  These 
#               optional parameters will be passed to this evaluate function
#               unchanged by DOT.
# Return: Nothing
#------------------------------------------------------------------------------
def myEvaluate(x, obj, g, param):

    # Optional step to map the design variable array to local variables that
    # are easier to work with
    flag = 0
    file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\stat.txt","r")
    flag = float(file1.read())
    file1.close()
    
    file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\count.txt","r")
    flag2 = float(file1.read())
    file1.close()
    
    file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\count.txt", "w")
    flag2 += 1
    file.write(str(flag2))
    file.close()
    print(flag2)
    ccde = flag2
    count_out = flag2
    if flag == 0:
        e_ch_var1 = x[0]
        e_ch_var2 = x[1]
        e_ch_var3 = x[2]
        print('***1***')
        print(e_ch_var1)
        print(e_ch_var2)
        print(e_ch_var3)
        with open(r"C:\Users\18507522\Downloads\SB\CODE\ch_var1.txt", 'w') as f:
            f.write(str(e_ch_var1))
            f.close()

        file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\var1.txt", "a")
        # Content to be added
        content = str(e_ch_var1)+'\n'
        # Writing the file
        file.write(content)
        # Closing the opened file
        file.close()

        with open(r"C:\Users\18507522\Downloads\SB\CODE\ch_var2.txt", 'w') as f:
            f.write(str(e_ch_var2))
            f.close()
        file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\var2.txt", "a")
        # Content to be added
        content = str(e_ch_var2)+'\n'
        # Writing the file
        file.write(content)
        # Closing the opened file
        file.close()

        with open(r"C:\Users\18507522\Downloads\SB\CODE\ch_var3.txt", 'w') as f:
            f.write(str(e_ch_var3))
            f.close()
        file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\var3.txt", "a")
        # Content to be added
        content = str(e_ch_var3)+'\n'
        # Writing the file
        file.write(content)
        # Closing the opened file
        file.close()

        # Evaluate the objective function value and use the ".value" notation to
        # update this new value in the calling function, which is DOT in this
        # case
        print('***a***')
        time.sleep(3)
        #==========================================================================================
        # ***************************************ApexStart*****************************************
        
        #==========================================================================================
        #a = %run Apex_start.ipynb
        #a = %run Apex_Final_18507522_04_11_OJoint_Cor.ipynb
        #a = %run Apex_close.ipynb
        
        
        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\gap_height.txt","r")
        gap_height = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\meshing_size.txt","r")
        meshing_size = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ch_var1.txt","r")
        ch_var1 = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ch_var2.txt","r")
        ch_var2 = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ch_var3.txt","r")
        ch_var3 = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\paper_width.txt","r")
        paper_width = float(file1.read())
        file1.close()
        
        apex.setScriptUnitSystem(unitSystemName = r'''m-kg-s-N''')

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\width.txt","r")
        width = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\height.txt","r")
        height = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\bredth.txt","r")
        bredth = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\no_ch.txt","r")
        no_ch = int(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ac_th_up.txt","r")
        ac_th_up = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ac_th_side.txt","r")
        ac_th_side = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ac_th_for.txt","r")
        ac_th_for = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\gap.txt","r")
        gap = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\air_vent.txt","r")
        air_vent = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\gap_height.txt","r")
        gap_height = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\ends_ext.txt","r")
        ends_ext = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\L0.txt","r")
        SL0 = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\L1.txt","r")
        SL1 = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\L2.txt","r")
        SL2 = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\L3.txt","r")
        SL3 = float(file1.read())
        file1.close()

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\fin_rad.txt","r")
        fin_rad = float(file1.read())
        file1.close

        file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\meshsize.txt","r")
        meshsize = float(file1.read())
        file1.close()

        def getAllParts():
            # get and return all solids from current model
            model_1 = apex.currentModel()
            parts = model_1.getParts(True)
            return parts

        def getAllSolids():
            solids = apex.entityCollection()
            parts = getAllParts()
            for part in parts:
                solids += part.getSolids()
            return solids

        def getAllSurfs():
            surfs = apex.entityCollection()
            parts = getAllParts()
            for part in parts:
                surfs += part.getSurfaces()
            return surfs

        # added
        def getAllSurfFaces():
            surffaces = apex.entityCollection()
            surfs = getAllSurfs()
            for surf in surfs:
                surffaces += surf.getFaces()
            return surffaces

        #
        def getAllFaces():
            faces = apex.entityCollection()
            surfs = getAllSurfs()
            for surf in surfs:
                faces += surf.getFaces()
            solids = getAllSolids()
            for solid in solids:
                faces += solid.getFaces()
            return faces

        allSurfs = getAllSurfs()

        for surf in allSurfs:
            print(surf.name)


        # #  links
        # [p1](#p1)
        # [p2](#p2)
        # [p3](#p3)
        # <a id = 'home'></a>

        # In[12]:


        # model = apex.currentModel()
        # model = model.close()


        # In[13]:


        # 1
        # width = 20e-3 # 20e-3
        # height = 15e-3 # 15e-3
        # bredth = 8e-3 # 8e-3
        # no_ch = 11 # 11

        # ac_th_up = 2e-3 # actuator thickness top 2e-3
        # ac_th_side = 3e-3 # actuator thickness side 3e-3
        # ac_th_for = 2.5e-3 # forward dwidth of actuator 2.5e-3
        #=======================================================================================

        ch_width = width-2*ac_th_side
        ch_height = height-ac_th_up
        ch_bredth = bredth-2*ac_th_for

        #***************************************
        #---------------------------------------

        # # B Joint
        # L0= SL0-(SL1-SL0)/4 
        # Origin_start = L0+2e-3
        # L1 = SL0+(SL1-SL0)/2
        # L2 = SL1+(SL2-SL1)/2
        # L3 = SL3

        # # A Joint
        # L0= SL0-(SL1-SL0)/4
        # Origin_start = L0+2e-3
        # L1 = SL1
        # L2 = SL2
        # L3 = SL3+(SL1-SL0)/2

        L0= SL0
        Origin_start = L0+2e-3
        L1 = SL1
        L2 = SL2
        L3 = SL3

        #***************************************
        #---------------------------------------

        # gap = 1e-3 # 1e-3
        # air_vent = 2e-3 # 2e-3
        # gap_height = 1e-3 # 1e-3
        ch_sel_1 = ch_var1#3.31666666666666665#3.8
        no_ch_max_1 = (L1-L0-0.002-0.002)/(2*ac_th_for+0.001+gap) # NB CORRECT
        if ch_sel_1>no_ch_max_1:
            ch_sel_1 = no_ch_max_1

        ch_width_1 = (L1-L0-0.002-0.002)/ch_sel_1 - 2*ac_th_for-gap 
        print(ch_width_1)


        # In[87]:


        print(ch_width_1)


        # In[14]:


        #2
        num = math.floor(ch_sel_1)
        print(num)
        rem_n = round(ch_sel_1-num,6)
        print(rem_n)
        pointa = ac_th_for/(2*ac_th_for+ch_width_1+gap)
        pointb = (ac_th_for+ch_width_1)/(2*ac_th_for+ch_width_1+gap)
        pointc = (ac_th_for*2+ch_width_1)/(2*ac_th_for+ch_width_1+gap)
        print(pointa)
        print(pointb)
        print(pointc) 


        # In[15]:


        #model_1 = apex.currentModel()


        # In[16]:


        # 3
        # FINALLY TRHALK YOU ALRD
        model_1 = apex.currentModel()


        def doSketch_1():
            part_1 = model_1.getCurrentPart()
            if part_1 is None:
                part_1 = model_1.createPart()
            sketch_1 = part_1.createSketchOnGlobalPlane(
                name = 'Sketch 1',
                plane = apex.construct.GlobalPlane.XY,
                alignSketchViewWithViewport = False
            )
        #     rectangle_1 = sketch_1.createRectangle2Point(
        #             name = "Rectangle 1",
        #             location = Point2D( L0+0.002, width/1.2 ),
        #             diagonal = Point2D( L1-0.002, -width/1.2 )
        #         )

        #     rectangle_1 = sketch_1.createRectangle2Point(
        #             name = "Rectangle 1",
        #             location = Point2D( L0+0.002, width/1.5 ),
        #             diagonal = Point2D( L1, -width/1.5 )
        #         )
        #     rectangle_1 = sketch_1.createRectangle2Point(
        #             name = "Rectangle 1",
        #             location = Point2D( L1, width/1.5 ),
        #             diagonal = Point2D( L2, -width/1.5 )
        #         )
        #     rectangle_1 = sketch_1.createRectangle2Point(
        #             name = "Rectangle 1",
        #             location = Point2D( L2, width/1.5 ),
        #             diagonal = Point2D( L3, -width/1.5 )
        #         )
            varb = Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))
            varc = Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n)


            for a in range(math.floor(ch_sel_1)):
                rectangle_1 = sketch_1.createRectangle2Point(
                    name = "Rectangle 1",
                    location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(a), width/2 ),
                    diagonal = Point2D( Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(a), -width/2 )
                )
            if rem_n>0:
                if varc < varb:
                    rectangle_1 = sketch_1.createRectangle2Point(
                        name = "Rectangle 2",
                        location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1)), width/2 ),
                        diagonal = Point2D( Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n), -width/2 )
                    )
                if varc >= varb:
                    rectangle_1 = sketch_1.createRectangle2Point(
                        name = "Rectangle 2",
                        location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1)), width/2 ),
                        diagonal = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+(2*ac_th_for+ch_width_1), -width/2 )
                    )

            rectangle_1 = sketch_1.createRectangle2Point(
                    name = "Rectangle 3",
                    location = Point2D( Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n), -width/2 ),
                    diagonal = Point2D( Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n)+0.002, width/2 )
                )

            return sketch_1.completeSketch( fillSketches = True )

        newbodies = doSketch_1()
        print(type(newbodies))


        # In[17]:


        # _target = apex.EntityCollection()

        # for body in newbodies:
        #     print(body.name)
        #     newSurf = body
        #     break    

        # #_target = apex.EntityCollection()

        # surfFaces = newSurf.getFaces()
        # for iface in surfFaces:
        #     _target.append(iface)


        # In[18]:


        # 4
        # THANK YOU T_____T
        a = getAllSurfFaces()
        #pushpull
        pushpull = apex.geometry.pushPull(
            target = a,
            method = apex.geometry.PushPullMethod.Normal,
            behavior = apex.geometry.PushPullBehavior.Extrude,
            removeInnerLoops = False,
            createBooleanUnion = False,
            distance = height,
            direction = [ 0, 0.0, 1.0 ] )


        # In[19]:


        # 5
        # FINALLY TThis includes filter for end
        model_1 = apex.currentModel()


        def doSketch_1():
            part_1 = model_1.getCurrentPart()
            if part_1 is None:
                part_1 = model_1.createPart()
            sketch_1 = part_1.createSketchOnGlobalPlane(
                name = 'Sketch 1',
                plane = apex.construct.GlobalPlane.XY,
                alignSketchViewWithViewport = False
            )
            for a in range(math.floor(ch_sel_1)):
                rectangle_1 = sketch_1.createRectangle2Point(
                    name = "Rectangle 1",
                    location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(a)+ac_th_for, width/2-ac_th_side ),
                    diagonal = Point2D( Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(a)-ac_th_for, -width/2 +ac_th_side)
                )
            vara = Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
            varb = Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))
            varc = Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n)
            vard = Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_side
            vare = Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap
            if varc <= vara:
                print('nothing')
            elif varc > vara:
                if varc <= vard:
                    rectangle_1 = sketch_1.createRectangle2Point(
                        name = "Rectangle 2",
                        location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2-ac_th_side ),
                        diagonal = Point2D( varc, -width/2+ac_th_side )
                    )
                elif varc > vard:
                    if varc <= varb:
                        rectangle_1 = sketch_1.createRectangle2Point(
                            name = "Rectangle 2",
                            location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2-ac_th_side ),
                            diagonal = Point2D( Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for, -width/2+ac_th_side )
                        )
                    elif varc > varb:
                        rectangle_1 = sketch_1.createRectangle2Point(
                            name = "Rectangle 2",
                            location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2-ac_th_side ),
                            diagonal = Point2D( Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for, -width/2+ac_th_side )
                        )

            return sketch_1.completeSketch( fillSketches = True )

        newbodies = doSketch_1()
        print(type(newbodies))


        # In[20]:


        # 6
        # THANK YOU T_____T x2 caves
        a = getAllSurfFaces()
        #pushpull
        pushpull = apex.geometry.pushPull(
            target = a,
            method = apex.geometry.PushPullMethod.Normal,
            behavior = apex.geometry.PushPullBehavior.Extrude,
            removeInnerLoops = False,
            createBooleanUnion = False,
            distance = height-ac_th_up,
            direction = [ 0, 0.0, 1.0 ] )


        # # gaps

        # In[21]:


        # 5
        # FINALLY TThis includes filter for end
        model_1 = apex.currentModel()


        def doSketch_1():
            part_1 = model_1.getCurrentPart()
            if part_1 is None:
                part_1 = model_1.createPart()
            sketch_1 = part_1.createSketchOnGlobalPlane(
                name = 'Sketch 1',
                plane = apex.construct.GlobalPlane.XY,
                alignSketchViewWithViewport = False
            )
            for a in range(math.floor(ch_sel_1)):
                rectangle_1 = sketch_1.createRectangle2Point(
                    name = "Rectangle 1",
                    location = Point2D( Origin_start+(2*ac_th_for+ch_width_1) +(2*ac_th_for+ch_width_1+gap)*(a), width/2 ),
                    diagonal = Point2D( Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(a)+gap, -width/2 )
                )
            vara = Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
            varb = Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))
            varc = Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n)
            vard = Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_side
            vare = Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap
        #     if varc <= vara:
        #         print('nothing')
        #     elif varc > vara:
        #         if varc > varb:
        #             rectangle_1 = sketch_1.createRectangle2Point(
        #                 name = "Rectangle 2",
        #                 location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2 ),
        #                 diagonal = Point2D( Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for, -width/2)
        #             )
        #         elif varc <= varb:
        #             rectangle_1 = sketch_1.createRectangle2Point(
        #                 name = "Rectangle 2",
        #                 location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2-ac_th_side ),
        #                 diagonal = Point2D( varc, -width/2+ac_th_side )
        #             )
            if varc > varb:
                rectangle_1 = sketch_1.createRectangle2Point(
                    name = "Rectangle 1",
                    location = Point2D( Origin_start+(2*ac_th_for+ch_width_1) +(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1)), width/2 ),
                    diagonal = Point2D( varc, -width/2 )
                )   



            return sketch_1.completeSketch( fillSketches = True )

        newbodies = doSketch_1()
        print(type(newbodies))


        # In[22]:


        # 6
        # THANK YOU T_____T x2 caves
        a = getAllSurfFaces()
        #pushpull
        pushpull = apex.geometry.pushPull(
            target = a,
            method = apex.geometry.PushPullMethod.Normal,
            behavior = apex.geometry.PushPullBehavior.Extrude,
            removeInnerLoops = False,
            createBooleanUnion = False,
            distance = air_vent+gap_height,
            direction = [ 0, 0.0, 1.0 ] )


        # In[23]:


        #model = apex.currentModel()
        #model = model.close()


        # # Just for visualisation
        # <a id = 'vis'></a>
        # [home](#learn)

        # In[24]:


        # # 3
        # # FINALLY TRHALK YOU ALRD
        # model_1 = apex.currentModel()


        # def doSketch_1():
        #     part_1 = model_1.getCurrentPart()
        #     if part_1 is None:
        #         part_1 = model_1.createPart()
        #     sketch_1 = part_1.createSketchOnGlobalPlane(
        #         name = 'Sketch 1',
        #         plane = apex.construct.GlobalPlane.XY,
        #         alignSketchViewWithViewport = False
        #     )
        #     rectangle_1 = sketch_1.createRectangle2Point(
        #             name = "Rectangle 1",
        #             location = Point2D( L0+0.002, width/1.2 ),
        #             diagonal = Point2D( L1-0.002, -width/1.2 )
        #         )

        #     rectangle_1 = sketch_1.createRectangle2Point(
        #             name = "Rectangle 1",
        #             location = Point2D( L0+0.002, width/1.5 ),
        #             diagonal = Point2D( L1, -width/1.5 )
        #         )
        #     rectangle_1 = sketch_1.createRectangle2Point(
        #             name = "Rectangle 1",
        #             location = Point2D( L1, width/1.5 ),
        #             diagonal = Point2D( L2, -width/1.5 )
        #         )
        #     rectangle_1 = sketch_1.createRectangle2Point(
        #             name = "Rectangle 1",
        #             location = Point2D( L2, width/1.5 ),
        #             diagonal = Point2D( L3, -width/1.5 )
        #         )
        #     #var b is actuator just before gap
        #     #var a is for where chamber gap starts
        #     # var c is for position for start of transition block
        # #     vara = Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
        # #     varb = Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))
        # #     varc = Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n)

        # #     rectangle_1 = sketch_1.createRectangle2Point(
        # #             name = "Rectangle 1",
        # #             location = Point2D( 8e-3, width/1 ),
        # #             diagonal = Point2D( vara, -width/1 )
        # #         )
        # #     rectangle_1 = sketch_1.createRectangle2Point(
        # #             name = "Rectangle 1",
        # #             location = Point2D( 9e-3, width/0.9 ),
        # #             diagonal = Point2D( varb, -width/0.9 )
        # #         )
        # #     rectangle_1 = sketch_1.createRectangle2Point(
        # #             name = "Rectangle 1",
        # #             location = Point2D( 10e-3, width/0.8 ),
        # #             diagonal = Point2D( varc, -width/0.8 )
        # #         )

        #     return sketch_1.completeSketch( fillSketches = True )

        # newbodies = doSketch_1()
        # print(type(newbodies))


        # # For second part
        # <a id = 'p2'></a>
        # [home](#home)

        # In[25]:


        # 5GAAAAAAAAP
        # FINALLY TThis includes filter for end
        model_1 = apex.currentModel()


        def doSketch_1():
            part_1 = model_1.getCurrentPart()
            if part_1 is None:
                part_1 = model_1.createPart()
            sketch_1 = part_1.createSketchOnGlobalPlane(
                name = 'Sketch 1',
                plane = apex.construct.GlobalPlane.XY,
                alignSketchViewWithViewport = False
            )
            rectangle_1 = sketch_1.createRectangle2Point(
                name = "Rectangle 1",
                location = Point2D( L1, width/2 ),
                diagonal = Point2D( L1+ gap, -width/2 )
            )
        #     if varc <= vara:
        #         print('nothing')
        #     elif varc > vara:
        #         if varc > varb:
        #             rectangle_1 = sketch_1.createRectangle2Point(
        #                 name = "Rectangle 2",
        #                 location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2 ),
        #                 diagonal = Point2D( Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for, -width/2)
        #             )
        #         elif varc <= varb:
        #             rectangle_1 = sketch_1.createRectangle2Point(
        #                 name = "Rectangle 2",
        #                 location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2-ac_th_side ),
        #                 diagonal = Point2D( varc, -width/2+ac_th_side )
        #             )




            return sketch_1.completeSketch( fillSketches = True )

        newbodies = doSketch_1()
        print(type(newbodies))


        # In[26]:


        # 6
        # THANK YOU T_____T x2 caves
        a = getAllSurfFaces()
        #pushpull
        pushpull = apex.geometry.pushPull(
            target = a,
            method = apex.geometry.PushPullMethod.Normal,
            behavior = apex.geometry.PushPullBehavior.Extrude,
            removeInnerLoops = False,
            createBooleanUnion = False,
            distance = air_vent+gap_height,
            direction = [ 0, 0.0, 1.0 ] )


        # In[27]:


        # 1
        # width = 20e-3 # 20e-3
        # height = 15e-3 # 15e-3
        # bredth = 8e-3 # 8e-3
        # no_ch = 11 # 11

        # ac_th_up = 2e-3 # actuator thickness top 2e-3
        # ac_th_side = 3e-3 # actuator thickness side 3e-3
        # ac_th_for = 2.5e-3 # forward dwidth of actuator 2.5e-3

        # gap = 1e-3 # 1e-3
        # air_vent = 2e-3 # 2e-3
        # gap_height = 1e-3 # 1e-3
        ch_sel_1 = ch_var2#3.31666666666666665#3.8
        no_ch_max_1 = (L2-L1-0.002-gap)/(2*ac_th_for+0.001+gap) # NB CORRECT
        if ch_sel_1>no_ch_max_1:
            ch_sel_1 = no_ch_max_1

        ch_width_1 = (L2-L1-0.002-gap)/ch_sel_1 - 2*ac_th_for-gap 
        print(ch_width_1)


        # In[28]:


        #2
        num = math.floor(ch_sel_1)
        print(num)
        rem_n = round(ch_sel_1-num,6)
        print(rem_n)
        pointa = ac_th_for/(2*ac_th_for+ch_width_1+gap)
        pointb = (ac_th_for+ch_width_1)/(2*ac_th_for+ch_width_1+gap)
        pointc = (ac_th_for*2+ch_width_1)/(2*ac_th_for+ch_width_1+gap)
        print(pointa)
        print(pointb)
        print(pointc) 


        # In[29]:


        #model_1 = apex.currentModel()


        # In[30]:


        # 3
        # FINALLY TRHALK YOU ALRD
        model_1 = apex.currentModel()


        def doSketch_1():
            part_1 = model_1.getCurrentPart()
            if part_1 is None:
                part_1 = model_1.createPart()
            sketch_1 = part_1.createSketchOnGlobalPlane(
                name = 'Sketch 1',
                plane = apex.construct.GlobalPlane.XY,
                alignSketchViewWithViewport = False
            )
        #     rectangle_1 = sketch_1.createRectangle2Point(
        #             name = "Rectangle 1",
        #             location = Point2D( L0+0.002, width/1.2 ),
        #             diagonal = Point2D( L1-0.002, -width/1.2 )
        #         )

        #     rectangle_1 = sketch_1.createRectangle2Point(
        #             name = "Rectangle 1",
        #             location = Point2D( L0+0.002, width/1.5 ),
        #             diagonal = Point2D( L1, -width/1.5 )
        #         )
        #     rectangle_1 = sketch_1.createRectangle2Point(
        #             name = "Rectangle 1",
        #             location = Point2D( L1, width/1.5 ),
        #             diagonal = Point2D( L2, -width/1.5 )
        #         )
        #     rectangle_1 = sketch_1.createRectangle2Point(
        #             name = "Rectangle 1",
        #             location = Point2D( L2, width/1.5 ),
        #             diagonal = Point2D( L3, -width/1.5 )
        #         )
            varb = L1+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))
            varc = L1+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n)
            for a in range(math.floor(ch_sel_1)):
                rectangle_1 = sketch_1.createRectangle2Point(
                    name = "Rectangle 1",
                    location = Point2D( L1+gap+(2*ac_th_for+ch_width_1+gap)*(a), width/2 ),
                    diagonal = Point2D( L1+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(a), -width/2 )
                )
            if rem_n>0:
                if varc < varb:
                    rectangle_1 = sketch_1.createRectangle2Point(
                        name = "Rectangle 2",
                        location = Point2D( L1+gap+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1)), width/2 ),
                        diagonal = Point2D( L1+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n), -width/2 )
                    )
                if varc >= varb:
                    rectangle_1 = sketch_1.createRectangle2Point(
                        name = "Rectangle 2",
                        location = Point2D( L1+gap+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1)), width/2 ),
                        diagonal = Point2D( L1+gap+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+(2*ac_th_for+ch_width_1), -width/2 )
                    )
            rectangle_1 = sketch_1.createRectangle2Point(
                    name = "Rectangle 3",
                    location = Point2D( L1+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n), -width/2 ),
                    diagonal = Point2D( L1+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n)+0.002, width/2 )
                )

            return sketch_1.completeSketch( fillSketches = True )

        newbodies = doSketch_1()
        print(type(newbodies))


        # In[31]:


        # _target = apex.EntityCollection()

        # for body in newbodies:
        #     print(body.name)
        #     newSurf = body
        #     break    

        # #_target = apex.EntityCollection()

        # surfFaces = newSurf.getFaces()
        # for iface in surfFaces:
        #     _target.append(iface)


        # In[32]:


        # 4
        # THANK YOU T_____T
        a = getAllSurfFaces()
        #pushpull
        pushpull = apex.geometry.pushPull(
            target = a,
            method = apex.geometry.PushPullMethod.Normal,
            behavior = apex.geometry.PushPullBehavior.Extrude,
            removeInnerLoops = False,
            createBooleanUnion = False,
            distance = height,
            direction = [ 0, 0.0, 1.0 ] )


        # In[33]:


        # 5
        # FINALLY TThis includes filter for end
        model_1 = apex.currentModel()


        def doSketch_1():
            part_1 = model_1.getCurrentPart()
            if part_1 is None:
                part_1 = model_1.createPart()
            sketch_1 = part_1.createSketchOnGlobalPlane(
                name = 'Sketch 1',
                plane = apex.construct.GlobalPlane.XY,
                alignSketchViewWithViewport = False
            )
            for a in range(math.floor(ch_sel_1)):
                rectangle_1 = sketch_1.createRectangle2Point(
                    name = "Rectangle 1",
                    location = Point2D( L1+gap+(2*ac_th_for+ch_width_1+gap)*(a)+ac_th_for, width/2-ac_th_side ),
                    diagonal = Point2D( L1+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(a)-ac_th_for, -width/2 +ac_th_side)
                )
            vara = L1+gap+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
            varb = L1+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))
            varc = L1+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n)
            vard = L1+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_side
            vare = L1+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap


            st_pt = L1+gap
            if varc <= vara:
                print('nothing')
            elif varc > vara:
                if varc <= vard:
                    rectangle_1 = sketch_1.createRectangle2Point(
                        name = "Rectangle 2",
                        location = Point2D( st_pt+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2-ac_th_side ),
                        diagonal = Point2D( varc, -width/2+ac_th_side )
                    )
                elif varc > vard:
                    if varc <= varb:
                        rectangle_1 = sketch_1.createRectangle2Point(
                            name = "Rectangle 2",
                            location = Point2D( st_pt+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2-ac_th_side ),
                            diagonal = Point2D( st_pt+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for, -width/2+ac_th_side )
                        )
                    elif varc > varb:
                        rectangle_1 = sketch_1.createRectangle2Point(
                            name = "Rectangle 2",
                            location = Point2D( st_pt+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2-ac_th_side ),
                            diagonal = Point2D( st_pt+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for, -width/2+ac_th_side )
                        )


            return sketch_1.completeSketch( fillSketches = True )

        newbodies = doSketch_1()
        print(type(newbodies))


        # In[34]:


        # 6
        # THANK YOU T_____T x2 caves
        a = getAllSurfFaces()
        #pushpull
        pushpull = apex.geometry.pushPull(
            target = a,
            method = apex.geometry.PushPullMethod.Normal,
            behavior = apex.geometry.PushPullBehavior.Extrude,
            removeInnerLoops = False,
            createBooleanUnion = False,
            distance = height-ac_th_up,
            direction = [ 0, 0.0, 1.0 ] )


        # # gaps

        # In[35]:


        # 5
        # FINALLY TThis includes filter for end
        model_1 = apex.currentModel()


        def doSketch_1():
            part_1 = model_1.getCurrentPart()
            if part_1 is None:
                part_1 = model_1.createPart()
            sketch_1 = part_1.createSketchOnGlobalPlane(
                name = 'Sketch 1',
                plane = apex.construct.GlobalPlane.XY,
                alignSketchViewWithViewport = False
            )
            for a in range(math.floor(ch_sel_1)):
                rectangle_1 = sketch_1.createRectangle2Point(
                    name = "Rectangle 1",
                    location = Point2D( L1+gap+(2*ac_th_for+ch_width_1) +(2*ac_th_for+ch_width_1+gap)*(a), width/2 ),
                    diagonal = Point2D( L1+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(a)+gap, -width/2 )
                )
            vara = L1+gap+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
            varb = L1+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))
            varc = L1+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n)

        #     if varc <= vara:
        #         print('nothing')
        #     elif varc > vara:
        #         if varc > varb:
        #             rectangle_1 = sketch_1.createRectangle2Point(
        #                 name = "Rectangle 2",
        #                 location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2 ),
        #                 diagonal = Point2D( Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for, -width/2)
        #             )
        #         elif varc <= varb:
        #             rectangle_1 = sketch_1.createRectangle2Point(
        #                 name = "Rectangle 2",
        #                 location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2-ac_th_side ),
        #                 diagonal = Point2D( varc, -width/2+ac_th_side )
        #             )

            if varc > varb:
                rectangle_1 = sketch_1.createRectangle2Point(
                    name = "Rectangle 1",
                    location = Point2D( L1+gap+(2*ac_th_for+ch_width_1) +(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1)), width/2 ),
                    diagonal = Point2D( varc, -width/2 )
                )       


            return sketch_1.completeSketch( fillSketches = True )

        newbodies = doSketch_1()
        print(type(newbodies))


        # In[36]:


        # 6
        # THANK YOU T_____T x2 caves
        a = getAllSurfFaces()
        #pushpull
        pushpull = apex.geometry.pushPull(
            target = a,
            method = apex.geometry.PushPullMethod.Normal,
            behavior = apex.geometry.PushPullBehavior.Extrude,
            removeInnerLoops = False,
            createBooleanUnion = False,
            distance = air_vent+gap_height,
            direction = [ 0, 0.0, 1.0 ] )


        # In[37]:


        # model = apex.currentModel()
        # model = model.close()


        # [home](#home)

        # # next part 3
        # <a id='p3'></a>

        # In[ ]:





        # In[38]:


        # 5GAAAAAAAAP
        # FINALLY TThis includes filter for end
        model_1 = apex.currentModel()


        def doSketch_1():
            part_1 = model_1.getCurrentPart()
            if part_1 is None:
                part_1 = model_1.createPart()
            sketch_1 = part_1.createSketchOnGlobalPlane(
                name = 'Sketch 1',
                plane = apex.construct.GlobalPlane.XY,
                alignSketchViewWithViewport = False
            )
            rectangle_1 = sketch_1.createRectangle2Point(
                name = "Rectangle 1",
                location = Point2D( L2, width/2 ),
                diagonal = Point2D( L2+ gap, -width/2 )
            )
        #     if varc <= vara:
        #         print('nothing')
        #     elif varc > vara:
        #         if varc > varb:
        #             rectangle_1 = sketch_1.createRectangle2Point(
        #                 name = "Rectangle 2",
        #                 location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2 ),
        #                 diagonal = Point2D( Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for, -width/2)
        #             )
        #         elif varc <= varb:
        #             rectangle_1 = sketch_1.createRectangle2Point(
        #                 name = "Rectangle 2",
        #                 location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2-ac_th_side ),
        #                 diagonal = Point2D( varc, -width/2+ac_th_side )
        #             )




            return sketch_1.completeSketch( fillSketches = True )

        newbodies = doSketch_1()
        print(type(newbodies))


        # In[39]:


        # 6
        # THANK YOU T_____T x2 caves
        a = getAllSurfFaces()
        #pushpull
        pushpull = apex.geometry.pushPull(
            target = a,
            method = apex.geometry.PushPullMethod.Normal,
            behavior = apex.geometry.PushPullBehavior.Extrude,
            removeInnerLoops = False,
            createBooleanUnion = False,
            distance = air_vent+gap_height,
            direction = [ 0, 0.0, 1.0 ] )


        # In[40]:


        # 1
        # width = 20e-3 # 20e-3
        # height = 15e-3 # 15e-3
        # bredth = 8e-3 # 8e-3
        # no_ch = 11 # 11

        # ac_th_up = 2e-3 # actuator thickness top 2e-3
        # ac_th_side = 3e-3 # actuator thickness side 3e-3
        # ac_th_for = 2.5e-3 # forward dwidth of actuator 2.5e-3

        # gap = 1e-3 # 1e-3
        # air_vent = 2e-3 # 2e-3
        # gap_height = 1e-3 # 1e-3
        ch_sel_1 = ch_var3#3.31666666666666665#3.8
        no_ch_max_1 = (L3-L2-0.002-gap)/(2*ac_th_for+0.001+gap) # NB CORRECT
        if ch_sel_1>no_ch_max_1:
            ch_sel_1 = no_ch_max_1

        ch_width_1 = (L3-L2-0.002-gap)/ch_sel_1 - 2*ac_th_for-gap 
        print(ch_width_1)


        # In[41]:


        #2
        num = math.floor(ch_sel_1)
        print(num)
        rem_n = round(ch_sel_1-num,6)
        print(rem_n)
        pointa = ac_th_for/(2*ac_th_for+ch_width_1+gap)
        pointb = (ac_th_for+ch_width_1)/(2*ac_th_for+ch_width_1+gap)
        pointc = (ac_th_for*2+ch_width_1)/(2*ac_th_for+ch_width_1+gap)
        print(pointa)
        print(pointb)
        print(pointc) 


        # In[42]:


        #model_1 = apex.currentModel()


        # In[43]:


        # 3
        # FINALLY TRHALK YOU ALRD
        model_1 = apex.currentModel()


        def doSketch_1():
            part_1 = model_1.getCurrentPart()
            if part_1 is None:
                part_1 = model_1.createPart()
            sketch_1 = part_1.createSketchOnGlobalPlane(
                name = 'Sketch 1',
                plane = apex.construct.GlobalPlane.XY,
                alignSketchViewWithViewport = False
            )
        #     rectangle_1 = sketch_1.createRectangle2Point(
        #             name = "Rectangle 1",
        #             location = Point2D( L0+0.002, width/1.2 ),
        #             diagonal = Point2D( L1-0.002, -width/1.2 )
        #         )

        #     rectangle_1 = sketch_1.createRectangle2Point(
        #             name = "Rectangle 1",
        #             location = Point2D( L0+0.002, width/1.5 ),
        #             diagonal = Point2D( L1, -width/1.5 )
        #         )
        #     rectangle_1 = sketch_1.createRectangle2Point(
        #             name = "Rectangle 1",
        #             location = Point2D( L1, width/1.5 ),
        #             diagonal = Point2D( L2, -width/1.5 )
        #         )
        #     rectangle_1 = sketch_1.createRectangle2Point(
        #             name = "Rectangle 1",
        #             location = Point2D( L2, width/1.5 ),
        #             diagonal = Point2D( L3, -width/1.5 )
        #         )
            varb = L2+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))
            varc = L2+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n)

            for a in range(math.floor(ch_sel_1)):
                rectangle_1 = sketch_1.createRectangle2Point(
                    name = "Rectangle 1",
                    location = Point2D( L2+gap+(2*ac_th_for+ch_width_1+gap)*(a), width/2 ),
                    diagonal = Point2D( L2+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(a), -width/2 )
                )
            if rem_n>0:
                if varc < varb:
                    rectangle_1 = sketch_1.createRectangle2Point(
                        name = "Rectangle 2",
                        location = Point2D( L2+gap+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1)), width/2 ),
                        diagonal = Point2D( L2+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n), -width/2 )
                    )
                if varc >= varb:
                    rectangle_1 = sketch_1.createRectangle2Point(
                        name = "Rectangle 2",
                        location = Point2D( L2+gap+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1)), width/2 ),
                        diagonal = Point2D( L2+gap+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+(2*ac_th_for+ch_width_1), -width/2 )
                    )
            rectangle_1 = sketch_1.createRectangle2Point(
                    name = "Rectangle 3",
                    location = Point2D( L2+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n), -width/2 ),
                    diagonal = Point2D( L2+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n)+0.002, width/2 )
                )

            return sketch_1.completeSketch( fillSketches = True )

        newbodies = doSketch_1()
        print(type(newbodies))


        # In[44]:


        # _target = apex.EntityCollection()

        # for body in newbodies:
        #     print(body.name)
        #     newSurf = body
        #     break    

        # #_target = apex.EntityCollection()

        # surfFaces = newSurf.getFaces()
        # for iface in surfFaces:
        #     _target.append(iface)


        # In[45]:


        # 4
        # THANK YOU T_____T
        a = getAllSurfFaces()
        #pushpull
        pushpull = apex.geometry.pushPull(
            target = a,
            method = apex.geometry.PushPullMethod.Normal,
            behavior = apex.geometry.PushPullBehavior.Extrude,
            removeInnerLoops = False,
            createBooleanUnion = False,
            distance = height,
            direction = [ 0, 0.0, 1.0 ] )


        # In[46]:


        final_chamber_section =[]


        # In[47]:


        # 5
        # FINALLY TThis includes filter for end
        model_1 = apex.currentModel()


        def doSketch_1():
            part_1 = model_1.getCurrentPart()
            if part_1 is None:
                part_1 = model_1.createPart()
            sketch_1 = part_1.createSketchOnGlobalPlane(
                name = 'Sketch 1',
                plane = apex.construct.GlobalPlane.XY,
                alignSketchViewWithViewport = False
            )
            for a in range(math.floor(ch_sel_1)):
                rectangle_1 = sketch_1.createRectangle2Point(
                    name = "Rectangle 1",
                    location = Point2D( L2+gap+(2*ac_th_for+ch_width_1+gap)*(a)+ac_th_for, width/2-ac_th_side ),
                    diagonal = Point2D( L2+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(a)-ac_th_for, -width/2 +ac_th_side)
                )
            vara = L2+gap+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
            varb = L2+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))
            varc = L2+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n)
            st_pt = L2+gap
            vard = st_pt+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_side
            vare = st_pt+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap
            final_chamber_section =  L2+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1)-1)-ac_th_for
            with open(r"C:\Users\18507522\cham_end.txt", 'w') as f:
                f.write(str(final_chamber_section))
                f.close()
            print('a')
            print(final_chamber_section)


            if varc <= vara:
                print('nothing')
            elif varc > vara:
                if varc <= vard:
                    rectangle_1 = sketch_1.createRectangle2Point(
                        name = "Rectangle 2",
                        location = Point2D( st_pt+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2-ac_th_side ),
                        diagonal = Point2D( varc, -width/2+ac_th_side )
                    )
                    final_chamber_section  = varc
                    with open(r"C:\Users\18507522\cham_end.txt", 'w') as f:
                        f.write(str(final_chamber_section))
                        f.close()

                elif varc > vard:
                    if varc <= varb:
                        rectangle_1 = sketch_1.createRectangle2Point(
                            name = "Rectangle 2",
                            location = Point2D( st_pt+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2-ac_th_side ),
                            diagonal = Point2D( st_pt+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for, -width/2+ac_th_side )
                        )
                        final_chamber_section  = st_pt+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for
                        with open(r"C:\Users\18507522\cham_end.txt", 'w') as f:
                            f.write(str(final_chamber_section))
                            f.close()
                    elif varc > varb:
                        rectangle_1 = sketch_1.createRectangle2Point(
                            name = "Rectangle 2",
                            location = Point2D( st_pt+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2-ac_th_side ),
                            diagonal = Point2D( st_pt+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for, -width/2+ac_th_side )
                        )
                        final_chamber_section  = st_pt+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for
                        with open(r"C:\Users\18507522\cham_end.txt", 'w') as f:
                            f.write(str(final_chamber_section))
                            f.close()

            return sketch_1.completeSketch( fillSketches = True )

        newbodies = doSketch_1()
        print(type(newbodies))


        # In[48]:


        print(final_chamber_section)


        # In[49]:


        # 6
        # THANK YOU T_____T x2 caves
        a = getAllSurfFaces()
        #pushpull
        pushpull = apex.geometry.pushPull(
            target = a,
            method = apex.geometry.PushPullMethod.Normal,
            behavior = apex.geometry.PushPullBehavior.Extrude,
            removeInnerLoops = False,
            createBooleanUnion = False,
            distance = height-ac_th_up,
            direction = [ 0, 0.0, 1.0 ] )


        # # gaps

        # In[50]:


        # 5
        # FINALLY TThis includes filter for end
        model_1 = apex.currentModel()


        def doSketch_1():
            part_1 = model_1.getCurrentPart()
            if part_1 is None:
                part_1 = model_1.createPart()
            sketch_1 = part_1.createSketchOnGlobalPlane(
                name = 'Sketch 1',
                plane = apex.construct.GlobalPlane.XY,
                alignSketchViewWithViewport = False
            )
            for a in range(math.floor(ch_sel_1)):
                rectangle_1 = sketch_1.createRectangle2Point(
                    name = "Rectangle 1",
                    location = Point2D( L2+gap+(2*ac_th_for+ch_width_1) +(2*ac_th_for+ch_width_1+gap)*(a), width/2 ),
                    diagonal = Point2D( L2+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(a)+gap, -width/2 )
                )
            vara = L2+gap+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for
            varb = L2+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))
            varc = L2+gap+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+gap-(2*ac_th_for+ch_width_1+gap)*(1-rem_n)

        #     if varc <= vara:
        #         print('nothing')
        #     elif varc > vara:
        #         if varc > varb:
        #             rectangle_1 = sketch_1.createRectangle2Point(
        #                 name = "Rectangle 2",
        #                 location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2 ),
        #                 diagonal = Point2D( Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for, -width/2)
        #             )
        #         elif varc <= varb:
        #             rectangle_1 = sketch_1.createRectangle2Point(
        #                 name = "Rectangle 2",
        #                 location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2-ac_th_side ),
        #                 diagonal = Point2D( varc, -width/2+ac_th_side )
        #             )
            if varc > varb:
                rectangle_1 = sketch_1.createRectangle2Point(
                    name = "Rectangle 1",
                    location = Point2D( L2+gap+(2*ac_th_for+ch_width_1) +(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1)), width/2 ),
                    diagonal = Point2D( varc, -width/2 )
                )                                                                          



            return sketch_1.completeSketch( fillSketches = True )

        newbodies = doSketch_1()
        print(type(newbodies))


        # In[51]:


        # 6
        # THANK YOU T_____T x2 caves
        a = getAllSurfFaces()
        #pushpull
        pushpull = apex.geometry.pushPull(
            target = a,
            method = apex.geometry.PushPullMethod.Normal,
            behavior = apex.geometry.PushPullBehavior.Extrude,
            removeInnerLoops = False,
            createBooleanUnion = False,
            distance = air_vent+gap_height,
            direction = [ 0, 0.0, 1.0 ] )


        # # Final

        # In[52]:


        # 5
        # FINALLY TThis includes filter for end
        model_1 = apex.currentModel()


        def doSketch_1():
            part_1 = model_1.getCurrentPart()
            if part_1 is None:
                part_1 = model_1.createPart()
            sketch_1 = part_1.createSketchOnGlobalPlane(
                name = 'Sketch 1',
                plane = apex.construct.GlobalPlane.XY,
                alignSketchViewWithViewport = False
            )
            rectangle_1 = sketch_1.createRectangle2Point(
                name = "Rectangle 1",
                location = Point2D( Origin_start, width/2 ),
                diagonal = Point2D( L0, -width/2 )
            )
            rectangle_1 = sketch_1.createRectangle2Point(
                name = "Rectangle 1",
                location = Point2D( L3, width/2 ),
                diagonal = Point2D( L3+2e-3, -width/2 )
            )
        #     if varc <= vara:
        #         print('nothing')
        #     elif varc > vara:
        #         if varc > varb:
        #             rectangle_1 = sketch_1.createRectangle2Point(
        #                 name = "Rectangle 2",
        #                 location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2 ),
        #                 diagonal = Point2D( Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for, -width/2)
        #             )
        #         elif varc <= varb:
        #             rectangle_1 = sketch_1.createRectangle2Point(
        #                 name = "Rectangle 2",
        #                 location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2-ac_th_side ),
        #                 diagonal = Point2D( varc, -width/2+ac_th_side )
        #             )




            return sketch_1.completeSketch( fillSketches = True )

        newbodies = doSketch_1()
        print(type(newbodies))


        # In[53]:


        # 6
        # THANK YOU T_____T x2 caves
        a = getAllSurfFaces()
        #pushpull
        pushpull = apex.geometry.pushPull(
            target = a,
            method = apex.geometry.PushPullMethod.Normal,
            behavior = apex.geometry.PushPullBehavior.Extrude,
            removeInnerLoops = False,
            createBooleanUnion = False,
            distance = height,
            direction = [ 0, 0.0, 1.0 ] )


        # In[ ]:





        # In[54]:


        point0 = Origin_start+(2*ac_th_for+ch_width_1+gap)*0+ac_th_for


        file1 = open(r"C:\Users\18507522\cham_end.txt","r")
        fin_end_ch = float(file1.read())
        file1.close()

        point_fin = fin_end_ch

        # 5
        # FINALLY TThis includes filter for end
        model_1 = apex.currentModel()


        def doSketch_1():
            part_1 = model_1.getCurrentPart()
            if part_1 is None:
                part_1 = model_1.createPart()
            sketch_1 = part_1.createSketchOnGlobalPlane(
                name = 'Sketch 1',
                plane = apex.construct.GlobalPlane.XY,
                alignSketchViewWithViewport = False
            )
            rectangle_1 = sketch_1.createRectangle2Point(
                name = "Rectangle 1",
                location = Point2D( point0, air_vent/2 ),
                diagonal = Point2D( point_fin, -air_vent/2 )
            )

        #     if varc <= vara:
        #         print('nothing')
        #     elif varc > vara:
        #         if varc > varb:
        #             rectangle_1 = sketch_1.createRectangle2Point(
        #                 name = "Rectangle 2",
        #                 location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2 ),
        #                 diagonal = Point2D( Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for, -width/2)
        #             )
        #         elif varc <= varb:
        #             rectangle_1 = sketch_1.createRectangle2Point(
        #                 name = "Rectangle 2",
        #                 location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2-ac_th_side ),
        #                 diagonal = Point2D( varc, -width/2+ac_th_side )
        #             )




            return sketch_1.completeSketch( fillSketches = True )

        newbodies = doSketch_1()
        print(type(newbodies))


        # In[55]:


        # 6
        # THANK YOU T_____T x2 caves
        a = getAllSurfFaces()
        #pushpull
        pushpull = apex.geometry.pushPull(
            target = a,
            method = apex.geometry.PushPullMethod.Normal,
            behavior = apex.geometry.PushPullBehavior.Extrude,
            removeInnerLoops = False,
            createBooleanUnion = False,
            distance = air_vent,
            direction = [ 0, 0.0, 1.0 ] )


        # In[56]:


        # 5
        # FINALLY TThis includes filter for end
        model_1 = apex.currentModel()


        def doSketch_1():
            part_1 = model_1.getCurrentPart()
            if part_1 is None:
                part_1 = model_1.createPart()
            sketch_1 = part_1.createSketchOnGlobalPlane(
                name = 'Sketch 1',
                plane = apex.construct.GlobalPlane.XY,
                alignSketchViewWithViewport = False
            )
            rectangle_1 = sketch_1.createRectangle2Point(
                name = "Rectangle 1",
                location = Point2D( L0, width/2 ),
                diagonal = Point2D( L3+2e-3, -width/2 )
            )

        #     if varc <= vara:
        #         print('nothing')
        #     elif varc > vara:
        #         if varc > varb:
        #             rectangle_1 = sketch_1.createRectangle2Point(
        #                 name = "Rectangle 2",
        #                 location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2 ),
        #                 diagonal = Point2D( Origin_start+(2*ac_th_for+ch_width_1) + (2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))-ac_th_for, -width/2)
        #             )
        #         elif varc <= varb:
        #             rectangle_1 = sketch_1.createRectangle2Point(
        #                 name = "Rectangle 2",
        #                 location = Point2D( Origin_start+(2*ac_th_for+ch_width_1+gap)*(math.floor(ch_sel_1))+ac_th_for, width/2-ac_th_side ),
        #                 diagonal = Point2D( varc, -width/2+ac_th_side )
        #             )




            return sketch_1.completeSketch( fillSketches = True )

        newbodies = doSketch_1()
        print(type(newbodies))


        # In[57]:


        # 6
        # THANK YOU T_____T x2 caves
        a = getAllSurfFaces()
        #pushpull
        pushpull = apex.geometry.pushPull(
            target = a,
            method = apex.geometry.PushPullMethod.Normal,
            behavior = apex.geometry.PushPullBehavior.Extrude,
            removeInnerLoops = False,
            createBooleanUnion = False,
            distance = 2e-3,
            direction = [ 0, 0.0, -1.0 ] )


        #--------------------------------------------------------
        #************************************************************
        #************************************************************
        # gaps split in x direction
        part_1 = model_1.getCurrentPart()
        if part_1 is None:
            part_1 = model_1.createPart()

        part_2 = apex.getPart( pathName = "Model/Part 1" )

        #-------------------- name
        allSol = getAllSolids()
        sol_name = str(allSol[0].name)
        #--------------------

        solid_1 = part_2.getSolid( name = sol_name )

        # This next part is to get the faces
        #--------------------
        facecollection = part_1.getSolid( name = sol_name).getFaces()

        faceselection = 'Null'

        temp_X = 0
        temp_Y = 0
        temp_Z = 0

        id_col = []
        x_col = []
        y_col = []
        z_col = []

        iter_count = 0
        top_count = 0

        side1 = width
        side2 = height-gap_height-air_vent
        for face in facecollection:
            if round(float(face.getArea()),7) == round(side1*side2,7):
                #print(str(round(face.getArea(),4))+"first check " + str(round(height*width,4)))
                #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))
                if round(float(face.getCentroid().getY()),4) == round(0.0,4):
                    print('o:'+str(round(float(face.getArea()),7)))
                    print('d:'+str(round(side1*side2,7)))
                    print('')
                    #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))    
                    faceselection = str(face.id)
                    temp_X = float(face.getCentroid().getX())
                    temp_Y = float(face.getCentroid().getY())
                    temp_Z = float(face.getCentroid().getZ())
                    id_col.append(faceselection)
                    x_col.append(temp_X)
                    y_col.append(temp_Y)
                    z_col.append(temp_Z)
                    iter_count += 1
                    #print('face selection is: '+ faceselection)

                    #--------------------
        if faceselection == 'Null':
            raise TypeError("Face wasn't found")

        for a in range(iter_count):            
            print(str(temp_X)+" "+str(temp_Y)+" "+str(temp_Z)+" face: "+str(faceselection))

            _target = apex.EntityCollection()
            part_1 = apex.getPart( pathName = "Model/Part 1" )
            solid_1 = part_1.getSolid( name = sol_name )
            _target.append( solid_1 )
            _location = apex.Coordinate( x_col[a], y_col[a], z_col[a])
            part_1 = apex.getPart( pathName = "Model/Part 1" )
            solid_1 = part_1.getSolid( name = sol_name )
            _snapEntity = solid_1.getFace( id = int(id_col[a]) )
            result = apex.geometry.splitOnFeaturePlane(
                target = _target,
                location = _location,
                snapEntity = _snapEntity,
                splitBehavior = apex.geometry.GeometrySplitBehavior.Partition
            )

            # gaps split in x direction
        part_1 = model_1.getCurrentPart()
        if part_1 is None:
            part_1 = model_1.createPart()
        part_2 = apex.getPart( pathName = "Model/Part 1" )

        #-------------------- name
        allSol = getAllSolids()
        sol_name = str(allSol[0].name)
        #--------------------

        solid_1 = part_2.getSolid( name = sol_name )

        # This next part is to get the faces
        #--------------------
        facecollection = part_1.getSolid( name = sol_name).getFaces()

        faceselection = 'Null'

        temp_X = 0
        temp_Y = 0
        temp_Z = 0

        id_col = []
        x_col = []
        y_col = []
        z_col = []

        iter_count = 0
        top_count = 0

        side1 = ch_width
        side2 = height-air_vent
        for face in facecollection:
            if round(float(face.getArea()),7) == round(side1*side2-air_vent*air_vent,7):
                #print(str(round(face.getArea(),4))+"first check " + str(round(height*width,4)))
                #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))
                if round(float(face.getCentroid().getY()),4) == round(0.0,4):
                    print('o:'+str(round(float(face.getArea()),7)))
                    print('d:'+str(round(side1*side2,7)))
                    print('')
                    #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))    
                    faceselection = str(face.id)
                    temp_X = float(face.getCentroid().getX())
                    temp_Y = float(face.getCentroid().getY())
                    temp_Z = float(face.getCentroid().getZ())
                    id_col.append(faceselection)
                    x_col.append(temp_X)
                    y_col.append(temp_Y)
                    z_col.append(temp_Z)
                    iter_count += 1
                    #print('face selection is: '+ faceselection)

                    #--------------------
        if faceselection == 'Null':
            raise TypeError("Face wasn't found")

        for a in range(iter_count):            
            print(str(temp_X)+" "+str(temp_Y)+" "+str(temp_Z)+" face: "+str(faceselection))

            _target = apex.EntityCollection()
            part_1 = apex.getPart( pathName = "Model/Part 1" )
            solid_1 = part_1.getSolid( name = sol_name )
            _target.append( solid_1 )
            _location = apex.Coordinate( x_col[a], y_col[a], z_col[a])
            part_1 = apex.getPart( pathName = "Model/Part 1" )
            solid_1 = part_1.getSolid( name = sol_name )
            _snapEntity = solid_1.getFace( id = int(id_col[a]) )
            result = apex.geometry.splitOnFeaturePlane(
                target = _target,
                location = _location,
                snapEntity = _snapEntity,
                splitBehavior = apex.geometry.GeometrySplitBehavior.Partition
            )

        # gaps split in x direction
        part_1 = model_1.getCurrentPart()
        if part_1 is None:
            part_1 = model_1.createPart()
        part_2 = apex.getPart( pathName = "Model/Part 1" )

        #-------------------- name
        allSol = getAllSolids()
        sol_name = str(allSol[0].name)
        #--------------------

        solid_1 = part_2.getSolid( name = sol_name )

        # This next part is to get the faces
        #--------------------
        facecollection = part_1.getSolid( name = sol_name).getFaces()

        faceselection = 'Null'

        temp_X = 0
        temp_Y = 0
        temp_Z = 0

        id_col = []
        x_col = []
        y_col = []
        z_col = []

        iter_count = 0
        top_count = 0

        side1 = ch_width
        side2 = height-air_vent
        for face in facecollection:
            if round(float(face.getArea()),7) == round(side1*side2,7):
                #print(str(round(face.getArea(),4))+"first check " + str(round(height*width,4)))
                #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))
                if round(float(face.getCentroid().getY()),4) == round(0.0,4):
                    print('o:'+str(round(float(face.getArea()),7)))
                    print('d:'+str(round(side1*side2,7)))
                    print('')
                    #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))    
                    faceselection = str(face.id)
                    temp_X = float(face.getCentroid().getX())
                    temp_Y = float(face.getCentroid().getY())
                    temp_Z = float(face.getCentroid().getZ())
                    id_col.append(faceselection)
                    x_col.append(temp_X)
                    y_col.append(temp_Y)
                    z_col.append(temp_Z)
                    iter_count += 1
                    #print('face selection is: '+ faceselection)

                    #--------------------
        if faceselection == 'Null':
            raise TypeError("Face wasn't found")

        for a in range(iter_count):            
            print(str(temp_X)+" "+str(temp_Y)+" "+str(temp_Z)+" face: "+str(faceselection))

            _target = apex.EntityCollection()
            part_1 = apex.getPart( pathName = "Model/Part 1" )
            solid_1 = part_1.getSolid( name = sol_name )
            _target.append( solid_1 )
            _location = apex.Coordinate( x_col[a], y_col[a], z_col[a])
            part_1 = apex.getPart( pathName = "Model/Part 1" )
            solid_1 = part_1.getSolid( name = sol_name )
            _snapEntity = solid_1.getFace( id = int(id_col[a]) )
            result = apex.geometry.splitOnFeaturePlane(
                target = _target,
                location = _location,
                snapEntity = _snapEntity,
                splitBehavior = apex.geometry.GeometrySplitBehavior.Partition
            )

        #******************************top split ********************x direct
        # This code is used to create the splits needed for meshing
        part_1 = model_1.getCurrentPart()
        if part_1 is None:
            part_1 = model_1.createPart()
        part_2 = apex.getPart( pathName = "Model/Part 1" )

        #-------------------- name
        allSol = getAllSolids()
        sol_name = str(allSol[0].name)
        #--------------------

        solid_1 = part_2.getSolid( name = sol_name )

        # This next part is to get the faces
        #--------------------
        facecollection = part_1.getSolid( name = sol_name).getFaces()

        faceselection = 'Null'
        temp_X = 0
        temp_Y = 0
        temp_Z = 0

        ch_sel_1 = ch_var1
        ch_width_1 = (L1-L0-0.002-0.002)/ch_sel_1 - 2*ac_th_for-gap 

        count = 0
        for face in facecollection:
            print(count)
            print(str(round((width-2*ac_th_side)*ch_width_1,8)))
            print("found:"+str(round(float(face.getArea()),8) ))
            if round(float(face.getArea()),8) == round((width-2*ac_th_side)*ch_width_1,8):
                #print(str(round(face.getArea(),8))+"first check " + str(round(height*width,8)))
                #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))
                if round(count,5) == round(0,5):
                    if round(float(face.getCentroid().getZ()),8) == round(height-ac_th_up,8):
                        count = 1
                        #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))    
                        faceselection = str(face.id)
                        temp_X = float(face.getCentroid().getX())
                        temp_Y = float(face.getCentroid().getY())
                        temp_Z = float(face.getCentroid().getZ())
                        #print('face selection is: '+ faceselection)

                    #--------------------
        if faceselection == 'Null':
            raise TypeError("Face wasn't found")

        print(str(temp_X)+" "+str(temp_Y)+" "+str(temp_Z)+" face: "+str(faceselection))

        _target = apex.EntityCollection()
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        solid_1 = part_1.getSolid( name = sol_name )
        _target.append( solid_1 )
        _location = apex.Coordinate( temp_X, temp_Y, temp_Z )
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        solid_1 = part_1.getSolid( name = sol_name )
        _snapEntity = solid_1.getFace( id = int(faceselection) )
        result = apex.geometry.splitOnFeaturePlane(
            target = _target,
            location = _location,
            snapEntity = _snapEntity,
            splitBehavior = apex.geometry.GeometrySplitBehavior.Partition
        )

        # ***********************gap split x direct ***********************
        # This code is used to create the splits needed for meshing
        part_1 = model_1.getCurrentPart()
        if part_1 is None:
            part_1 = model_1.createPart()
        part_2 = apex.getPart( pathName = "Model/Part 1" )

        #-------------------- name
        allSol = getAllSolids()
        sol_name = str(allSol[0].name)
        #--------------------

        solid_1 = part_2.getSolid( name = sol_name )

        # This next part is to get the faces
        #--------------------
        facecollection = part_1.getSolid( name = sol_name).getFaces()

        faceselection = 'Null'
        temp_X = 0
        temp_Y = 0
        temp_Z = 0

        ch_sel_1 = ch_var1
        ch_width_1 = (L1-L0-0.002-0.002)/ch_sel_1 - 2*ac_th_for-gap 

        count = 0
        for face in facecollection:
            print(count)
            print(str(round((width-2*ac_th_side)*ch_width_1,8)))
            print("found:"+str(round(float(face.getArea()),8) ))
            if round(float(face.getArea()),8) == round((width)*gap,8):
                #print(str(round(face.getArea(),8))+"first check " + str(round(height*width,8)))
                #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))
                if round(count,5) == round(0,5):
                    if round(float(face.getCentroid().getZ()),8) == round(gap_height+air_vent,8):
                        count = 1
                        #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))    
                        faceselection = str(face.id)
                        temp_X = float(face.getCentroid().getX())
                        temp_Y = float(face.getCentroid().getY())
                        temp_Z = float(face.getCentroid().getZ())
                        #print('face selection is: '+ faceselection)

                    #--------------------
        if faceselection == 'Null':
            raise TypeError("Face wasn't found")

        print(str(temp_X)+" "+str(temp_Y)+" "+str(temp_Z)+" face: "+str(faceselection))

        _target = apex.EntityCollection()
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        solid_1 = part_1.getSolid( name = sol_name )
        _target.append( solid_1 )
        _location = apex.Coordinate( temp_X, temp_Y, temp_Z )
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        solid_1 = part_1.getSolid( name = sol_name )
        _snapEntity = solid_1.getFace( id = int(faceselection) )
        result = apex.geometry.splitOnFeaturePlane(
            target = _target,
            location = _location,
            snapEntity = _snapEntity,
            splitBehavior = apex.geometry.GeometrySplitBehavior.Partition
        )


        # This code is used to create the splits needed for meshing
        part_1 = model_1.getCurrentPart()
        if part_1 is None:
            part_1 = model_1.createPart()
        part_2 = apex.getPart( pathName = "Model/Part 1" )

        #-------------------- name
        allSol = getAllSolids()
        sol_name = str(allSol[0].name)
        #--------------------

        solid_1 = part_2.getSolid( name = sol_name )

        # This next part is to get the faces
        #--------------------
        facecollection = part_1.getSolid( name = sol_name).getFaces()

        faceselection = 'Null'

        temp_X = 0
        temp_Y = 0
        temp_Z = 0

        side1 = air_vent
        side2 = ac_th_for
        count = 0
        for face in facecollection:
            if round(float(face.getArea()),8) == round(side1*side2,8):
                #print(str(round(face.getArea(),4))+"first check " + str(round(height*width,4)))
                #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))
                if round(float(face.getCentroid().getZ()),8) == round(air_vent,8):
                    #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))    
                    if round(count,5) == round(0,5):
                        count = 1
                        faceselection = str(face.id)
                        temp_X = float(face.getCentroid().getX())
                        temp_Y = float(face.getCentroid().getY())
                        temp_Z = float(face.getCentroid().getZ())
                    #print('face selection is: '+ faceselection)

                    #--------------------
        if faceselection == 'Null':
            raise TypeError("Face wasn't found")

        print(str(temp_X)+" "+str(temp_Y)+" "+str(temp_Z)+" face: "+str(faceselection))

        _target = apex.EntityCollection()
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        solid_1 = part_1.getSolid( name = sol_name )
        _target.append( solid_1 )
        _location = apex.Coordinate( temp_X, temp_Y, temp_Z )
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        solid_1 = part_1.getSolid( name = sol_name )
        _snapEntity = solid_1.getFace( id = int(faceselection) )
        result = apex.geometry.splitOnFeaturePlane(
            target = _target,
            location = _location,
            snapEntity = _snapEntity,
            splitBehavior = apex.geometry.GeometrySplitBehavior.Partition
        )

        # This code is used to create the splits needed for meshing
        part_1 = model_1.getCurrentPart()
        if part_1 is None:
            part_1 = model_1.createPart()
        part_2 = apex.getPart( pathName = "Model/Part 1" )

        #-------------------- name
        allSol = getAllSolids()
        sol_name = str(allSol[0].name)
        #--------------------

        solid_1 = part_2.getSolid( name = sol_name )

        # This next part is to get the faces
        #--------------------
        facecollection = part_1.getSolid( name = sol_name).getFaces()

        faceselection = 'Null'

        temp_X = 0
        temp_Y = 0
        temp_Z = 0

        side1 = air_vent
        side2 = ac_th_for*2+gap

        for face in facecollection:
            if round(float(face.getArea()),4) == round(side1*side2,4):
                #print(str(round(face.getArea(),4))+"first check " + str(round(height*width,4)))
                #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))
                if round(float(face.getCentroid().getY()),4) == round(air_vent/2,4):
                    #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))    
                    faceselection = str(face.id)
                    temp_X = float(face.getCentroid().getX())
                    temp_Y = float(face.getCentroid().getY())
                    temp_Z = float(face.getCentroid().getZ())
                    #print('face selection is: '+ faceselection)

                    #--------------------
        if faceselection == 'Null':
            raise TypeError("Face wasn't found")

        print(str(temp_X)+" "+str(temp_Y)+" "+str(temp_Z)+" face: "+str(faceselection))

        _target = apex.EntityCollection()
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        solid_1 = part_1.getSolid( name = sol_name )
        _target.append( solid_1 )
        _location = apex.Coordinate( temp_X, temp_Y, temp_Z )
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        solid_1 = part_1.getSolid( name = sol_name )
        _snapEntity = solid_1.getFace( id = int(faceselection) )
        result = apex.geometry.splitOnFeaturePlane(
            target = _target,
            location = _location,
            snapEntity = _snapEntity,
            splitBehavior = apex.geometry.GeometrySplitBehavior.Partition
        )

        # This code is used to create the splits needed for meshing
        part_1 = model_1.getCurrentPart()
        if part_1 is None:
            part_1 = model_1.createPart()
        part_2 = apex.getPart( pathName = "Model/Part 1" )

        #-------------------- name
        allSol = getAllSolids()
        sol_name = str(allSol[0].name)
        #--------------------

        solid_1 = part_2.getSolid( name = sol_name )

        # This next part is to get the faces
        #--------------------
        facecollection = part_1.getSolid( name = sol_name).getFaces()

        faceselection = 'Null'

        temp_X = 0
        temp_Y = 0
        temp_Z = 0

        side1 = air_vent
        side2 = ac_th_for*2+gap

        for face in facecollection:
            if round(float(face.getArea()),4) == round(side1*side2,4):
                #print(str(round(face.getArea(),4))+"first check " + str(round(height*width,4)))
                #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))
                if round(float(face.getCentroid().getY()),4) == round(-air_vent/2,4):
                    #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))    
                    faceselection = str(face.id)
                    temp_X = float(face.getCentroid().getX())
                    temp_Y = float(face.getCentroid().getY())
                    temp_Z = float(face.getCentroid().getZ())
                    #print('face selection is: '+ faceselection)

                    #--------------------
        if faceselection == 'Null':
            raise TypeError("Face wasn't found")

        print(str(temp_X)+" "+str(temp_Y)+" "+str(temp_Z)+" face: "+str(faceselection))

        _target = apex.EntityCollection()
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        solid_1 = part_1.getSolid( name = sol_name )
        _target.append( solid_1 )
        _location = apex.Coordinate( temp_X, temp_Y, temp_Z )
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        solid_1 = part_1.getSolid( name = sol_name )
        _snapEntity = solid_1.getFace( id = int(faceselection) )
        result = apex.geometry.splitOnFeaturePlane(
            target = _target,
            location = _location,
            snapEntity = _snapEntity,
            splitBehavior = apex.geometry.GeometrySplitBehavior.Partition
        )

        # This code is used to create the splits needed for meshing
        part_1 = model_1.getCurrentPart()
        if part_1 is None:
            part_1 = model_1.createPart()
        part_2 = apex.getPart( pathName = "Model/Part 1" )

        #-------------------- name
        allSol = getAllSolids()
        sol_name = str(allSol[0].name)
        #--------------------

        solid_1 = part_2.getSolid( name = sol_name )

        # This next part is to get the faces
        #--------------------
        facecollection = part_1.getSolid( name = sol_name).getFaces()

        faceselection = 'Null'

        temp_X = 0
        temp_Y = 0
        temp_Z = 0

        side1 = air_vent
        side2 = gap
        count = 0
        for face in facecollection:
            if round(float(face.getArea()),4) == round(side1*side2,4):
                #print(str(round(face.getArea(),4))+"first check " + str(round(height*width,4)))
                #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))
                if count ==0:
                    if round(float(face.getCentroid().getZ()),4) == round(0.0,4):
                        #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))    
                        count = 1
                        faceselection = str(face.id)
                        temp_X = float(face.getCentroid().getX())
                        temp_Y = float(face.getCentroid().getY())
                        temp_Z = float(face.getCentroid().getZ())
                        #print('face selection is: '+ faceselection)

                    #--------------------
        if faceselection == 'Null':
            raise TypeError("Face wasn't found")

        print(str(temp_X)+" "+str(temp_Y)+" "+str(temp_Z)+" face: "+str(faceselection))

        _target = apex.EntityCollection()
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        solid_1 = part_1.getSolid( name = sol_name )
        _target.append( solid_1 )
        _location = apex.Coordinate( temp_X, temp_Y, temp_Z )
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        solid_1 = part_1.getSolid( name = sol_name )
        _snapEntity = solid_1.getFace( id = int(faceselection) )
        result = apex.geometry.splitOnFeaturePlane(
            target = _target,
            location = _location,
            snapEntity = _snapEntity,
            splitBehavior = apex.geometry.GeometrySplitBehavior.Partition
        )







        # This code is used to create the splits needed for meshing
        part_1 = model_1.getCurrentPart()
        if part_1 is None:
            part_1 = model_1.createPart()
        part_2 = apex.getPart( pathName = "Model/Part 1" )

        #-------------------- name
        allSol = getAllSolids()
        sol_name = str(allSol[0].name)
        #--------------------

        solid_1 = part_2.getSolid( name = sol_name )

        # This next part is to get the faces
        #--------------------
        facecollection = part_1.getSolid( name = sol_name).getFaces()

        faceselection = 'Null'

        temp_X = 0
        temp_Y = 0
        temp_Z = 0

        ch_sel_1 = ch_var1
        ch_bredth_p = (L1-L0-0.002-0.002)/ch_sel_1 - 2*ac_th_for-gap 

        side1 = ch_bredth_p
        side2 = height-ac_th_up-air_vent-gap_height
        count = 0

        for face in facecollection:
            if round(float(face.getArea()),4) == round(side1*side2,4):
                #print(str(round(face.getArea(),4))+"first check " + str(round(height*width,4)))
                #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))
                if count == 0:

                    if round(float(face.getCentroid().getY()),4) == round(ch_width/2,4):
                        count = 1
                        #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))    
                        faceselection = str(face.id)
                        temp_X = float(face.getCentroid().getX())
                        temp_Y = float(face.getCentroid().getY())
                        temp_Z = float(face.getCentroid().getZ())
                    #print('face selection is: '+ faceselection)

                    #--------------------
        if faceselection == 'Null':
            raise TypeError("Face wasn't found")

        print(str(temp_X)+" "+str(temp_Y)+" "+str(temp_Z)+" face: "+str(faceselection))

        _target = apex.EntityCollection()
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        solid_1 = part_1.getSolid( name = sol_name )
        _target.append( solid_1 )
        _location = apex.Coordinate( temp_X, temp_Y, temp_Z )
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        solid_1 = part_1.getSolid( name = sol_name )
        _snapEntity = solid_1.getFace( id = int(faceselection) )
        result = apex.geometry.splitOnFeaturePlane(
            target = _target,
            location = _location,
            snapEntity = _snapEntity,
            splitBehavior = apex.geometry.GeometrySplitBehavior.Partition
        )



        # This code is used to create the splits needed for meshing
        part_1 = model_1.getCurrentPart()
        if part_1 is None:
            part_1 = model_1.createPart()
        part_2 = apex.getPart( pathName = "Model/Part 1" )

        #-------------------- name
        allSol = getAllSolids()
        sol_name = str(allSol[0].name)
        #--------------------

        solid_1 = part_2.getSolid( name = sol_name )

        # This next part is to get the faces
        #--------------------
        facecollection = part_1.getSolid( name = sol_name).getFaces()

        faceselection = 'Null'

        temp_X = 0
        temp_Y = 0
        temp_Z = 0

        ch_sel_1 = ch_var1
        ch_bredth_p = (L1-L0-0.002-0.002)/ch_sel_1 - 2*ac_th_for-gap 

        side1 = ch_bredth_p
        side2 = height-ac_th_up-air_vent-gap_height
        count = 0

        for face in facecollection:
            if round(float(face.getArea()),4) == round(side1*side2,4):
                #print(str(round(face.getArea(),4))+"first check " + str(round(height*width,4)))
                #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))
                if count == 0:

                    if round(float(face.getCentroid().getY()),4) == round(-ch_width/2,4):
                        count = 1
                        #print(str(face.getCentroid().getX())+ " second "+ str(bredth*(a+1)+gap*(a)-bredth/2))    
                        faceselection = str(face.id)
                        temp_X = float(face.getCentroid().getX())
                        temp_Y = float(face.getCentroid().getY())
                        temp_Z = float(face.getCentroid().getZ())
                    #print('face selection is: '+ faceselection)

                    #--------------------
        if faceselection == 'Null':
            raise TypeError("Face wasn't found")

        print(str(temp_X)+" "+str(temp_Y)+" "+str(temp_Z)+" face: "+str(faceselection))

        _target = apex.EntityCollection()
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        solid_1 = part_1.getSolid( name = sol_name )
        _target.append( solid_1 )
        _location = apex.Coordinate( temp_X, temp_Y, temp_Z )
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        solid_1 = part_1.getSolid( name = sol_name )
        _snapEntity = solid_1.getFace( id = int(faceselection) )
        result = apex.geometry.splitOnFeaturePlane(
            target = _target,
            location = _location,
            snapEntity = _snapEntity,
            splitBehavior = apex.geometry.GeometrySplitBehavior.Partition
        )

        #=======================================================
        #*****************************************************

        #                 CREATE MESH AND EXPORT

        #***********************************************************
        #========================================================

        _target = apex.EntityCollection()
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        allSol = getAllSolids()
        sol_name = str(allSol[0].name)
        #--------------------
        part_2 = apex.getPart( pathName = "Model/Part 1" )

        solid_1 = part_2.getSolid( name = sol_name )

        _target.append( solid_1 )
        _SweepFace = apex.EntityCollection()
        result = apex.mesh.createHexMesh(
            name = "",
            target = _target,
            meshSize = meshing_size,
            surfaceMeshMethod = apex.mesh.SurfaceMeshMethod.Auto,
            mappedMeshDominanceLevel = 2,
            elementOrder = apex.mesh.ElementOrder.Linear,
            refineMeshUsingCurvature = False,
            elementGeometryDeviationRatio = 0.10,
            elementMinEdgeLengthRatio = 0.20,
            createFeatureMeshOnWashers = False,
            createFeatureMeshOnArbitraryHoles = False,
            preserveWasherThroughMesh = True,
            sweepFace = _SweepFace,
            hexMeshMethod = apex.mesh.HexMeshMethod.Auto,
            projectMidsideNodesToGeometry = True
        )
        #**************************EXPORT************
        mesh1 = apex.getMesh( pathName = "Model/Part 1/Mesh 1" )
        mesh1.exportFEModel(
            filename = "C:/Users/18507522/Downloads/SB/Mesh/Mesh1.bdf",
            unitSystem = "m-kg-s-N-K",
            exportWideFormat = False,
            exportHierarchicalFiles = False,
            resultOutputType = apex.attribute.NastranResultOutputType.Hdf5,
            renumberMethod = apex.attribute.ExportRenumberMethod.Internal,
            apexEngineeringAbstractions = False,
         )

        model = apex.currentModel()
        model = model.close()

        #========================================
        #****************************************

        #                  Meshing 2 #TagSB

        #****************************************
        #========================================

        model_1 = apex.currentModel()
        def doSketch_1():
            part_1 = model_1.getCurrentPart()
            if part_1 is None:
                part_1 = model_1.createPart()
            sketch_1 = part_1.createSketchOnGlobalPlane(
                name = 'Sketch 1',
                plane = apex.construct.GlobalPlane.XY,
                alignSketchViewWithViewport = True
            )

            rectangle_1 = sketch_1.createRectangle2Point(
                name = "Rectangle 1",
                location = Point2D( Origin_start-2e-3, width/2 ),
                diagonal = Point2D( L3+2e-3, -width/2 )
            )

            return sketch_1.completeSketch( fillSketches = True )

        newbodies = doSketch_1()
        print(type(newbodies))

        for body in newbodies:
            print(body.name)
            newSurf = body
            break    

        _target = apex.EntityCollection()

        surfFaces = newSurf.getFaces()
        for iface in surfFaces:
            _target.append(iface)
        #pushpull
        pushpull = apex.geometry.pushPull(
            target = _target,
            method = apex.geometry.PushPullMethod.Normal,
            behavior = apex.geometry.PushPullBehavior.Extrude,
            removeInnerLoops = False,
            createBooleanUnion = False,
            distance = 2e-3+paper_width,
            direction = [ 0, 0.0, -1.0 ] )
        model_1 = apex.currentModel()
        def doSketch_1():
            part_1 = model_1.getCurrentPart()
            if part_1 is None:
                part_1 = model_1.createPart()
            sketch_1 = part_1.createSketchOnGlobalPlane(
                name = 'Sketch 1',
                plane = apex.construct.GlobalPlane.XY,
                alignSketchViewWithViewport = True
            )

            rectangle_1 = sketch_1.createRectangle2Point(
                name = "Rectangle 1",
                location = Point2D( Origin_start-2e-3, width/2 ),
                diagonal = Point2D( L3+2e-3, -width/2 )
            )

            return sketch_1.completeSketch( fillSketches = True )

        newbodies = doSketch_1()
        print(type(newbodies))

        for body in newbodies:
            print(body.name)
            newSurf = body
            break    

        _target = apex.EntityCollection()

        surfFaces = newSurf.getFaces()
        for iface in surfFaces:
            _target.append(iface)
        #pushpull
        pushpull = apex.geometry.pushPull(
            target = _target,
            method = apex.geometry.PushPullMethod.Normal,
            behavior = apex.geometry.PushPullBehavior.Extrude,
            removeInnerLoops = False,
            createBooleanUnion = False,
            distance = 2e-3,
            direction = [ 0, 0.0, -1.0 ] )

        _target = apex.EntityCollection()
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        allSol = getAllSolids()
        sol_name = str(allSol[0].name)
        #--------------------
        part_2 = apex.getPart( pathName = "Model/Part 1" )
        solid_1 = part_2.getSolid( name = sol_name )

        _target.append( solid_1 )
        _SweepFace = apex.EntityCollection()
        result = apex.mesh.createHexMesh(
            name = "",
            target = _target,
            meshSize = meshing_size,
            surfaceMeshMethod = apex.mesh.SurfaceMeshMethod.Auto,
            mappedMeshDominanceLevel = 2,
            elementOrder = apex.mesh.ElementOrder.Linear,
            refineMeshUsingCurvature = False,
            elementGeometryDeviationRatio = 0.10,
            elementMinEdgeLengthRatio = 0.20,
            createFeatureMeshOnWashers = False,
            createFeatureMeshOnArbitraryHoles = False,
            preserveWasherThroughMesh = True,
            sweepFace = _SweepFace,
            hexMeshMethod = apex.mesh.HexMeshMethod.Auto,
            projectMidsideNodesToGeometry = True
        )

        mesh1 = apex.getMesh( pathName = "Model/Part 1/Mesh 1" )
        mesh1.exportFEModel(
            filename = "C:/Users/18507522/Downloads/SB/Mesh/Mesh2.bdf",
            unitSystem = "m-kg-s-N-K",
            exportWideFormat = False,
            exportHierarchicalFiles = False,
            resultOutputType = apex.attribute.NastranResultOutputType.Hdf5,
            renumberMethod = apex.attribute.ExportRenumberMethod.Internal,
            apexEngineeringAbstractions = False,
         )

        model = apex.currentModel()
        model = model.close()

        #========================================
        #****************************************

        #                  Meshing3 # TagSB

        #****************************************
        #========================================

        model_1 = apex.currentModel()
        def doSketch_1():
            part_1 = model_1.getCurrentPart()
            if part_1 is None:
                part_1 = model_1.createPart()
            sketch_1 = part_1.createSketchOnGlobalPlane(
                name = 'Sketch 1',
                plane = apex.construct.GlobalPlane.XY,
                alignSketchViewWithViewport = True
            )

            rectangle_1 = sketch_1.createRectangle2Point(
                name = "Rectangle 1",
                location = Point2D( Origin_start-2e-3, width/2 ),
                diagonal = Point2D( L3+2e-3, -width/2 )
            )

            return sketch_1.completeSketch( fillSketches = True )

        newbodies = doSketch_1()
        print(type(newbodies))

        for body in newbodies:
            print(body.name)
            newSurf = body
            break    

        _target = apex.EntityCollection()

        surfFaces = newSurf.getFaces()
        for iface in surfFaces:
            _target.append(iface)
        #pushpull
        pushpull = apex.geometry.pushPull(
            target = _target,
            method = apex.geometry.PushPullMethod.Normal,
            behavior = apex.geometry.PushPullBehavior.Extrude,
            removeInnerLoops = False,
            createBooleanUnion = False,
            distance = 2e-3+paper_width+2e-3,
            direction = [ 0, 0.0, -1.0 ] )
        model_1 = apex.currentModel()
        def doSketch_1():
            part_1 = model_1.getCurrentPart()
            if part_1 is None:
                part_1 = model_1.createPart()
            sketch_1 = part_1.createSketchOnGlobalPlane(
                name = 'Sketch 1',
                plane = apex.construct.GlobalPlane.XY,
                alignSketchViewWithViewport = True
            )

            rectangle_1 = sketch_1.createRectangle2Point(
                name = "Rectangle 1",
                location = Point2D( L0, width/2 ),
                diagonal = Point2D( L3+2e-3, -width/2 )
            )

            return sketch_1.completeSketch( fillSketches = True )

        newbodies = doSketch_1()
        print(type(newbodies))

        for body in newbodies:
            print(body.name)
            newSurf = body
            break    

        _target = apex.EntityCollection()

        surfFaces = newSurf.getFaces()
        for iface in surfFaces:
            _target.append(iface)
        #pushpull
        pushpull = apex.geometry.pushPull(
            target = _target,
            method = apex.geometry.PushPullMethod.Normal,
            behavior = apex.geometry.PushPullBehavior.Extrude,
            removeInnerLoops = False,
            createBooleanUnion = False,
            distance = 2e-3+paper_width,
            direction = [ 0, 0.0, -1.0 ] )

        _target = apex.EntityCollection()
        part_1 = apex.getPart( pathName = "Model/Part 1" )
        allSol = getAllSolids()
        sol_name = str(allSol[0].name)
        #--------------------
        part_2 = apex.getPart( pathName = "Model/Part 1" )

        solid_1 = part_2.getSolid( name = sol_name )

        _target.append( solid_1 )
        _SweepFace = apex.EntityCollection()
        result = apex.mesh.createHexMesh(
            name = "",
            target = _target,
            meshSize = meshing_size,
            surfaceMeshMethod = apex.mesh.SurfaceMeshMethod.Auto,
            mappedMeshDominanceLevel = 2,
            elementOrder = apex.mesh.ElementOrder.Linear,
            refineMeshUsingCurvature = False,
            elementGeometryDeviationRatio = 0.10,
            elementMinEdgeLengthRatio = 0.20,
            createFeatureMeshOnWashers = False,
            createFeatureMeshOnArbitraryHoles = False,
            preserveWasherThroughMesh = True,
            sweepFace = _SweepFace,
            hexMeshMethod = apex.mesh.HexMeshMethod.Auto,
            projectMidsideNodesToGeometry = True
        )
        mesh1 = apex.getMesh( pathName = "Model/Part 1/Mesh 1" )
        mesh1.exportFEModel(
            filename = "C:/Users/18507522/Downloads/SB/Mesh/Mesh3.bdf",
            unitSystem = "m-kg-s-N-K",
            exportWideFormat = False,
            exportHierarchicalFiles = False,
            resultOutputType = apex.attribute.NastranResultOutputType.Hdf5,
            renumberMethod = apex.attribute.ExportRenumberMethod.Internal,
            apexEngineeringAbstractions = False,
         )
        model = apex.currentModel()
        model = model.close()

        # ***************************************ApexEnd*****************************************
        #=========================================================================================

        d = %run Marc_Final_InProgress_04_11_OJoint.ipynb
        process_wait = subprocess.Popen(r'C:\Users\18507522\Downloads\SB\CODE\final_con.proc',shell =  True,bufsize=2048)
        process_wait.wait()
        time.sleep(5)


        print('***mfff***')
        sts = r'C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Marc\Model1_job1.sts'
        text = pd.read_csv(sts, header=None, skipinitialspace=True, sep=' ', skiprows=9, keep_default_na=False)
        a = len(text)


        # Opening the file with append mode
        file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\exitcode.txt", "a")
        content = text.iloc[a-1-2,6]+'\n'
        file.write(content)
        file.close()

        #-------------------------
        sts = r'C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Marc\MCP'
        text = pd.read_csv(sts, header=None, skipinitialspace=True, sep=' ', skiprows=9, keep_default_na=False)

        # Opening the file with append mode
        file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\mcp_t.txt", "a")
        content = str(text.values[len(text)-1,0])+'\n'
        file.write(content)
        file.close()

        file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\mcp_rot.txt", "a")
        content = str(text.values[len(text)-1,1])+'\n'
        file.write(content)
        file.close()
        mcp_obj = text.values[len(text)-1,1]

        sts = r'C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Marc\PIP'
        text = pd.read_csv(sts, header=None, skipinitialspace=True, sep=' ', skiprows=9, keep_default_na=False)

        # Opening the file with append mode
        file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\pip_t.txt", "a")
        content = str(text.values[len(text)-1,0])+'\n'
        file.write(content)
        file.close()

        file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\pip_rot.txt", "a")
        content = str(text.values[len(text)-1,1])+'\n'
        file.write(content)
        file.close()
        pip_obj = text.values[len(text)-1,1]

        sts = r'C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Marc\DIP'
        text = pd.read_csv(sts, header=None, skipinitialspace=True, sep=' ', skiprows=9, keep_default_na=False)

        # Opening the file with append mode
        file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\dip_t.txt", "a")
        content = str(text.values[len(text)-1,0])+'\n'
        file.write(content)
        file.close()

        file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\dip_rot.txt", "a")
        content = str(text.values[len(text)-1,1])+'\n'
        file.write(content)
        file.close()
        dip_obj = text.values[len(text)-1,1]
        #---------------------------
        
        # Directory
        directory = "data" + str(int(count_out))

        # Parent Directory path
        parent_dir = r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Data"

        # Path
        path = os.path.join(parent_dir, directory)

        # Create the directory
        # 'Nikhil'
        try:
            os.makedirs(path, exist_ok = True)
            print("Directory '%s' created successfully" % directory)
        except OSError as error:
            print("Directory '%s' can not be created" % directory)
        #***************************************************
        #**********************************************
        # importing required packages
        
        # defining source and destination
        # paths
        src = r'C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Marc'
        trg = r'C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Data\data'+str(int(count_out))

        files=os.listdir(src)

        # iterating over all the files in
        # the source directory
        for fname in files:

            # copying the files to the
            # destination directory
            shutil.copy2(os.path.join(src,fname), trg)
        #************************************************
        print(trg)

        
        folder = r'C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Marc'
        for filename in os.listdir(folder):
            file_path = os.path.join(folder, filename)
            try:
                if os.path.isfile(file_path) or os.path.islink(file_path):
                    os.unlink(file_path)
                elif os.path.isdir(file_path):
                    shutil.rmtree(file_path)
            except Exception as e:
                print('Failed to delete %s. Reason: %s' % (file_path, e))

        
        
        #===========================

        obj.value = math.sqrt(((mcp_obj-4*2*math.pi/360)**2+(pip_obj-10*2*math.pi/360)**2+ (dip_obj-6*2*math.pi/360)**2)/3)
        file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\obj_val.txt", "a")
        content = str(obj.value)+'\n'
        file.write(content)
        file.close()
        print(obj.value)
        print('***2***')
    else:
        print('quite')
        h = x[0]
        w = x[1]
        d = x[2]

        # Evaluate the objective function value and use the ".value" notation to
        # update this new value in the calling function, which is DOT in this
        # case
        obj.value = 2.0*(h*w+h*d+2.0*w*d) + 1.25*h/12.0

        

    # Evaluate the constraints and update the constraint vector.  Since this 
    # is a numpy object, the values will be updated in the calling function
    #g[0] = 1.0 - h*w*d/2.

    return


#------------------------------------------------------------------------------
# The main code that setup the optimization problem and calls DOT to solve the
# problem
flag = 0
ccde = 0
#------------------------------------------------------------------------------
nDvar = 3  # Number of design variables
nCons = 0  # Number of constraints

# Create numpy arrays for the initial values and lower and upper bounds of the
# design variables
x  = nm.empty(nDvar, float)
xl = nm.empty(nDvar, float)
xu = nm.empty(nDvar, float)

# Set the initial values and upper and lower bounds for the design variables
x[0]  = 2.0
xl[0] = 1.0
xu[0] = 4.665

x[1]  = 2.0
xl[1] = 1.0
xu[1] = 3.832

x[2]  = 2.0
xl[2] = 1.0
xu[2] = 2.5

remoting.launchApplication()
# Initialize the DOT wrapper - this will load the shared library
aDot = dot.dot()

# Set some of the DOT parameters
# page 24
aDot.nPrint   = 3
aDot.nMethod  = 2

# Set the function to call for evaluating the objective function and constraints
aDot.evaluate = myEvaluate

# Call DOT to perform the optimization
dotRet = aDot.dotcall(x, xl, xu, nCons)

remoting.shutdownApplication()
# Print the DOT return values, this will be the final Objective function value,
# the worst constaint value at the optimum and the optimum design variable 
# values.  This is returned as a numpy array.
print( 'Final, optimum results from DOT:' )
print( dotRet )
print("done")
# Out:
# 1.0
# ***1***
# 2.0
# 2.0
# 2.0
# ***a***
# 0.008999999999999998
# 0.008999999999999998
# 2
# 0.0
# 0.14285714285714288
# 0.7857142857142856
# 0.9285714285714285
# <class 'apex.EntityCollection'>
# nothing
# <class 'apex.EntityCollection'>
# <class 'apex.EntityCollection'>
# <class 'apex.EntityCollection'>
# 0.0065
# 2
# 0.0
# 0.17391304347826086
# 0.7391304347826088
# 0.9130434782608695
# <class 'apex.EntityCollection'>
# nothing
# <class 'apex.EntityCollection'>
# <class 'apex.EntityCollection'>
# <class 'apex.EntityCollection'>
# 0.002500000000000003
# 2
# 0.0
# 0.26666666666666655
# 0.6000000000000002
# 0.8666666666666667
# <class 'apex.EntityCollection'>
# a
# 0.065
# nothing
# <class 'apex.EntityCollection'>
# []
# <class 'apex.EntityCollection'>
# <class 'apex.EntityCollection'>
# <class 'apex.EntityCollection'>
# <class 'apex.EntityCollection'>
# o:0.00024
# d:0.00024
#
# o:0.00024
# d:0.00024
#
# o:0.00024
# d:0.00024
#
# o:0.00024
# d:0.00024
#
# o:0.00024
# d:0.00024
#
# ...

# %%
# print('***mfff***')
# sts = r'C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Marc\Model1_job1.sts'
# text = pd.read_csv(sts, header=None, skipinitialspace=True, sep=' ', skiprows=9, keep_default_na=False)
# a = len(text)


# # Opening the file with append mode
# file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\exitcode.txt", "a")
# content = text.iloc[a-1-2,6]+'\n'
# file.write(content)
# file.close()

# #-------------------------
# sts = r'C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Marc\MCP'
# text = pd.read_csv(sts, header=None, skipinitialspace=True, sep=' ', skiprows=9, keep_default_na=False)

# # Opening the file with append mode
# file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\mcp_t.txt", "a")
# content = str(text.values[len(text)-1,0])+'\n'
# file.write(content)
# file.close()

# file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\mcp_rot.txt", "a")
# content = str(text.values[len(text)-1,1])+'\n'
# file.write(content)
# file.close()
# mcp_obj = text.values[len(text)-1,1]

# sts = r'C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Marc\PIP'
# text = pd.read_csv(sts, header=None, skipinitialspace=True, sep=' ', skiprows=9, keep_default_na=False)

# # Opening the file with append mode
# file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\pip_t.txt", "a")
# content = str(text.values[len(text)-1,0])+'\n'
# file.write(content)
# file.close()

# file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\pip_rot.txt", "a")
# content = str(text.values[len(text)-1,1])+'\n'
# file.write(content)
# file.close()
# pip_obj = text.values[len(text)-1,1]

# sts = r'C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Marc\DIP'
# text = pd.read_csv(sts, header=None, skipinitialspace=True, sep=' ', skiprows=9, keep_default_na=False)

# # Opening the file with append mode
# file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\dip_t.txt", "a")
# content = str(text.values[len(text)-1,0])+'\n'
# file.write(content)
# file.close()

# file = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\ResultsSQP\dip_rot.txt", "a")
# content = str(text.values[len(text)-1,1])+'\n'
# file.write(content)
# file.close()
# dip_obj = text.values[len(text)-1,1]
# #---------------------------

# # Directory
# directory = "data" + str(int(count))

# # Parent Directory path
# parent_dir = r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Data"

# # Path
# path = os.path.join(parent_dir, directory)

# # Create the directory
# # 'Nikhil'
# try:
#     os.makedirs(path, exist_ok = True)
#     print("Directory '%s' created successfully" % directory)
# except OSError as error:
#     print("Directory '%s' can not be created" % directory)
# #***************************************************
# #**********************************************
# # importing required packages

# # defining source and destination
# # paths
# src = r'C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Marc'
# trg = r'C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Data\data'+str(int(count))

# files=os.listdir(src)

# # iterating over all the files in
# # the source directory
# for fname in files:

#     # copying the files to the
#     # destination directory
#     shutil.copy2(os.path.join(src,fname), trg)
# #************************************************
# print(trg)


# folder = r'C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Marc'
# for filename in os.listdir(folder):
#     file_path = os.path.join(folder, filename)
#     try:
#         if os.path.isfile(file_path) or os.path.islink(file_path):
#             os.unlink(file_path)
#         elif os.path.isdir(file_path):
#             shutil.rmtree(file_path)
#     except Exception as e:
#         print('Failed to delete %s. Reason: %s' % (file_path, e))



# #===========================

# val = math.sqrt(((mcp_obj-4*2*math.pi/360)**2+(pip_obj-10*2*math.pi/360)**2+ (dip_obj-6*2*math.pi/360)**2)/3)

# %% [markdown]
# # Run Apex

# %% [markdown]
# # Run Mark

# %%
# d = %run Marc_Final_InProgress_04_11_OJoint.ipynb
# process_wait = subprocess.Popen(r'C:\Users\18507522\Downloads\SB\CODE\final_con.proc',shell =  True,bufsize=2048)
# process_wait.wait()
# time.sleep(5)
# Out:
# nothing
# nothing
# nothing
# nothing
# *select_method_user_box
# *select_filter_surface
# *select_faces -0.0025 0.0005 -0.0075 0.0075 -0.0005 0.0135
# *select_method_user_box
# *select_filter_surface
# *select_faces 0.0045 0.0075 -0.0075 0.0075 -0.0005 0.0135
# *select_method_user_box
# *select_filter_surface
# *select_faces 0.0115 0.0145 -0.0075 0.0075 -0.0005 0.0135
# *select_method_user_box
# *select_filter_surface
# *select_faces 0.0185 0.0215 -0.0075 0.0075 -0.0005 0.0135
# *select_method_user_box
# *select_filter_surface
# *select_faces 0.0285 0.031071 -0.0075 0.0075 -0.0005 0.0135
# *select_method_user_box
# *select_filter_surface
# *select_faces 0.035071 0.037643 -0.0075 0.0075 -0.0005 0.0135
# *select_method_user_box
# *select_filter_surface
# *select_faces 0.041643 0.044214 -0.0075 0.0075 -0.0005 0.0135
# *select_method_user_box
# *select_filter_surface
# *select_faces 0.048214 0.0505 -0.0075 0.0075 -0.0005 0.0135
# *select_method_user_box
# *select_filter_surface
# ...

# %%
process_wait = subprocess.Popen(r'C:\Users\18507522\Downloads\SB\CODE\Apex_Final_18507522_04_11_OJoint_Cor.py',shell =  True,bufsize=2048)
process_wait.wait()
time.sleep(5)

# %% [markdown]
# # Create and folder

# %%
# # create new folder to store files
# #***************************************************
# count = 1
# # Directory
# directory = "data" + str(int(count))
  
# # Parent Directory path
# parent_dir = r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Data"
  
# # Path
# path = os.path.join(parent_dir, directory)
  
# # Create the directory
# # 'Nikhil'
# try:
#     os.makedirs(path, exist_ok = True)
#     print("Directory '%s' created successfully" % directory)
# except OSError as error:
#     print("Directory '%s' can not be created" % directory)
# #***************************************************
# Out:
# Directory 'data1' created successfully

# %%
# #**********************************************
# # importing required packages
# from pathlib import Path
# import shutil
# import os
# count = 1
# # defining source and destination
# # paths
# src = r'C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Marc'
# trg = r'C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Data\data'+str(int(count))
 
# files=os.listdir(src)
 
# # iterating over all the files in
# # the source directory
# for fname in files:
     
#     # copying the files to the
#     # destination directory
#     shutil.copy2(os.path.join(src,fname), trg)
# #************************************************
# print(trg)
# Out:
# C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Data\data1

# %%
# import os, shutil
# folder = r'C:\Users\18507522\Downloads\SB\CODE\FinalOpt\Marc'
# for filename in os.listdir(folder):
#     file_path = os.path.join(folder, filename)
#     try:
#         if os.path.isfile(file_path) or os.path.islink(file_path):
#             os.unlink(file_path)
#         elif os.path.isdir(file_path):
#             shutil.rmtree(file_path)
#     except Exception as e:
#         print('Failed to delete %s. Reason: %s' % (file_path, e))

# %%
#     else:
#         time.sleep(25)
#         file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\c1.txt","r")
#         c1 = float(file1.read())
#         file1.close()
#         file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\c2.txt","r")
#         c2 = float(file1.read())
#         file1.close()
#         file1 = open(r"C:\Users\18507522\Downloads\SB\CODE\FinalOpt\c3.txt","r")
#         c3 = float(file1.read())
#         file1.close()
#         obj.value = 0
