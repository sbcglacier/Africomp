# %% [markdown]
# # This code was written to generate the proc files which should be used to automate the prceedure for 2D FEA mesh creation of the finger-actuator setup aimed at achieveing TGE

# %%
# This selects the finger to be the mean dimensions
selg = 6

# %%
import math as math
import numpy as np
import os
import subprocess
import pandas as pd
import csv
import sys
import time
from pathlib import Path
import shutil
from textwrap import dedent
import os

# %% [markdown]
# Note: just run -> mentat -pr testing.proc -bg
#
# C:\Users\18507522\FinalSBSpring\CODE

# %%
import os

os.getcwd()
ob_path = os.getcwd()
# This section of code is to 
if not os.path.isdir(ob_path+"\\CODE"):
    
    # if the demo_folder2 directory is 
    # not present then create it.
    os.makedirs(ob_path+"\\CODE")
    
root_dir = ob_path+"\\CODE"

# code creates the folder ExampleResultsforMarc
if not os.path.isdir(ob_path+"\\CODE\\ExampleResultsForMarc"):
    
    # if the demo_folder2 directory is 
    # not present then create it.
    os.makedirs(ob_path+"\\CODE\\ExampleResultsForMarc")

# %%
# specify the spring values 
f_names = ["_DPLP","_DMLP","_Lm","_DPLM","_Dm","","_DMM","_DMLM","_LMM"]
r1x = [0.0582,0.085,0.0375,0.043,0.0641,0.0485,0.0465,0.0412,0.0793]
r2x = [0.028,0.0305,0.0196,0.0226,0.0251,0.0252,0.0253,0.0198,0.0309]
r3x = [0.0036,0.0033,0.0023,0.0028,0.0026,0.003,0.0033,0.0021,0.0037]

#1 D+L+,2*D-L+, 3>Lm, 4>D+L-, 5>Dm, 6>O, 7>D-L+, 8>DM, 9>D-L-, 10>LM,  
# SELECT THE VAR USING selg!!!!


mcp_sp = r1x[selg-1]

pip_sp = r2x[selg-1]

dip_sp = r3x[selg-1]

# %%
file = pd.read_csv(root_dir+"\\"+"Fing_points"+f_names[selg-1]+".txt", sep=',',header=None)
file2 = pd.read_csv(root_dir+"\\"+"Bone_points"+f_names[selg-1]+".txt", sep=',',header=None)

# %%
# Setting up the code
#====================
if 1 == 1:
    os.getcwd()
    ob_path = os.getcwd()
    # This section of code is to 
    # -------------create CODE -------------------
    if not os.path.isdir(ob_path+"\\CODE"):

        # if the demo_folder2 directory is 
        # not present then create it.
        os.makedirs(ob_path+"\\CODE")

    root_dir = ob_path+"\\CODE"

    #--------------create CODE/FinalOpt ----------------
    if not os.path.isdir(root_dir+"\\FinalOpt"):

        # if the demo_folder2 directory is 
        # not present then create it.
        os.makedirs(root_dir+"\\FinalOpt")

    #--------------create CODE/FinalOpt/Results_Opt  ----------------
    if not os.path.isdir(root_dir+"\\FinalOpt\\Results_Opt"):

        # if the demo_folder2 directory is 
        # not present then create it.
        os.makedirs(root_dir+"\\FinalOpt\\Results_Opt")

    #--------------part creates the MARC folder for proc folder --------------
    if not os.path.isdir(root_dir+"\\FinalOpt\\Marc"):

        # if the demo_folder2 directory is 
        # not present then create it.
        os.makedirs(root_dir+"\\FinalOpt\\Marc")
        
    # ran 3
    # NOTE THIS WAS TO TRY AND DELETE:
    # creates folder if it doesnt exist then deletes content inside
    if not os.path.isdir(root_dir+"\\APEX"):

        os.makedirs(root_dir+"\\APEX")

    folder = root_dir + "\\APEX"
            
    file1 = open(root_dir+"\\"+"gap_height.txt","r")
    gap_height = float(file1.read())
    file1.close()

    file1 = open(root_dir+"\\"+"meshing_size.txt","r")
    meshing_size = float(file1.read())
    file1.close()

    file1 = open(root_dir+"\\"+"ch_var1.txt","r")
    ch_var1 = float(file1.read())
    file1.close()

    file1 = open(root_dir+"\\"+"ch_var2.txt","r")
    ch_var2 = float(file1.read())
    file1.close()

    file1 = open(root_dir+"\\"+"ch_var3.txt","r")
    ch_var3 = float(file1.read())
    file1.close()
    
    file1 = open(root_dir+"\\"+"ch_var4.txt","r")
    ch_var4 = float(file1.read())
    file1.close()

    file1 = open(root_dir+"\\"+"paper_width.txt","r")
    paper_width = float(file1.read())
    file1.close()

    file1 = open(root_dir+"\\"+"width.txt","r")
    width = float(file1.read())
    file1.close()

    file1 = open(root_dir+"\\"+"height.txt","r")
    height = float(file1.read())
    file1.close()

    file1 = open(root_dir+"\\"+"bredth.txt","r")
    bredth = float(file1.read())
    file1.close()

    file1 = open(root_dir+"\\"+"no_ch.txt","r")
    no_ch = int(file1.read())
    file1.close()

    file1 = open(root_dir+"\\"+"ac_th_up.txt","r")
    ac_th_up = float(file1.read())
    file1.close()

    file1 = open(root_dir+"\\"+"ac_th_side.txt","r")
    ac_th_side = float(file1.read())
    file1.close()

    file1 = open(root_dir+"\\"+"ac_th_for.txt","r")
    ac_th_for = float(file1.read())
    file1.close()

    file1 = open(root_dir+"\\"+"gap.txt","r")
    gap = float(file1.read())
    file1.close()

    file1 = open(root_dir+"\\"+"air_vent.txt","r")
    air_vent = float(file1.read())
    file1.close()

    file1 = open(root_dir+"\\"+"gap_height.txt","r")
    gap_height = float(file1.read())
    file1.close()

    file1 = open(root_dir+"\\"+"ends_ext.txt","r")
    ends_ext = float(file1.read())
    file1.close()
    
    SL0 = file[1][0]
    SL1 = file[1][3]
    SL2 = file[1][6]
    SL3 = file[1][9]
    SL4 = file[1][15]

    file1 = open(root_dir+"\\"+"meshsize.txt","r")
    meshsize = float(file1.read())
    file1.close()

    file1 = open(root_dir+"\\"+"above_paper.txt","r")
    above_paper = float(file1.read())
    file1.close()

    file1 = open(root_dir+"\\"+"below_paper.txt","r")
    below_paper = float(file1.read())
    file1.close()

    ch_width = width-2*ac_th_side
    ch_height = height-ac_th_up
    
    # Negative because -y-axis is along the length in opensim but positive x here
    TL0 = -SL0
    TL1 = -SL1
    TL2 = -SL2
    TL3 = -SL3
    TL4 = -SL4
    
    # want to extend the fingers a little bit
    L_ext = (-SL4)-(-SL3)
    
    # ["_DPLP","_DMLP","_Lm","_DPLM","_Dm","","_DMM","_DMLM","_LMM"]
    L_matlab_1 = [0.02168,0.02168,0.01594,0.01693,0.0193,0.0193,0.0193,0.01693,0.02267]
    L_matlab_2 = [0.08769,0.08769,0.06694,0.07042,0.07929,0.07929,0.07929,0.07042,0.0907]
    L_matlab_3 = [0.04853,0.04853,0.03537,0.03763,0.04308,0.04308,0.04308,0.03763,0.0508]
    L_matlab_4 = [0.03612,0.03612,0.02596,0.02769,0.03191,0.03191,0.03191,0.02769,0.03785]
    
    # Get these variables from line 181
    L_arc1 = L_matlab_1[selg-1]*4
    L_arc2 = L_matlab_2[selg-1]
    L_arc3 = L_matlab_3[selg-1]
    L_arc4 = L_matlab_4[selg-1]
    
    L_arc_tot = L_arc1+L_arc2+L_arc3+L_arc4
    
    #actuator lengths
    L3 = TL0 + (11+7+5)*7.88e-3  -7*7.88e-3
    L2 = L3-5*7.88e-3
    L1 = L2-7*7.88e-3
    L0 = L1-11*7.88e-3
    L4 = L3+ 8*7.88e-3 +2e-3
    
    cmc_offset = TL0-L0
#====================

# Setting variable definition:
#=============================
#=============================
# Use gravity flag
use_gravity_flag = 0

# If you want to include the elastic strap keeping the actuator fixed at the end
elastic_wrist = 1

# if you want the start of the actuator with sliding contact to be longer and not jump around
extra_ac_start_straight = 1

# If you want to change from default contact to considering an automatic way set equal to 1
auto_contact = 1

# make this zero if you want the end block just to be ends extend length
block_more = ends_ext*3.1

# flag to cut contact segments at the end
cut_contact_ends_flag = 1

# Flag determines whether I use spring tables or values
spring_tab_flag = 0

# flag to include or remove the CMC section of actuator (1 is remove)
remove_cmc_flag = 0

# Setting variables planar:
planar_flag = 1 # 1 is activate 0 is remove

# setting to turn off or on below actuator
below_actuator_flag = 1

# height of actuator for extension
xFlex_height = height#height/2.4

# start point for bottom actuator
R_d = -above_paper-paper_width-below_paper

# sets how much thinner bottom actuators need to be
thin = 0.0005

# So this flag determines if you are using consistent or smaller
ext_chambers_smaller_flag = 0 # 1 is make smaller 0 is make symmetric

# Contact tolerance scale factor
contact_tol_scale_factor = 1# default is 1

# Penalty scale factor
penalty_scale_factor = 10

solver = "mumps" # its either mumps or pardiso
#=============================

# normally use RBEs to constrain joint but if you want to remove make 0
rbe_joint_flag = 1 # was 0

# If not going  to use RBE define the spring stiffness limiting Tx Ty
joint_spring_stiffness = 1e7

# if the res_disp_flag_and_or = 0 then it will be 'and' if set to 1 it will be 'or'
res_disp_and_or_flag = 0

# defines whether to use linear or mooney flesh material parameters
flesh_nonlinear_flag = 0

if res_disp_and_or_flag == 1:
    res_disp_and_or = 'or'
else:
    res_disp_and_or = 'and'
    
# setting tolerance convergence 
con_tol_res = 0.03#0.03
con_tol_mom = 0.03

con_tol_dis = 0.03
con_tol_rot = 0.03
#if you want to not include moment and rot set this flag to 0
rot_mom_yes_flag = 1

# Selecting either Smooth-Sil 950 (option 0) or Moldstar 15 (option 1)
Moon_or_Ogden = 1 # 1 for mooney 2 for ogden
Sil_option = 1

bulk_auto_flag = 1 #(1 = use defined bulk values; 0 ignore and use auto)

# Setting silicon material parameters
if Moon_or_Ogden ==1:
    if Sil_option ==1:
        Sil_name = "Mooney"
        Sil_Mooney_C10 = 36428.1
        Sil_Mooney_C01 = 18924.3
        Sil_Mooney_C20 = 3926.09
        density = 1139
        bulk = 119e3
    else:
        Sil_name = "Mooney"
        Sil_Mooney_C10 = 260567.62#-39898.2#
        Sil_Mooney_C01 = 97549.81#316617
        Sil_Mooney_C20 = 57500.69#24525.5
        density = 1211
        bulk = 679e3
else:
    if Sil_option ==1:
        Sil_name = "Ogden"
        Sil_Ogden_M1 = -6.503
        Sil_Ogden_E1 = -21.32
        Sil_Ogden_M2 = 0.2169e6
        Sil_Ogden_E2 = 1.18
        Sil_Ogden_M3 = 1.372e3
        Sil_Ogden_E3 = 4.884
        density = 1139
        bulk = 119e3
    else:
        Sil_name = "Ogden"
        Sil_Ogden_M1 =-0.3062e6
        Sil_Ogden_E1 =-3.059
        Sil_Ogden_M2 =0.0283e6
        Sil_Ogden_E2 =4.597
        Sil_Ogden_M3 =6.596e-3
        Sil_Ogden_E3 =17.69
        density = 1211
        bulk = 679e3
    
    
# I want to try create code to use Ogden Material model:

#*************        START         *************
fin_rad = file[2][4]-file[2][5]
finger_offset = 0.000
core_thread = 5
pressure = float(50000)#float(130000)
max_load_case = 0.01#0.02
min_load_case = 1e-5

#************* Parameters for Fingers from Matlab **************
CS = 0.9 # Im using Bazier curves set this value to be as close to a circle
MOS = R_d-xFlex_height-file[2][1] # Matlab offset 39 is 34

#===================Setting Pressures ======================
max_pressure = 234720

# Set the pressure values
pressure_ch1top = round(     73.74e3    ,1)
pressure_ch2top = round(     73.74e3     ,1)
pressure_ch3top = round(     73.94e3    ,1)
pressure_ch4top = round(     73.74e3     ,1)

pressure_ch1bot = round(    128.54e3    ,1)
pressure_ch2bot = round(    128.54e3   ,1)
pressure_ch3bot = round(    128.54e3    ,1)
pressure_ch4bot = round(    128.54e3   ,1)

# %% [markdown]
# # Determine where to find the spring tables

# %%
# The directory of the spring files
#dir_spring = r"C:\Users\18507522\Downloads\Sim_01_09"        # This is default
dir_spring = root_dir#r"F:"
# Names of the tables
MCP_spring_data_name = "NR_MCP_line_Ends_rev.txt"
PIP_spring_data_name = "NR_PIP_line_Ends.txt"
DIP_spring_data_name = "NR_DIP_line_Ends.txt"

MCP_spring_table = "\""+dir_spring+"\\"+MCP_spring_data_name+"\""
PIP_spring_table = "\""+dir_spring+"\\"+PIP_spring_data_name+"\""
DIP_spring_table = "\""+dir_spring+"\\"+DIP_spring_data_name+"\""
print(MCP_spring_table)
# Out:
# "C:\Users\18507522\FinalSBSpring\CODE\NR_MCP_line_Ends_rev.txt"

# %%
# Remember that Python uses index 0,1,2
# 0 is for the breadth, 1 is for the length (must consider -length as it needs to be reversed), 2 is for height
Fing_MCP_T = file[2][4] - file[2][3]
Fing_PIP_T = file[2][7]- file[2][6]
Fing_DIP_T = file[2][10]- file[2][9]
Fing_DP_End_T = file[2][13]- file[2][12]

Fing_MCP_B = file[2][3] - file[2][5]
Fing_PIP_B = file[2][6]- file[2][8]
Fing_DIP_B = file[2][9]- file[2][11]
Fing_DP_End_B = file[2][12]- file[2][14]

Bone_MCP_T = file2[2][4] - file2[2][3]
Bone_PIP_T = file2[2][7]- file2[2][6]
Bone_DIP_T = file2[2][10]- file2[2][9]
Bone_DP_End_T = file2[2][13]- file2[2][12]

Bone_MCP_B = file2[2][3] - file2[2][5]
Bone_PIP_B = file2[2][6]- file2[2][8]
Bone_DIP_B = file2[2][9]- file2[2][11]
Bone_DP_End_B = file2[2][12]- file2[2][14]

# %%
print(ch_var1)
print(ch_var2)
print(ch_var3)
print(ch_var4)

ch_var1 = 10.619289
ch_var2 = 6.619289
ch_var3 = 4.619289
ch_var4 = 7.619289
# Out:
# 10.567397856162783
# 6.555084745762712
# 4.552972731336611
# 7.5404028943127726

# %% [markdown]
# ## Create Actuator
# * Creates actuator mesh

# %%
tmp = """"""
final = """"""
ch1_top = """"""
ch1_bot = """"""
ch2_top = """"""
ch2_bot = """"""
ch3_top = """"""
ch3_bot = """"""
ch4_top = """"""
ch4_bot = """"""
final = final + """
| Created by Marc Mentat 2021.4 (64bit)
*prog_option compatibility:prog_version:ment2021.4
*prog_analysis_class structural
*prog_use_current_job on
*set_default_length_unit meter
*set_model_length_unit meter
*theme dark
*set_save_formatted off *save_as_model \""""+root_dir+"""\\FinalOpt\\Marc\\Planar.mud\" yes
*change_directory "."
"""+root_dir+"""\\FinalOpt\\Marc

*set_undo off
*set_update off
*model_navigator_update off
*set_undo off
*set_model_analysis_dimension planar
*set_curve_type line
*prog_option geometry_and_mesh:mesh_cv_div_uniform:target_length
*prog_param geometry_and_mesh:mesh_cv_div_target_length """+str(round(meshing_size,10))+"""

"""
if remove_cmc_flag == 1:

    P_len = [L1,L2,L3,L4]
    chambers = [ch_var2,ch_var3,ch_var4]
    
elif remove_cmc_flag == 0:
    
    P_len = [L0,L1,L2,L3,L4]
    chambers = [ch_var1,ch_var2,ch_var3,ch_var4]

# =============Start of Ends_extend (additional support silicon layer at start and end of actuator) =====
if 1 == 1:
    LK = P_len[0]
    # first create ends extend at start
    #-------------------------------------------------------    
    tmp = tmp + """
    *add_points
    """ + str(round(LK-ends_ext,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
    """ + str(round(LK-ends_ext,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
    """
    # I counted 4 nodes now

    tmp = tmp + """
    *add_curves
    1 2 3 4 1 3 2 4
    """

    tmp = tmp+"""
    *apply_curve_divisions
    1 2 3 4
    #
    """

    tmp = tmp+ """
    *af_planar_quadmesh
    1 4 2 3
    #
    """

    tmp = tmp+"""
    *remove_curves
    all_existing
    *remove_points
    all_existing
    """

    #---------------------------------------------------------
    tmp = tmp + """
    *add_points
    """ + str(round(LK-ends_ext,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
    """ + str(round(LK-ends_ext,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
    """

    tmp = tmp + """
    *add_curves
    1 2 3 4 1 3 2 4
    """

    tmp = tmp+"""
    *apply_curve_divisions
    1 2 3 4
    #
    """

    tmp = tmp+ """
    *af_planar_quadmesh
    1 4 2 3
    #
    """

    tmp = tmp+"""
    *remove_curves
    all_existing
    *remove_points
    all_existing
    """
    #------------------------------------------------
    # tip section
    tmp = tmp + """
    *add_points
    """ + str(round(LK-ends_ext,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
    """ + str(round(LK-ends_ext,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""

    """

    tmp = tmp + """
    *add_curves
    1 2 3 4 1 3 2 4
    """

    tmp = tmp+"""
    *apply_curve_divisions
    1 2 3 4
    #
    """

    tmp = tmp+ """
    *af_planar_quadmesh
    1 4 2 3
    #
    """

    tmp = tmp+"""
    *remove_curves
    all_existing
    *remove_points
    all_existing
    """
    #============ above paper ==============
    tmp = tmp + """
    *add_points
    """ + str(round(LK-ends_ext,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
    """ + str(round(LK-ends_ext,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
    """
    # I counted 4 nodes now

    tmp = tmp + """
    *add_curves
    1 2 3 4 1 3 2 4
    """

    tmp = tmp+"""
    *apply_curve_divisions
    1 2 3 4
    #
    """

    tmp = tmp+ """
    *af_planar_quadmesh
    1 4 2 3
    #
    """

    tmp = tmp+"""
    *remove_curves
    all_existing
    *remove_points
    all_existing
    """
    #***************************paper***************************
    tmp = tmp + """
    *add_points
    """ + str(round(LK-ends_ext,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
    """ + str(round(LK-ends_ext,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
    """
    # I counted 4 nodes now

    tmp = tmp + """
    *add_curves
    1 2 3 4 1 3 2 4
    """

    tmp = tmp+"""
    *apply_curve_divisions
    1 2 3 4
    #
    """

    tmp = tmp+ """
    *af_planar_quadmesh
    1 4 2 3
    #
    """

    tmp = tmp+"""
    *remove_curves
    all_existing
    *remove_points
    all_existing
    """
    #***********************below paper silicon layer *************
    tmp = tmp + """
    *add_points
    """ + str(round(LK-ends_ext,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
    """ + str(round(LK-ends_ext,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
    """
    # I counted 4 nodes now

    tmp = tmp + """
    *add_curves
    1 2 3 4 1 3 2 4
    """

    tmp = tmp+"""
    *apply_curve_divisions
    1 2 3 4
    #
    """

    tmp = tmp+ """
    *af_planar_quadmesh
    1 4 2 3
    #
    """

    tmp = tmp+"""
    *remove_curves
    all_existing
    *remove_points
    all_existing
    """
    #***************************** below actuator ********************
    if below_actuator_flag == 1:

        tmp = tmp + """
    *add_points
    """ + str(round(LK-ends_ext,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
    """ + str(round(LK-ends_ext,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
        """
            # I counted 4 nodes now

        tmp = tmp + """
    *add_curves
    1 2 3 4 1 3 2 4
    """

        tmp = tmp+"""
    *apply_curve_divisions
    1 2 3 4
    #
    """

        tmp = tmp+ """
    *af_planar_quadmesh
    1 4 2 3
    #
    """

        tmp = tmp+"""
    *remove_curves
    all_existing
    *remove_points
    all_existing
    """
    #---------------------- creating next block -----------------------
        tmp = tmp + """
    *add_points
    """ + str(round(LK-ends_ext,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
    """ + str(round(LK-ends_ext,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
    """

        tmp = tmp + """
    *add_curves
    1 2 3 4 1 3 2 4
    """

        tmp = tmp+"""
    *apply_curve_divisions
    1 2 3 4
    #
    """

        tmp = tmp+ """
    *af_planar_quadmesh
    1 4 2 3
    #
    """

        tmp = tmp+"""
    *remove_curves
    all_existing
    *remove_points
    all_existing
    """
            #------------------------------------------------
            # tip section
        tmp = tmp + """
    *add_points
    """ + str(round(LK-ends_ext,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
    """ + str(round(LK-ends_ext,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""

    """

        tmp = tmp + """
    *add_curves
    1 2 3 4 1 3 2 4
    """

        tmp = tmp+"""
    *apply_curve_divisions
    1 2 3 4
    #
    """

        tmp = tmp+ """
    *af_planar_quadmesh
    1 4 2 3
    #
    """

        tmp = tmp+"""
    *remove_curves
    all_existing
    *remove_points
    all_existing
    
    """
    
    final = final +"\n"+ dedent(tmp).strip("\n")
    tmp = """"""
# =======================================================================================================

for seg in range(len(P_len)-1):
    LK = P_len[seg]
    
    # Determine the maximum number of chambers if larger fix values
    ch_sel_1 = chambers[seg]
    no_ch_max_1 = (P_len[seg+1]-P_len[seg]-ac_th_for-gap)/(2*ac_th_for+0.001+gap)
    if ch_sel_1>no_ch_max_1:
        ch_sel_1 = no_ch_max_1

    ch_depth = (P_len[seg+1]-P_len[seg]-ac_th_for-gap)/ch_sel_1 - 2*ac_th_for-gap

    num = math.floor(ch_sel_1)
    rem_n = round(ch_sel_1-num,6)
    print(rem_n)
    pointa = ac_th_for/(2*ac_th_for+ch_depth+gap)
    pointb = (ac_th_for+ch_depth)/(2*ac_th_for+ch_depth+gap)
    pointc = (ac_th_for*2+ch_depth)/(2*ac_th_for+ch_depth+gap)

    #====bellows====
    if 1==1:
        for cnt in range(num):
            OS = cnt*(2*ac_th_for+ch_depth+gap)
        #---------------------- creating next block -----------------------
        #----------now create from start of actuator:
            tmp = tmp + """
        
        *add_points
        """ + str(round(OS+LK,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
        """
        # I counted 4 nodes now

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        """

        #---------------------- creating next block -----------------------

            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
        """

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        """
        #------------------------------------------------
        # tip section
            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""

        """

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        """

        #*************************mid section**************************
        #ZXC3
        #------------------------------------------------

        # tip section
            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""


        """
            # adds to select chambers
            if seg == 0:
                ch1_top = ch1_top +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                ch1_top = ch1_top +"\n"+str(round(-ac_th_up*1.5,10))+" "+str(round(height-ac_th_up/2,10))
                ch1_top = ch1_top +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
            elif seg == 1:
                ch2_top = ch2_top +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                ch2_top = ch2_top +"\n"+str(round(-ac_th_up*1.5,10))+" "+str(round(height-ac_th_up/2,10))
                ch2_top = ch2_top +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
            elif seg == 2:
                ch3_top = ch3_top +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                ch3_top = ch3_top +"\n"+str(round(-ac_th_up*1.5,10))+" "+str(round(height-ac_th_up/2,10))
                ch3_top = ch3_top +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
            elif seg == 3:
                ch4_top = ch4_top +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                ch4_top = ch4_top +"\n"+str(round(-ac_th_up*1.5,10))+" "+str(round(height-ac_th_up/2,10))
                ch4_top = ch4_top +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                
            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        """
        #**************************end section *****************************
        #ZXC4
            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
        """
        # I counted 4 nodes now

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        """

        #---------------------- creating next block -----------------------
            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
        """

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        """
        #------------------------------------------------
        # tip section
            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""

        """

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        """

        #==================================================
        #ZXC5
            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+2*ac_th_for+ch_depth+gap,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+2*ac_th_for+ch_depth+gap,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
        """
        # I counted 4 nodes now

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        
        """
            final = final +"\n"+ dedent(tmp).strip("\n")
            tmp = """"""
    #===============
    
    #====Silicon layer above paper ========
    if 1 ==1:
        for cnt in range(num):
            OS = cnt*(2*ac_th_for+ch_depth+gap)

        #-------------------------------------------------------    
            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
        """
        # I counted 4 nodes now

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        """
        # EDIT EDIT EDIT
        #-----------------------------------------------------------------------------------------
        # tip section
            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""


        """

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        """
        #--------------------------------------------------------------------------------
            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
        """
        # I counted 4 nodes now

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        """
            #-------------------------------------------------------------------------------------------
            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+2*ac_th_for+ch_depth+gap,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+2*ac_th_for+ch_depth+gap,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
        """
        # I counted 4 nodes now

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        
        """
            final = final +"\n"+ dedent(tmp).strip("\n")
            tmp = """"""
    #======================================
    
    #====Paper layer =======
    if 1 == 1:

        for cnt in range(num):
            OS = cnt*(2*ac_th_for+ch_depth+gap)
        # This section of code creates the layer just below the actuator silicon layer just above the strain limiting layer

        #-------------------------------------------------------    
            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
        """
        # I counted 4 nodes now

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        """
        # EDIT EDIT EDIT

        # tip section
            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""


        """

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        """

            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
        """
        # I counted 4 nodes now

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        """
            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+2*ac_th_for+ch_depth+gap,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+2*ac_th_for+ch_depth+gap,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
        """
        # I counted 4 nodes now

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        
        """
            final = final +"\n"+ dedent(tmp).strip("\n")
            tmp = """"""
    #=======================
    
    #====Silicon layer below paper ========
    if 1 == 1:

        # This section of code creates the layer just below the actuator silicon layer just above the strain limiting layer
        for cnt in range(num):
            OS = cnt*(2*ac_th_for+ch_depth+gap)

        #-------------------------------------------------------    
            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
        """
        # I counted 4 nodes now

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        """
        # EDIT EDIT EDIT

        # tip section
            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""


        """

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        """

            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
        """
        # I counted 4 nodes now

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        """
            tmp = tmp + """
        *add_points
        """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+2*ac_th_for+ch_depth+gap,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
        """ + str(round(OS+LK+2*ac_th_for+ch_depth+gap,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
        """
        # I counted 4 nodes now

            tmp = tmp + """
        *add_curves
        1 2 3 4 1 3 2 4
        """

            tmp = tmp+"""
        *apply_curve_divisions
        1 2 3 4
        #
        """

            tmp = tmp+ """
        *af_planar_quadmesh
        1 4 2 3
        #
        """

            tmp = tmp+"""
        *remove_curves
        all_existing
        *remove_points
        all_existing
        
        """
            final = final +"\n"+ dedent(tmp).strip("\n")
            tmp = """"""
    #======================================
    
    #===below actuator for extension ====
    if 1 == 1:
        if below_actuator_flag == 1:

            for cnt in range(num):
                OS = cnt*(2*ac_th_for+ch_depth+gap)
                    #----------now create from start of actuator:
                    #ZXC2
                    #-------------------------------------------------------    
                tmp = tmp + """
            *add_points
            """ + str(round(OS+LK,10))+" "+str(round(R_d -gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d -gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

                tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

                tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

                tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

                tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """

            #---------------------- creating next block -----------------------

                tmp = tmp + """
            *add_points
            """ + str(round(OS+LK,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """

                tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

                tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

                tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

                tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """
            #------------------------------------------------
            # tip section
                tmp = tmp + """
            *add_points
            """ + str(round(OS+LK,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
            """

                tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

                tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

                tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

                tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """

            #*************************mid section**************************
            #ZXC3
            #------------------------------------------------

            # tip section
                tmp = tmp + """
            *add_points
            """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
            """
            
                if seg == 0:
                    ch1_bot = ch1_bot +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                    ch1_bot = ch1_bot +"\n"+str(round(R_d-(xFlex_height-ac_th_up/2),10))+ " " +str(round(R_d+ac_th_up/2,10))
                    ch1_bot = ch1_bot +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                elif seg == 1:
                    ch2_bot = ch2_bot +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                    ch2_bot = ch2_bot +"\n"+str(round(R_d-(xFlex_height-ac_th_up/2),10))+ " " +str(round(R_d+ac_th_up/2,10))
                    ch2_bot = ch2_bot +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                elif seg == 2:
                    ch3_bot = ch3_bot +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                    ch3_bot = ch3_bot +"\n"+str(round(R_d-(xFlex_height-ac_th_up/2),10))+ " " +str(round(R_d+ac_th_up/2,10))
                    ch3_bot = ch3_bot +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                elif seg == 3:
                    ch4_bot = ch4_bot +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                    ch4_bot = ch4_bot +"\n"+str(round(R_d-(xFlex_height-ac_th_up/2),10))+ " " +str(round(R_d+ac_th_up/2,10))
                    ch4_bot = ch4_bot +"\n"+ str(round(-1,10))+" "+ str(round(1,10))

                tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

                tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

                tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

                tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """
            #**************************end section *****************************
            #ZXC4
                tmp = tmp + """
            *add_points
            """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

                tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

                tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

                tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

                tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """

            #---------------------- creating next block -----------------------
                tmp = tmp + """
            *add_points
            """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """

                tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

                tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

                tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

                tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """
            #------------------------------------------------
            # tip section
                tmp = tmp + """
            *add_points
            """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""

            """

                tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

                tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

                tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

                tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """

            #==================================================
            #ZXC5
                tmp = tmp + """
            *add_points
            """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+2*ac_th_for+ch_depth+gap,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
            """ + str(round(OS+LK+2*ac_th_for+ch_depth+gap,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

                tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

                tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

                tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

                tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            
            """
                final = final +"\n"+ dedent(tmp).strip("\n")
                tmp = """"""

        #=============================
    
    #====closing the remainder =======
    if 1 == 1:
        st_pt = LK

        OS = num*(2*ac_th_for+ch_depth+gap)

        if rem_n == 0:
            # problem: ch_sel_1 without -1 goes over the available so 2 ch code will mode to 3 ch
            # sol: trying to split into two cases
            vara = st_pt+(2*ac_th_for+ch_depth+gap)*(math.floor(ch_sel_1-1)) + ac_th_for
            varb = st_pt+(2*ac_th_for+ch_depth+gap)*(math.floor(ch_sel_1-1)) + (2*ac_th_for+ch_depth)

            # for varc we are subtracting from end so no -1
            varc = st_pt+(2*ac_th_for+ch_depth+gap)*(math.floor(ch_sel_1)) - (2*ac_th_for+ch_depth+gap)*(1-rem_n)
            # for vard going from end - gap and ac_th_side
            vard = st_pt+(2*ac_th_for+ch_depth+gap)*(math.floor(ch_sel_1)) - ac_th_side-gap
            vare = st_pt+(2*ac_th_for+ch_depth+gap)*(math.floor(ch_sel_1))
        else:
            # if segment PNA whole number dont want to make A part of ch +1 segment which doesnt exist thus -1
            vara = st_pt+(2*ac_th_for+ch_depth+gap)*(math.floor(ch_sel_1)) + ac_th_for
            varb = st_pt+(2*ac_th_for+ch_depth+gap)*(math.floor(ch_sel_1)) + (ac_th_for+ch_depth)  
            varc = st_pt+(2*ac_th_for+ch_depth+gap)*(math.floor(ch_sel_1)) + (2*ac_th_for+ch_depth) 

            # we are doing +1 here
            var_current = st_pt+(2*ac_th_for+ch_depth+gap)*(math.floor(ch_sel_1+1)) - (2*ac_th_for+ch_depth+gap)*(1-rem_n)

            if rem_n>0:
                if var_current <= vara:
                    # start var_current <= vara
                    if 1==1:
                        st_pt = LK
                        #rem_n = 0.05 # remove

                        var_current = st_pt+(2*ac_th_for+ch_depth+gap)*(math.floor(ch_sel_1+1)) - (2*ac_th_for+ch_depth+gap)*(1-rem_n)
                        OS = num*(2*ac_th_for+ch_depth+gap)
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #---------------------- creating next block -----------------------

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        #------------------------------------------------
                        # tip section
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""

                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """


                        #&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&AbovePaper&&&&&&&&&&&&&&&&&&&&&&&&&&&&

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        # &&&&&&&&&&&&&&&&&&&&&&&&&&&&PaperLayer&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        # &&&&&&&&&&&&&&&&&&&&&&&&&

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        
                        """
                        
                        final = final + "\n"+dedent(tmp).strip("\n")
                        tmp = """"""

                        # &&&&&&&&&&&&&&&&&&&&&&&&&&&&&& Below actuator layer

                        if below_actuator_flag == 1:
                            tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(R_d -gap_height-air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(R_d -gap_height-air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
                        """
                            # I counted 4 nodes now

                            tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                            tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                            tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                            tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                                #---------------------- creating next block -----------------------

                            tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                        """

                            tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                            tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                            tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                            tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                                #------------------------------------------------
                                # tip section
                            tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """

                            tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                            tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                            tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                            tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        
                        """
                            final = final + "\n"+dedent(tmp).strip("\n")
                            tmp = """"""
                    # end var_current <= vara
                elif var_current <= varb:
                    # start var_current <= varb
                    if 1==1:
                        st_pt = LK
                        #rem_n = 0.5 # remove

                        var_current = st_pt+(2*ac_th_for+ch_depth+gap)*(math.floor(ch_sel_1+1)) - (2*ac_th_for+ch_depth+gap)*(1-rem_n)
                        OS = num*(2*ac_th_for+ch_depth+gap)


                        #ZARG1

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #---------------------- creating next block -----------------------

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        #------------------------------------------------
                        # tip section
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""

                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #*************************mid section**************************
                        #ZXC3
                        #------------------------------------------------

                        # tip section
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""


                        """
                                 
                        if seg == 0:
                            ch1_top = ch1_top +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(var_current+ac_th_for/2,10))
                            ch1_top = ch1_top +"\n"+str(round(-ac_th_up*1.5,10))+" "+str(round(height-ac_th_up/2,10))
                            ch1_top = ch1_top +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                        elif seg == 1:
                            ch2_top = ch2_top +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(var_current+ac_th_for/2,10))
                            ch2_top = ch2_top +"\n"+str(round(-ac_th_up*1.5,10))+" "+str(round(height-ac_th_up/2,10))
                            ch2_top = ch2_top +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                        elif seg == 2:
                            ch3_top = ch3_top +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(var_current+ac_th_for/2,10))
                            ch3_top = ch3_top +"\n"+str(round(-ac_th_up*1.5,10))+" "+str(round(height-ac_th_up/2,10))
                            ch3_top = ch3_top +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                        elif seg == 3:
                            ch4_top = ch4_top +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(var_current+ac_th_for/2,10))
                            ch4_top = ch4_top +"\n"+str(round(-ac_th_up*1.5,10))+" "+str(round(height-ac_th_up/2,10))
                            ch4_top = ch4_top +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
            


                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #ZARG2
                        #=============================================

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        # EDIT EDIT EDIT
                        #-----------------------------------------------------------------------------------------
                        # tip section
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""


                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        #--------------------------------------------------------------------------------

                        #ZARG3
                        #==============================================================================
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        # EDIT EDIT EDIT

                        # tip section
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""


                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        # ZARG4
                        #==================

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        # EDIT EDIT EDIT

                        # tip section
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""


                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        
                        """
                        
                        final = final + "\n"+dedent(tmp).strip("\n")
                        tmp = """"""

                        #ZARG5
                        #=======================================
                        if below_actuator_flag == 1:

                            tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(R_d -gap_height-air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d -gap_height-air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                            tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                            tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                            tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                            tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #---------------------- creating next block -----------------------

                            tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                        """

                            tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                            tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                            tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                            tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        #------------------------------------------------
                        # tip section
                            tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """

                            tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                            tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                            tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                            tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #*************************mid section**************************
                        #ZXC3
                        #------------------------------------------------

                        # tip section
                            tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """
                            if seg == 0:
                                ch1_bot = ch1_bot +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(var_current+ac_th_for/2,10))
                                ch1_bot = ch1_bot +"\n"+str(round(R_d-(xFlex_height-ac_th_up/2),10))+ " " +str(round(R_d+ac_th_up/2,10))
                                ch1_bot = ch1_bot +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                            elif seg == 1:
                                ch2_bot = ch2_bot +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(var_current+ac_th_for/2,10))
                                ch2_bot = ch2_bot +"\n"+str(round(R_d-(xFlex_height-ac_th_up/2),10))+ " " +str(round(R_d+ac_th_up/2,10))
                                ch2_bot = ch2_bot +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                            elif seg == 2:
                                ch3_bot = ch3_bot +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(var_current+ac_th_for/2,10))
                                ch3_bot = ch3_bot +"\n"+str(round(R_d-(xFlex_height-ac_th_up/2),10))+ " " +str(round(R_d+ac_th_up/2,10))
                                ch3_bot = ch3_bot +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                            elif seg == 3:
                                ch4_bot = ch4_bot +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(var_current+ac_th_for/2,10))
                                ch4_bot = ch4_bot +"\n"+str(round(R_d-(xFlex_height-ac_th_up/2),10))+ " " +str(round(R_d+ac_th_up/2,10))
                                ch4_bot = ch4_bot +"\n"+ str(round(-1,10))+" "+ str(round(1,10))

                            tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                            tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                            tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                            tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        
                        """
                            final = final + "\n"+dedent(tmp).strip("\n")
                            tmp = """"""
                    # end var_current <= varb
                elif var_current <= varc:
                    # start var_current <= varc
                    if 1==1:
                        st_pt = LK
                        #rem_n = 0.75 # remove

                        var_current = st_pt+(2*ac_th_for+ch_depth+gap)*(math.floor(ch_sel_1+1)) - (2*ac_th_for+ch_depth+gap)*(1-rem_n)
                        OS = num*(2*ac_th_for+ch_depth+gap)

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #---------------------- creating next block -----------------------

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        #------------------------------------------------
                        # tip section
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""

                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #*************************mid section**************************
                        #ZXC3
                        #------------------------------------------------

                        # tip section
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""


                        """
                        
                        if seg == 0:
                            ch1_top = ch1_top +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                            ch1_top = ch1_top +"\n"+str(round(-ac_th_up*1.5,10))+" "+str(round(height-ac_th_up/2,10))
                            ch1_top = ch1_top +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                        elif seg == 1:
                            ch2_top = ch2_top +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                            ch2_top = ch2_top +"\n"+str(round(-ac_th_up*1.5,10))+" "+str(round(height-ac_th_up/2,10))
                            ch2_top = ch2_top +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                        elif seg == 2:
                            ch3_top = ch3_top +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                            ch3_top = ch3_top +"\n"+str(round(-ac_th_up*1.5,10))+" "+str(round(height-ac_th_up/2,10))
                            ch3_top = ch3_top +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                        elif seg == 3:
                            ch4_top = ch4_top +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                            ch4_top = ch4_top +"\n"+str(round(-ac_th_up*1.5,10))+" "+str(round(height-ac_th_up/2,10))
                            ch4_top = ch4_top +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
            



                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        #**************************end section *****************************
                        #ZXC4
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #---------------------- creating next block -----------------------
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        #------------------------------------------------
                        # tip section
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""

                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #==================================================

                        #ZARG2

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        # EDIT EDIT EDIT
                        #-----------------------------------------------------------------------------------------
                        # tip section
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""


                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        #--------------------------------------------------------------------------------
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #ZARG3
                        #============================================
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        # EDIT EDIT EDIT

                        # tip section
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""


                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #ZARG4
                        #=============================

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        # EDIT EDIT EDIT

                        # tip section
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""


                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        
                        """
                        final = final + "\n"+dedent(tmp).strip("\n")
                        tmp = """"""

                        # ZARG5
                        #=====================================
                        if below_actuator_flag == 1:

                            tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(R_d -gap_height-air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d -gap_height-air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                            tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                            tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                            tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                            tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #---------------------- creating next block -----------------------

                            tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                        """

                            tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                            tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                            tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                            tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        #------------------------------------------------
                        # tip section
                            tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """

                            tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                            tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                            tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                            tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #*************************mid section**************************
                        #ZXC3
                        #------------------------------------------------

                        # tip section
                            tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """

                            if seg == 0:
                                ch1_bot = ch1_bot +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                                ch1_bot = ch1_bot +"\n"+str(round(R_d-(xFlex_height-ac_th_up/2),10))+ " " +str(round(R_d+ac_th_up/2,10))
                                ch1_bot = ch1_bot +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                            elif seg == 1:
                                ch2_bot = ch2_bot +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                                ch2_bot = ch2_bot +"\n"+str(round(R_d-(xFlex_height-ac_th_up/2),10))+ " " +str(round(R_d+ac_th_up/2,10))
                                ch2_bot = ch2_bot +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                            elif seg == 2:
                                ch3_bot = ch3_bot +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                                ch3_bot = ch3_bot +"\n"+str(round(R_d-(xFlex_height-ac_th_up/2),10))+ " " +str(round(R_d+ac_th_up/2,10))
                                ch3_bot = ch3_bot +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                            elif seg == 3:
                                ch4_bot = ch4_bot +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                                ch4_bot = ch4_bot +"\n"+str(round(R_d-(xFlex_height-ac_th_up/2),10))+ " " +str(round(R_d+ac_th_up/2,10))
                                ch4_bot = ch4_bot +"\n"+ str(round(-1,10))+" "+ str(round(1,10))

                            
                            tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                            tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                            tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                            tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        #**************************end section *****************************
                        #ZXC4
                            tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                            tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                            tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                            tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                            tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #---------------------- creating next block -----------------------
                            tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                        """

                            tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                            tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                            tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                            tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        #------------------------------------------------
                        # tip section
                            tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""

                        """

                            tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                            tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                            tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                            tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        
                        """
                            final = final + "\n"+dedent(tmp).strip("\n")
                            tmp = """"""
                    # end var_current <= vara
                else:
                    if 1==1:    
                        st_pt = LK

                        var_current = st_pt+(2*ac_th_for+ch_depth+gap)*(math.floor(ch_sel_1+1)) - (2*ac_th_for+ch_depth+gap)*(1-rem_n)
                        OS = num*(2*ac_th_for+ch_depth+gap)

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #---------------------- creating next block -----------------------

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        #------------------------------------------------
                        # tip section
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""

                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #*************************mid section**************************
                        #ZXC3
                        #------------------------------------------------

                        # tip section
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""


                        """
                        
                        if seg == 0:
                            ch1_top = ch1_top +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                            ch1_top = ch1_top +"\n"+str(round(-ac_th_up*1.5,10))+" "+str(round(height-ac_th_up/2,10))
                            ch1_top = ch1_top +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                        elif seg == 1:
                            ch2_top = ch2_top +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                            ch2_top = ch2_top +"\n"+str(round(-ac_th_up*1.5,10))+" "+str(round(height-ac_th_up/2,10))
                            ch2_top = ch2_top +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                        elif seg == 2:
                            ch3_top = ch3_top +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                            ch3_top = ch3_top +"\n"+str(round(-ac_th_up*1.5,10))+" "+str(round(height-ac_th_up/2,10))
                            ch3_top = ch3_top +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                        elif seg == 3:
                            ch4_top = ch4_top +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                            ch4_top = ch4_top +"\n"+str(round(-ac_th_up*1.5,10))+" "+str(round(height-ac_th_up/2,10))
                            ch4_top = ch4_top +"\n"+ str(round(-1,10))+" "+ str(round(1,10))



                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        #**************************end section *****************************
                        #ZXC4
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #---------------------- creating next block -----------------------
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        #------------------------------------------------
                        # tip section
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""

                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #==================================================
                        #ZXC5
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        #ZARG2

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        # EDIT EDIT EDIT
                        #-----------------------------------------------------------------------------------------
                        # tip section
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""


                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        #--------------------------------------------------------------------------------
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        #-------------------------------------------------------------------------------------------
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #============================
                        #ZARG3

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        # EDIT EDIT EDIT

                        # tip section
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""


                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        #ZARG4
                        #=====================================
                        #-------------------------------------------------------    
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        # EDIT EDIT EDIT

                        # tip section
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""


                        """

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """

                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        """
                        tmp = tmp + """
                        *add_points
                        """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                        """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                        """
                        # I counted 4 nodes now

                        tmp = tmp + """
                        *add_curves
                        1 2 3 4 1 3 2 4
                        """

                        tmp = tmp+"""
                        *apply_curve_divisions
                        1 2 3 4
                        #
                        """

                        tmp = tmp+ """
                        *af_planar_quadmesh
                        1 4 2 3
                        #
                        """

                        tmp = tmp+"""
                        *remove_curves
                        all_existing
                        *remove_points
                        all_existing
                        
                        """
                        
                        final = final +"\n"+ dedent(tmp).strip("\n")
                        tmp = """"""
                        #==========================ZARG5=========================

                        if below_actuator_flag == 1:

                            tmp = tmp + """
                            *add_points
                            """ + str(round(OS+LK,10))+" "+str(round(R_d -gap_height-air_vent,10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d -gap_height-air_vent,10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
                            """
                            # I counted 4 nodes now

                            tmp = tmp + """
                            *add_curves
                            1 2 3 4 1 3 2 4
                            """

                            tmp = tmp+"""
                            *apply_curve_divisions
                            1 2 3 4
                            #
                            """

                            tmp = tmp+ """
                            *af_planar_quadmesh
                            1 4 2 3
                            #
                            """

                            tmp = tmp+"""
                            *remove_curves
                            all_existing
                            *remove_points
                            all_existing
                            """

                            #---------------------- creating next block -----------------------

                            tmp = tmp + """
                            *add_points
                            """ + str(round(OS+LK,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                            """

                            tmp = tmp + """
                            *add_curves
                            1 2 3 4 1 3 2 4
                            """

                            tmp = tmp+"""
                            *apply_curve_divisions
                            1 2 3 4
                            #
                            """

                            tmp = tmp+ """
                            *af_planar_quadmesh
                            1 4 2 3
                            #
                            """

                            tmp = tmp+"""
                            *remove_curves
                            all_existing
                            *remove_points
                            all_existing
                            """
                            #------------------------------------------------
                            # tip section
                            tmp = tmp + """
                            *add_points
                            """ + str(round(OS+LK,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                            """

                            tmp = tmp + """
                            *add_curves
                            1 2 3 4 1 3 2 4
                            """

                            tmp = tmp+"""
                            *apply_curve_divisions
                            1 2 3 4
                            #
                            """

                            tmp = tmp+ """
                            *af_planar_quadmesh
                            1 4 2 3
                            #
                            """

                            tmp = tmp+"""
                            *remove_curves
                            all_existing
                            *remove_points
                            all_existing
                            """

                            #*************************mid section**************************
                            #ZXC3
                            #------------------------------------------------

                            # tip section
                            tmp = tmp + """
                            *add_points
                            """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                            """

                            if seg == 0:
                                ch1_bot = ch1_bot +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                                ch1_bot = ch1_bot +"\n"+str(round(R_d-(xFlex_height-ac_th_up/2),10))+ " " +str(round(R_d+ac_th_up/2,10))
                                ch1_bot = ch1_bot +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                            elif seg == 1:
                                ch2_bot = ch2_bot +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                                ch2_bot = ch2_bot +"\n"+str(round(R_d-(xFlex_height-ac_th_up/2),10))+ " " +str(round(R_d+ac_th_up/2,10))
                                ch2_bot = ch2_bot +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                            elif seg == 2:
                                ch3_bot = ch3_bot +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                                ch3_bot = ch3_bot +"\n"+str(round(R_d-(xFlex_height-ac_th_up/2),10))+ " " +str(round(R_d+ac_th_up/2,10))
                                ch3_bot = ch3_bot +"\n"+ str(round(-1,10))+" "+ str(round(1,10))
                            elif seg == 3:
                                ch4_bot = ch4_bot +"\n"+ str(round(OS+LK+ac_th_for/2,10))+" "+ str(round(OS+LK+ac_th_for*1.5+ch_depth,10))
                                ch4_bot = ch4_bot +"\n"+str(round(R_d-(xFlex_height-ac_th_up/2),10))+ " " +str(round(R_d+ac_th_up/2,10))
                                ch4_bot = ch4_bot +"\n"+ str(round(-1,10))+" "+ str(round(1,10))

                            tmp = tmp + """
                            *add_curves
                            1 2 3 4 1 3 2 4
                            """

                            tmp = tmp+"""
                            *apply_curve_divisions
                            1 2 3 4
                            #
                            """

                            tmp = tmp+ """
                            *af_planar_quadmesh
                            1 4 2 3
                            #
                            """

                            tmp = tmp+"""
                            *remove_curves
                            all_existing
                            *remove_points
                            all_existing
                            """
                            #**************************end section *****************************
                            #ZXC4
                            tmp = tmp + """
                            *add_points
                            """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
                            """
                            # I counted 4 nodes now

                            tmp = tmp + """
                            *add_curves
                            1 2 3 4 1 3 2 4
                            """

                            tmp = tmp+"""
                            *apply_curve_divisions
                            1 2 3 4
                            #
                            """

                            tmp = tmp+ """
                            *af_planar_quadmesh
                            1 4 2 3
                            #
                            """

                            tmp = tmp+"""
                            *remove_curves
                            all_existing
                            *remove_points
                            all_existing
                            """

                            #---------------------- creating next block -----------------------
                            tmp = tmp + """
                            *add_points
                            """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                            """

                            tmp = tmp + """
                            *add_curves
                            1 2 3 4 1 3 2 4
                            """

                            tmp = tmp+"""
                            *apply_curve_divisions
                            1 2 3 4
                            #
                            """

                            tmp = tmp+ """
                            *af_planar_quadmesh
                            1 4 2 3
                            #
                            """

                            tmp = tmp+"""
                            *remove_curves
                            all_existing
                            *remove_points
                            all_existing
                            """
                            #------------------------------------------------
                            # tip section
                            tmp = tmp + """
                            *add_points
                            """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+ac_th_for+ch_depth,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+ac_th_for+ch_depth+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""

                            """

                            tmp = tmp + """
                            *add_curves
                            1 2 3 4 1 3 2 4
                            """

                            tmp = tmp+"""
                            *apply_curve_divisions
                            1 2 3 4
                            #
                            """

                            tmp = tmp+ """
                            *af_planar_quadmesh
                            1 4 2 3
                            #
                            """

                            tmp = tmp+"""
                            *remove_curves
                            all_existing
                            *remove_points
                            all_existing
                            """

                            #==================================================
                            #ZXC5
                            tmp = tmp + """
                            *add_points
                            """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                            """ + str(round(var_current,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                            """ + str(round(OS+LK+2*ac_th_for+ch_depth,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
                            """ + str(round(var_current,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
                            """
                            # I counted 4 nodes now

                            tmp = tmp + """
                            *add_curves
                            1 2 3 4 1 3 2 4
                            """

                            tmp = tmp+"""
                            *apply_curve_divisions
                            1 2 3 4
                            #
                            """

                            tmp = tmp+ """
                            *af_planar_quadmesh
                            1 4 2 3
                            #
                            """

                            tmp = tmp+"""
                            *remove_curves
                            all_existing
                            *remove_points
                            all_existing
                            
                            """
                            
                            final = final + "\n"+dedent(tmp).strip("\n")
                            tmp = """"""

            if 1==1:
                        # This is code to make the end encasing section:
                st_pt = LK
                #rem_n = 0.05 # remove

                var_current = st_pt+(2*ac_th_for+ch_depth+gap)*(math.floor(ch_sel_1+1)) - (2*ac_th_for+ch_depth+gap)*(1-rem_n)
                OS = num*(2*ac_th_for+ch_depth+gap)

                #ZARG1 = above bellows
                #ZARG2 = above sil
                #ZARG3 = Paper Layer
                tmp = tmp + """
                *add_points
                """ + str(round(var_current,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                """
                # I counted 4 nodes now

                tmp = tmp + """
                *add_curves
                1 2 3 4 1 3 2 4
                """

                tmp = tmp+"""
                *apply_curve_divisions
                1 2 3 4
                #
                """

                tmp = tmp+ """
                *af_planar_quadmesh
                1 4 2 3
                #
                """

                tmp = tmp+"""
                *remove_curves
                all_existing
                *remove_points
                all_existing
                """

                #---------------------- creating next block -----------------------
                tmp = tmp + """
                *add_points
                """ + str(round(var_current,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                """

                tmp = tmp + """
                *add_curves
                1 2 3 4 1 3 2 4
                """

                tmp = tmp+"""
                *apply_curve_divisions
                1 2 3 4
                #
                """

                tmp = tmp+ """
                *af_planar_quadmesh
                1 4 2 3
                #
                """

                tmp = tmp+"""
                *remove_curves
                all_existing
                *remove_points
                all_existing
                """
                #------------------------------------------------
                # tip section
                tmp = tmp + """
                *add_points
                """ + str(round(var_current,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""

                """

                tmp = tmp + """
                *add_curves
                1 2 3 4 1 3 2 4
                """

                tmp = tmp+"""
                *apply_curve_divisions
                1 2 3 4
                #
                """

                tmp = tmp+ """
                *af_planar_quadmesh
                1 4 2 3
                #
                """

                tmp = tmp+"""
                *remove_curves
                all_existing
                *remove_points
                all_existing
                """

                #==================================================
                #ZXC5
                tmp = tmp + """
                *add_points
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
                """
                # I counted 4 nodes now

                tmp = tmp + """
                *add_curves
                1 2 3 4 1 3 2 4
                """

                tmp = tmp+"""
                *apply_curve_divisions
                1 2 3 4
                #
                """

                tmp = tmp+ """
                *af_planar_quadmesh
                1 4 2 3
                #
                """

                tmp = tmp+"""
                *remove_curves
                all_existing
                *remove_points
                all_existing
                """

                # ZARG2 

                tmp = tmp + """
                *add_points
                """ + str(round(var_current,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                """
                # I counted 4 nodes now

                tmp = tmp + """
                *add_curves
                1 2 3 4 1 3 2 4
                """

                tmp = tmp+"""
                *apply_curve_divisions
                1 2 3 4
                #
                """

                tmp = tmp+ """
                *af_planar_quadmesh
                1 4 2 3
                #
                """

                tmp = tmp+"""
                *remove_curves
                all_existing
                *remove_points
                all_existing
                """
                #-------------------------------------------------------------------------------------------
                tmp = tmp + """
                *add_points
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
                """
                # I counted 4 nodes now

                tmp = tmp + """
                *add_curves
                1 2 3 4 1 3 2 4
                """

                tmp = tmp+"""
                *apply_curve_divisions
                1 2 3 4
                #
                """

                tmp = tmp+ """
                *af_planar_quadmesh
                1 4 2 3
                #
                """

                tmp = tmp+"""
                *remove_curves
                all_existing
                *remove_points
                all_existing
                """
                # ZARG3

                tmp = tmp + """
                *add_points
                """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                """
                # I counted 4 nodes now

                tmp = tmp + """
                *add_curves
                1 2 3 4 1 3 2 4
                """

                tmp = tmp+"""
                *apply_curve_divisions
                1 2 3 4
                #
                """

                tmp = tmp+ """
                *af_planar_quadmesh
                1 4 2 3
                #
                """

                tmp = tmp+"""
                *remove_curves
                all_existing
                *remove_points
                all_existing
                """
                tmp = tmp + """
                *add_points
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
                """
                # I counted 4 nodes now

                tmp = tmp + """
                *add_curves
                1 2 3 4 1 3 2 4
                """

                tmp = tmp+"""
                *apply_curve_divisions
                1 2 3 4
                #
                """

                tmp = tmp+ """
                *af_planar_quadmesh
                1 4 2 3
                #
                """

                tmp = tmp+"""
                *remove_curves
                all_existing
                *remove_points
                all_existing
                """

                #ZARG4

                tmp = tmp + """
                *add_points
                """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                """
                # I counted 4 nodes now

                tmp = tmp + """
                *add_curves
                1 2 3 4 1 3 2 4
                """

                tmp = tmp+"""
                *apply_curve_divisions
                1 2 3 4
                #
                """

                tmp = tmp+ """
                *af_planar_quadmesh
                1 4 2 3
                #
                """

                tmp = tmp+"""
                *remove_curves
                all_existing
                *remove_points
                all_existing
                """
                tmp = tmp + """
                *add_points
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
                """
                # I counted 4 nodes now

                tmp = tmp + """
                *add_curves
                1 2 3 4 1 3 2 4
                """

                tmp = tmp+"""
                *apply_curve_divisions
                1 2 3 4
                #
                """

                tmp = tmp+ """
                *af_planar_quadmesh
                1 4 2 3
                #
                """

                tmp = tmp+"""
                *remove_curves
                all_existing
                *remove_points
                all_existing
                
                """
                
                final = final + "\n"+dedent(tmp).strip("\n")
                tmp = """"""
    
                #ZARG5
                if below_actuator_flag == 1:

                    tmp = tmp + """
                *add_points
                """ + str(round(var_current,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
                """
                # I counted 4 nodes now

                    tmp = tmp + """
                *add_curves
                1 2 3 4 1 3 2 4
                """

                    tmp = tmp+"""
                *apply_curve_divisions
                1 2 3 4
                #
                """

                    tmp = tmp+ """
                *af_planar_quadmesh
                1 4 2 3
                #
                """

                    tmp = tmp+"""
                *remove_curves
                all_existing
                *remove_points
                all_existing
                """

                #---------------------- creating next block -----------------------
                    tmp = tmp + """
                *add_points
                """ + str(round(var_current,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                """ + str(round(var_current,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                """

                    tmp = tmp + """
                *add_curves
                1 2 3 4 1 3 2 4
                """

                    tmp = tmp+"""
                *apply_curve_divisions
                1 2 3 4
                #
                """

                    tmp = tmp+ """
                *af_planar_quadmesh
                1 4 2 3
                #
                """

                    tmp = tmp+"""
                *remove_curves
                all_existing
                *remove_points
                all_existing
                """
                #------------------------------------------------
                # tip section
                    tmp = tmp + """
                *add_points
                """ + str(round(var_current,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""

                """

                    tmp = tmp + """
                *add_curves
                1 2 3 4 1 3 2 4
                """

                    tmp = tmp+"""
                *apply_curve_divisions
                1 2 3 4
                #
                """

                    tmp = tmp+ """
                *af_planar_quadmesh
                1 4 2 3
                #
                """

                    tmp = tmp+"""
                *remove_curves
                all_existing
                *remove_points
                all_existing
                """

                #==================================================

                    tmp = tmp + """
                *add_points
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
                """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
                """
                # I counted 4 nodes now

                    tmp = tmp + """
                *add_curves
                1 2 3 4 1 3 2 4
                """

                    tmp = tmp+"""
                *apply_curve_divisions
                1 2 3 4
                #
                """

                    tmp = tmp+ """
                *af_planar_quadmesh
                1 4 2 3
                #
                """

                    tmp = tmp+"""
                *remove_curves
                all_existing
                *remove_points
                all_existing
                
                """
                    
                    final = final + "\n"+dedent(tmp).strip("\n")
                    tmp = """"""
    #================================
    
    #====End gap =================
    if 1 == 1:
        if seg+1 != len(P_len)-1: 
            # This is code to make the end encasing section:
            st_pt = LK
            #rem_n = 0.05 # remove
            if rem_n > 0:
                var_current = st_pt+(2*ac_th_for+ch_depth+gap)*(math.floor(ch_sel_1+1)) - (2*ac_th_for+ch_depth+gap)*(1-rem_n)
            else:
                # if chamber number whole number then
                var_current = st_pt+(2*ac_th_for+ch_depth+gap)*num

            #ZARG1 = above bellows
            #ZARG2 = above sil
            #ZARG3 = Paper Layer
            tmp = tmp + """
            *add_points
            """ + str(round(var_current,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """

            #---------------------- creating next block -----------------------
            tmp = tmp + """
            *add_points
            """ + str(round(var_current,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
            """

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """
            #------------------------------------------------
            # tip section
            tmp = tmp + """
            *add_points
            """ + str(round(var_current,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""

            """

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """

            #==================================================
            #ZXC5
            tmp = tmp + """
            *add_points
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """

            # ZARG2 

            tmp = tmp + """
            *add_points
            """ + str(round(var_current,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """
            #-------------------------------------------------------------------------------------------
            tmp = tmp + """
            *add_points
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """
            # ZARG3

            tmp = tmp + """
            *add_points
            """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """
            tmp = tmp + """
            *add_points
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """

            #ZARG4

            tmp = tmp + """
            *add_points
            """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """
            tmp = tmp + """
            *add_points
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            
            """
            
            final = final + "\n"+dedent(tmp).strip("\n")
            tmp = """"""

            #ZARG5
            if below_actuator_flag == 1:

                tmp = tmp + """
            *add_points
            """ + str(round(var_current,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

                tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

                tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

                tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

                tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """

            #---------------------- creating next block -----------------------
                tmp = tmp + """
            *add_points
            """ + str(round(var_current,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
            """ + str(round(var_current,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """

                tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

                tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

                tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

                tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """
            #------------------------------------------------
            # tip section
                tmp = tmp + """
            *add_points
            """ + str(round(var_current,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""

            """

                tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

                tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

                tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

                tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """

            #==================================================

                tmp = tmp + """
            *add_points
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

                tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

                tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

                tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

                tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            
            """
                final = final + "\n"+dedent(tmp).strip("\n")
                tmp = """"""
    
        elif seg+1 == len(P_len)-1:
             
            # This is code to make the end encasing section:
            st_pt = LK
            #rem_n = 0.05 # remove

            var_current = st_pt+(2*ac_th_for+ch_depth+gap)*(math.floor(ch_sel_1+1)) - (2*ac_th_for+ch_depth+gap)*(1-rem_n)
            OS = num*(2*ac_th_for+ch_depth+gap)

            #ZARG1 = above bellows
            #ZARG2 = above sil
            #ZARG3 = Paper Layer
            tmp = tmp + """
            *add_points
            """ + str(round(var_current,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """

            #---------------------- creating next block -----------------------
            tmp = tmp + """
            *add_points
            """ + str(round(var_current,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
            """

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """
            #------------------------------------------------
            # tip section
            tmp = tmp + """
            *add_points
            """ + str(round(var_current,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""

            """

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """

            #==================================================
            #ZXC5
            tmp = tmp + """
            *add_points
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """

            # ZARG2 
            # &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&& can remove if you dont want end to be blocked
            #---------------------- creating next block -----------------------
            tmp = tmp + """
            *add_points
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
            """

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """
            #------------------------------------------------
            # tip section
            tmp = tmp + """
            *add_points
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""

            """

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """

            #==================================================
            #&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
            
            tmp = tmp + """
            *add_points
            """ + str(round(var_current,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """
            #-------------------------------------------------------------------------------------------
            tmp = tmp + """
            *add_points
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """
            # ZARG3

            tmp = tmp + """
            *add_points
            """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """
            tmp = tmp + """
            *add_points
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """

            #ZARG4

            tmp = tmp + """
            *add_points
            """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """
            tmp = tmp + """
            *add_points
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

            tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

            tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

            tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

            tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            
            """
            
            final = final +"\n"+ dedent(tmp).strip("\n")
            tmp = """"""
    
            #ZARG5
            if below_actuator_flag == 1:

                tmp = tmp + """
            *add_points
            """ + str(round(var_current,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

                tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

                tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

                tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

                tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """

            #---------------------- creating next block -----------------------
                tmp = tmp + """
            *add_points
            """ + str(round(var_current,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
            """ + str(round(var_current,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """

                tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

                tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

                tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

                tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """
            #------------------------------------------------
            # tip section
                tmp = tmp + """
            *add_points
            """ + str(round(var_current,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""

            """

                tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

                tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

                tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

                tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """

            #==================================================

                tmp = tmp + """
            *add_points
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
            """
            # I counted 4 nodes now

                tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

                tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

                tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

                tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """
#&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&

                tmp = tmp + """
            *add_points
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
            """

                tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

                tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

                tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

                tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            """
            #------------------------------------------------
            # tip section
                tmp = tmp + """
            *add_points
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
            """ + str(round(var_current+ac_th_for+gap,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""

            """

                tmp = tmp + """
            *add_curves
            1 2 3 4 1 3 2 4
            """

                tmp = tmp+"""
            *apply_curve_divisions
            1 2 3 4
            #
            """

                tmp = tmp+ """
            *af_planar_quadmesh
            1 4 2 3
            #
            """

                tmp = tmp+"""
            *remove_curves
            all_existing
            *remove_points
            all_existing
            
            """
                final = final +"\n"+ dedent(tmp).strip("\n")
                tmp = """"""

#&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
    #=============================
    
    
# =============Start of Ends_extend (additional support silicon layer at start and end of actuator) =====
if 1 == 1:
    LK = P_len[len(P_len)-1]
    # first create ends extend at start
    #ZXC1
    #-------------------------------------------------------    
    tmp = tmp + """
    *add_points
    """ + str(round(LK+ends_ext,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
    """ + str(round(LK+ends_ext,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
    """
    # I counted 4 nodes now

    tmp = tmp + """
    *add_curves
    1 2 3 4 1 3 2 4
    """

    tmp = tmp+"""
    *apply_curve_divisions
    1 2 3 4
    #
    """

    tmp = tmp+ """
    *af_planar_quadmesh
    1 4 2 3
    #
    """

    tmp = tmp+"""
    *remove_curves
    all_existing
    *remove_points
    all_existing
    """

    #---------------------------------------------------------
    tmp = tmp + """
    *add_points
    """ + str(round(LK+ends_ext,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(gap_height+air_vent,10))+" "+str(round(0,10))+"""
    """ + str(round(LK+ends_ext,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
    """

    tmp = tmp + """
    *add_curves
    1 2 3 4 1 3 2 4
    """

    tmp = tmp+"""
    *apply_curve_divisions
    1 2 3 4
    #
    """

    tmp = tmp+ """
    *af_planar_quadmesh
    1 4 2 3
    #
    """

    tmp = tmp+"""
    *remove_curves
    all_existing
    *remove_points
    all_existing
    """
    #------------------------------------------------
    # tip section
    tmp = tmp + """
    *add_points
    """ + str(round(LK+ends_ext,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(height-ac_th_up,10))+" "+str(round(0,10))+"""
    """ + str(round(LK+ends_ext,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(height,10))+" "+str(round(0,10))+"""

    """

    tmp = tmp + """
    *add_curves
    1 2 3 4 1 3 2 4
    """

    tmp = tmp+"""
    *apply_curve_divisions
    1 2 3 4
    #
    """

    tmp = tmp+ """
    *af_planar_quadmesh
    1 4 2 3
    #
    """

    tmp = tmp+"""
    *remove_curves
    all_existing
    *remove_points
    all_existing
    """
    #============ above paper ==============
    tmp = tmp + """
    *add_points
    """ + str(round(LK+ends_ext,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
    """ + str(round(LK+ends_ext,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(0,10))+" "+str(round(0,10))+"""
    """
    # I counted 4 nodes now

    tmp = tmp + """
    *add_curves
    1 2 3 4 1 3 2 4
    """

    tmp = tmp+"""
    *apply_curve_divisions
    1 2 3 4
    #
    """

    tmp = tmp+ """
    *af_planar_quadmesh
    1 4 2 3
    #
    """

    tmp = tmp+"""
    *remove_curves
    all_existing
    *remove_points
    all_existing
    """
    #***************************paper***************************
    tmp = tmp + """
    *add_points
    """ + str(round(LK+ends_ext,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
    """ + str(round(LK+ends_ext,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(-above_paper,10))+" "+str(round(0,10))+"""
    """
    # I counted 4 nodes now

    tmp = tmp + """
    *add_curves
    1 2 3 4 1 3 2 4
    """

    tmp = tmp+"""
    *apply_curve_divisions
    1 2 3 4
    #
    """

    tmp = tmp+ """
    *af_planar_quadmesh
    1 4 2 3
    #
    """

    tmp = tmp+"""
    *remove_curves
    all_existing
    *remove_points
    all_existing
    """
    #***********************below paper silicon layer *************
    tmp = tmp + """
    *add_points
    """ + str(round(LK+ends_ext,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(-above_paper-paper_width-below_paper,10))+" "+str(round(0,10))+"""
    """ + str(round(LK+ends_ext,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(-above_paper-paper_width,10))+" "+str(round(0,10))+"""
    """
    # I counted 4 nodes now

    tmp = tmp + """
    *add_curves
    1 2 3 4 1 3 2 4
    """

    tmp = tmp+"""
    *apply_curve_divisions
    1 2 3 4
    #
    """

    tmp = tmp+ """
    *af_planar_quadmesh
    1 4 2 3
    #
    """

    tmp = tmp+"""
    *remove_curves
    all_existing
    *remove_points
    all_existing
    
    """
    final = final + "\n"+dedent(tmp).strip("\n")
    tmp = """"""
    
    #***************************** below actuator ********************
    if below_actuator_flag == 1:

        tmp = tmp + """
    *add_points
    """ + str(round(LK+ends_ext,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
    """ + str(round(LK+ends_ext,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(R_d,10))+" "+str(round(0,10))+"""
        """
            # I counted 4 nodes now

        tmp = tmp + """
    *add_curves
    1 2 3 4 1 3 2 4
    """

        tmp = tmp+"""
    *apply_curve_divisions
    1 2 3 4
    #
    """

        tmp = tmp+ """
    *af_planar_quadmesh
    1 4 2 3
    #
    """

        tmp = tmp+"""
    *remove_curves
    all_existing
    *remove_points
    all_existing
    """
    #---------------------- creating next block -----------------------
        tmp = tmp + """
    *add_points
    """ + str(round(LK+ends_ext,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
    """ + str(round(LK+ends_ext,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(R_d-gap_height-air_vent,10))+" "+str(round(0,10))+"""
    """

        tmp = tmp + """
    *add_curves
    1 2 3 4 1 3 2 4
    """

        tmp = tmp+"""
    *apply_curve_divisions
    1 2 3 4
    #
    """

        tmp = tmp+ """
    *af_planar_quadmesh
    1 4 2 3
    #
    """

        tmp = tmp+"""
    *remove_curves
    all_existing
    *remove_points
    all_existing
    """
            #------------------------------------------------
            # tip section
        tmp = tmp + """
    *add_points
    """ + str(round(LK+ends_ext,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(R_d-xFlex_height,10))+" "+str(round(0,10))+"""
    """ + str(round(LK+ends_ext,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""
    """ + str(round(LK,10))+" "+str(round(R_d-(xFlex_height-ac_th_up),10))+" "+str(round(0,10))+"""

    """

        tmp = tmp + """
    *add_curves
    1 2 3 4 1 3 2 4
    """

        tmp = tmp+"""
    *apply_curve_divisions
    1 2 3 4
    #
    """

        tmp = tmp+ """
    *af_planar_quadmesh
    1 4 2 3
    #
    """

        tmp = tmp+"""
    *remove_curves
    all_existing
    *remove_points
    all_existing
    
    """
        final = final + "\n"+dedent(tmp).strip("\n")
        tmp = """"""
# =======================================================================================================

BoxS = """
*select_method_user_box
*select_filter_outline
*select_mode_and
*select_edges
"""

ch1_top_F = BoxS+ch1_top.split("\n",1)[1]
ch2_top_F = BoxS+ch2_top.split("\n",1)[1]
ch3_top_F = BoxS+ch3_top.split("\n",1)[1]
if remove_cmc_flag == 0:
    ch4_top_F = BoxS+ch4_top.split("\n",1)[1]

ch1_bot_F = BoxS+ch1_bot.split("\n",1)[1]
ch2_bot_F = BoxS+ch2_bot.split("\n",1)[1]
ch3_bot_F = BoxS+ch3_bot.split("\n",1)[1]
if remove_cmc_flag == 0:
    ch4_bot_F = BoxS+ch4_bot.split("\n",1)[1]
# Out:
# 0.619289
# 0.619289
# 0.619289
# 0.619289

# %% [markdown]
# # Section of code for selecting the pressurized chambers

# %%
Ch_def = """"""
Ch_def = Ch_def + """
*sweep_nodes
all_visible
*renumber_nodes
*renumber_elements
*select_clear
""" + ch1_top_F + """
*store_edges
Ch1_top
all_selected

*select_clear
""" + ch2_top_F + """
*store_edges
Ch2_top
all_selected

*select_clear
""" + ch3_top_F + """
*store_edges
Ch3_top
all_selected

*select_clear
""" + ch1_bot_F + """
*store_edges
Ch1_bot
all_selected

*select_clear
""" + ch2_bot_F + """
*store_edges
Ch2_bot
all_selected

*select_clear
""" + ch3_bot_F + """
*store_edges
Ch3_bot
all_selected

*select_clear
"""

if remove_cmc_flag == 0:
    Ch_def = Ch_def + ch4_bot_F +"\n*store_edges\nCh4_bot\nall_selected\n*select_clear" +ch4_top_F +"\n*store_edges\nCh4_top\nall_selected\n*select_clear"

#Ch_def

# %% [markdown]
# # Creating set names for actuator

# %%
#thirdflag
if remove_cmc_flag == 1:
    Actuator_set = """
*select_method_user_box
*select_filter_none
*select_mode_and
*select_elements
"""+ str(round(L1-ends_ext-paper_width/2,6))+" " + str(round(L4+ends_ext+paper_width/2,6))+"""
"""+ str(round(-above_paper-paper_width/2,6))+" " + str(round(height+paper_width/2,6))+"""
"""+ str(round(-1,6))+" "+str(round(1,6))+"""
*store_elements
Actuator_top
all_selected
*select_clear
*select_elements
"""+ str(round(L1-ends_ext-paper_width/2,6))+" " + str(round(L4+ends_ext+paper_width/2,6))+"""
"""+ str(round(-above_paper-paper_width*1.5,6))+" " + str(round(-above_paper+paper_width/2,6))+"""
"""+ str(round(-1,6))+" "+str(round(1,6))+"""
*store_elements
Paper
all_selected
*select_clear
*select_elements
"""+ str(round(L1-ends_ext-paper_width/2,6))+" " + str(round(L4+ends_ext+paper_width/2,6))+"""
"""+ str(round(R_d-xFlex_height-paper_width/2,6))+" " + str(round(-above_paper-paper_width/2,6))+"""
"""+ str(round(-1,6))+" "+str(round(1,6))+"""
*store_elements
Actuator_bot
all_selected
*select_clear
*select_nodes
"""+ str(round(L1-ends_ext-paper_width/2,6))+" " + str(round(L1-paper_width/2,6))+"""
"""+ str(round(R_d-xFlex_height-paper_width/2,6))+" " + str(round(height+paper_width/2,6))+"""
"""+ str(round(-1,6))+" "+str(round(1,6))+"""
*store_nodes
Actuator_side_fix_nodes
all_selected
*select_clear
*reset
*select_nodes
all_visible
*store_nodes
Actuator_nodes
all_selected
*select_clear
*select_elements
all_visible
*store_elements
Actuator
all_selected
*select_clear
*invisible_set Actuator *redraw
*select_clear
*reset
"""
else:
    Actuator_set = """
*select_method_user_box
*select_filter_none
*select_mode_and
*select_elements
"""+ str(round(L0-ends_ext-paper_width/2,6))+" " + str(round(L4+ends_ext+paper_width/2,6))+"""
"""+ str(round(-above_paper-paper_width/2,6))+" " + str(round(height+paper_width/2,6))+"""
"""+ str(round(-1,6))+" "+str(round(1,6))+"""
*store_elements
Actuator_top
all_selected
*select_clear
*select_elements
"""+ str(round(L0-ends_ext-paper_width/2,6))+" " + str(round(L4+ends_ext+paper_width/2,6))+"""
"""+ str(round(-above_paper-paper_width*1.5,6))+" " + str(round(-above_paper+paper_width/2,6))+"""
"""+ str(round(-1,6))+" "+str(round(1,6))+"""
*store_elements
Paper
all_selected
*select_clear
*select_elements
"""+ str(round(L0-ends_ext-paper_width/2,6))+" " + str(round(L4+ends_ext+paper_width/2,6))+"""
"""+ str(round(R_d-xFlex_height-paper_width/2,6))+" " + str(round(-above_paper-paper_width/2,6))+"""
"""+ str(round(-1,6))+" "+str(round(1,6))+"""
*store_elements
Actuator_bot
all_selected
*select_clear
*select_nodes
"""+ str(round(L0-ends_ext-paper_width/2,6))+" " + str(round(L0-paper_width/2,6))+"""
"""+ str(round(R_d-xFlex_height-paper_width/2,6))+" " + str(round(height+paper_width/2,6))+"""
"""+ str(round(-1,6))+" "+str(round(1,6))+"""
*store_nodes
Actuator_side_fix_nodes
all_selected
*select_clear
*reset
*select_nodes
all_visible
*store_nodes
Actuator_nodes
all_selected
*select_clear
*select_elements
all_visible
*store_elements
Actuator
all_selected
*select_clear
*invisible_set Actuator *redraw
*select_clear
*reset
"""

# %% [markdown]
# # Creating the finger nodes

# %%
Fing_points = """
*add_points
""" + str(round(-file[1][0]-cmc_offset,10))+" "+str(round( MOS+file[2][0],10))+" "+str(round(0,10))+""" 
""" + str(round(-file[1][1]-cmc_offset,10))+" "+str(round( MOS+file[2][1],10))+" "+str(round(0,10))+""" 
""" + str(round(-file[1][2]-cmc_offset,10))+" "+str(round( MOS+file[2][2],10))+" "+str(round(0,10))+""" 
""" + str(round(-file[1][3],10))+" "+str(round( MOS+file[2][3],10))+" "+str(round(0,10))+""" 
""" + str(round(-file[1][4],10))+" "+str(round( MOS+file[2][4],10))+" "+str(round(0,10))+""" 
""" + str(round(-file[1][5],10))+" "+str(round( MOS+file[2][5],10))+" "+str(round(0,10))+""" 
""" + str(round(-file[1][6],10))+" "+str(round( MOS+file[2][6],10))+" "+str(round(0,10))+""" 
""" + str(round(-file[1][7],10))+" "+str(round( MOS+file[2][7],10))+" "+str(round(0,10))+""" 
""" + str(round(-file[1][8],10))+" "+str(round( MOS+file[2][8],10))+" "+str(round(0,10))+""" 
""" + str(round(-file[1][9],10))+" "+str(round( MOS+file[2][9],10))+" "+str(round(0,10))+""" 
""" + str(round(-file[1][10],10))+" "+str(round( MOS+file[2][10],10))+" "+str(round(0,10))+"""  
""" + str(round(-file[1][11],10))+" "+str(round( MOS+file[2][11],10))+" "+str(round(0,10))+""" 
""" + str(round(-file[1][12],10))+" "+str(round( MOS+file[2][12],10))+" "+str(round(0,10))+""" 
""" + str(round(-file[1][13],10))+" "+str(round( MOS+file[2][13],10))+" "+str(round(0,10))+""" 
""" + str(round(-file[1][14],10))+" "+str(round( MOS+file[2][14],10))+" "+str(round(0,10))+""" 
""" + str(round(-file[1][15],10))+" "+str(round( MOS+file[2][15],10))+" "+str(round(0,10))+""" 
""" + str(round(-file[1][16],10))+" "+str(round( MOS+file[2][16],10))+" "+str(round(0,10))+""" 
""" + str(round(-file2[1][0]-cmc_offset,10))+" "+str(round( MOS+file2[2][0],10))+" "+str(round(0,10))+"""  
""" + str(round(-file2[1][1]-cmc_offset,10))+" "+str(round( MOS+file2[2][1],10))+" "+str(round(0,10))+""" 
""" + str(round(-file2[1][2]-cmc_offset,10))+" "+str(round( MOS+file2[2][2],10))+" "+str(round(0,10))+""" 
""" + str(round(-file2[1][3],10))+" "+str(round( MOS+file2[2][3],10))+" "+str(round(0,10))+""" 
""" + str(round(-file2[1][4],10))+" "+str(round( MOS+file2[2][4],10))+" "+str(round(0,10))+""" 
""" + str(round(-file2[1][5],10))+" "+str(round( MOS+file2[2][5],10))+" "+str(round(0,10))+"""  
""" + str(round(-file2[1][6],10))+" "+str(round( MOS+file2[2][6],10))+" "+str(round(0,10))+""" 
""" + str(round(-file2[1][7],10))+" "+str(round( MOS+file2[2][7],10))+" "+str(round(0,10))+""" 
""" + str(round(-file2[1][8],10))+" "+str(round( MOS+file2[2][8],10))+" "+str(round(0,10))+""" 
""" + str(round(-file2[1][9],10))+" "+str(round( MOS+file2[2][9],10))+" "+str(round(0,10))+""" 
""" + str(round(-file2[1][10],10))+" "+str(round( MOS+file2[2][10],10))+" "+str(round(0,10))+""" 
""" + str(round(-file2[1][11],10))+" "+str(round( MOS+file2[2][11],10))+" "+str(round(0,10))+""" 
""" + str(round(-file2[1][12],10))+" "+str(round( MOS+file2[2][12],10))+" "+str(round(0,10))+""" 
""" + str(round(-file2[1][13],10))+" "+str(round( MOS+file2[2][13],10))+" "+str(round(0,10))+""" 
""" + str(round(-file2[1][14],10))+" "+str(round( MOS+file2[2][14],10))+" "+str(round(0,10))+""" 
""" + str(round(-file2[1][15],10))+" "+str(round( MOS+file2[2][15],10))+" "+str(round(0,10))+""" 
""" + str(round(-file2[1][16],10))+" "+str(round( MOS+file2[2][16],10))+" "+str(round(0,10))+""" 
""" + str(round(-file[1][5]-Fing_MCP_T*CS,10))+" "+str(round( MOS+file[2][5]+Fing_MCP_B*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][3]-Fing_MCP_T,10))+" "+str(round( MOS+file2[2][3],10))+" "+str(round(0,10))+"""
""" + str(round(-file[1][4]-Fing_MCP_T*CS,10))+" "+str(round( MOS+file[2][4]-Fing_MCP_T*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file[1][5]+Fing_MCP_T*CS,10))+" "+str(round( MOS+file[2][5]+Fing_MCP_B*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][3]+Fing_MCP_T,10))+" "+str(round( MOS+file2[2][3],10))+" "+str(round(0,10))+"""
""" + str(round(-file[1][4]+Fing_MCP_T*CS,10))+" "+str(round( MOS+file[2][4]-Fing_MCP_T*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][5]-Bone_MCP_T*CS,10))+" "+str(round( MOS+file2[2][5]+Bone_MCP_B*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][3]-Bone_MCP_T,10))+" "+str(round( MOS+file2[2][3],10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][4]-Bone_MCP_T*CS,10))+" "+str(round( MOS+file2[2][4]-Bone_MCP_T*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][5]+Bone_MCP_T*CS,10))+" "+str(round( MOS+file2[2][5]+Bone_MCP_B*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][3]+Bone_MCP_T,10))+" "+str(round( MOS+file2[2][3],10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][4]+Bone_MCP_T*CS,10))+" "+str(round( MOS+file2[2][4]-Bone_MCP_T*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file[1][8]-Fing_PIP_T*CS,10))+" "+str(round( MOS+file[2][8]+Fing_PIP_B*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][6]-Fing_PIP_T,10))+" "+str(round( MOS+file2[2][6],10))+" "+str(round(0,10))+"""
""" + str(round(-file[1][7]-Fing_PIP_T*CS,10))+" "+str(round( MOS+file[2][7]-Fing_PIP_T*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file[1][8]+Fing_PIP_T*CS,10))+" "+str(round( MOS+file[2][8]+Fing_PIP_B*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][6]+Fing_PIP_T,10))+" "+str(round( MOS+file2[2][6],10))+" "+str(round(0,10))+"""
""" + str(round(-file[1][7]+Fing_PIP_T*CS,10))+" "+str(round( MOS+file[2][7]-Fing_PIP_T*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][8]-Bone_PIP_T*CS,10))+" "+str(round( MOS+file2[2][8]+Bone_PIP_B*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][6]-Bone_PIP_T,10))+" "+str(round( MOS+file2[2][6],10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][7]-Bone_PIP_T*CS,10))+" "+str(round( MOS+file2[2][7]-Bone_PIP_T*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][8]+Bone_PIP_T*CS,10))+" "+str(round( MOS+file2[2][8]+Bone_PIP_B*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][6]+Bone_PIP_T,10))+" "+str(round( MOS+file2[2][6],10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][7]+Bone_PIP_T*CS,10))+" "+str(round( MOS+file2[2][7]-Bone_PIP_T*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file[1][11]-Fing_DIP_T*CS,10))+" "+str(round( MOS+file[2][11]+Fing_DIP_B*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][9]-Fing_DIP_T,10))+" "+str(round( MOS+file2[2][9],10))+" "+str(round(0,10))+"""
""" + str(round(-file[1][10]-Fing_DIP_T*CS,10))+" "+str(round( MOS+file[2][10]-Fing_DIP_T*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file[1][11]+Fing_DIP_T*CS,10))+" "+str(round( MOS+file[2][11]+Fing_DIP_B*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][9]+Fing_DIP_T,10))+" "+str(round( MOS+file2[2][9],10))+" "+str(round(0,10))+"""
""" + str(round(-file[1][10]+Fing_DIP_T*CS,10))+" "+str(round( MOS+file[2][10]-Fing_DIP_T*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][11]-Bone_DIP_T*CS,10))+" "+str(round( MOS+file2[2][11]+Bone_DIP_B*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][9]-Bone_DIP_T,10))+" "+str(round( MOS+file2[2][9],10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][10]-Bone_DIP_T*CS,10))+" "+str(round( MOS+file2[2][10]-Bone_DIP_T*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][11]+Bone_DIP_T*CS,10))+" "+str(round( MOS+file2[2][11]+Bone_DIP_B*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][9]+Bone_DIP_T,10))+" "+str(round( MOS+file2[2][9],10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][10]+Bone_DIP_T*CS,10))+" "+str(round( MOS+file2[2][10]-Bone_DIP_T*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file[1][14]+Fing_DP_End_T*CS,10))+" "+str(round( MOS+file[2][14]+Fing_DP_End_B*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file[1][13]+Fing_DP_End_T*CS,10))+" "+str(round( MOS+file[2][13]-Fing_DP_End_T*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][14]+Bone_DP_End_T*CS,10))+" "+str(round( MOS+file2[2][14]+Bone_DP_End_B*(1-CS),10))+" "+str(round(0,10))+"""
""" + str(round(-file2[1][13]+Bone_DP_End_T*CS,10))+" "+str(round( MOS+file2[2][13]-Bone_DP_End_T*(1-CS),10))+" "+str(round(0,10))+"""
"""
# Out:
# *add_points
# -0.08614 -0.02434 0
# -0.08614 -0.0142 0
# -0.08614 -0.03593 0
# 0.02626 -0.02434 0
# 0.02626 -0.0142 0
# 0.02626 -0.03593 0
# 0.07684 -0.02263 0
# 0.07684 -0.0142 0
# 0.07684 -0.03092 0
# 0.10732 -0.01987 0
# 0.10732 -0.0142 0
# 0.10732 -0.0268 0
# 0.12849 -0.01953 0
# 0.12849 -0.0142 0
# 0.12849 -0.02487 0
# 0.13382 -0.01945 0
# 0.1185 -0.0265 0
# -0.08614 -0.02434 0
# -0.08614 -0.01912 0
# -0.08614 -0.02956 0
# 0.02626 -0.02434 0
# 0.02626 -0.01912 0
# 0.02626 -0.02956 0
# 0.07684 -0.02263 0
# 0.07684 -0.01896 0
# 0.07684 -0.026 0
# 0.10732 -0.01987 0
# 0.10732 -0.01789 0
# 0.10732 -0.02221 0
# 0.12812 -0.01954 0
# 0.12812 -0.0181 0
# 0.12812 -0.02098 0
# 0.12956 -0.01952 0
# 0.11665 -0.02188 0
# 0.017134 -0.034771 0
# 0.01612 -0.02434 0
# 0.017134 -0.015214 0
# 0.035386 -0.034771 0
# 0.0364 -0.02434 0
# 0.035386 -0.015214 0
# 0.021562 -0.029038 0
# 0.02104 -0.02434 0
# 0.021562 -0.019642 0
# 0.030958 -0.029038 0
# 0.03148 -0.02434 0
# 0.030958 -0.019642 0
# ...

# %%
Create_finger = """
*set_curve_type line
*add_curves
3
6
20
23
1
4
19
22
2
5
3
20
20
1
1
19
19
2
6
23
23
4
4
22
22
5
4
45
*set_curve_type bezier
*add_curves
6
38
39
# | End of List
39
40
5
# | End of List
23
44
45
# | End of List
45
46
22
# | End of List
*set_curve_type line
*add_curves
45
39
*prog_option geometry_and_mesh:mesh_cv_div_uniform:target_length
*prog_param geometry_and_mesh:mesh_cv_div_target_length """+str(round(meshsize,6))+"""
*apply_curve_divisions
all_visible
*af_planar_quadmesh
6
1
10
2
# | End of List
10
15
19
17
# | End of List
19
16
18
# | End of List
18
19
16
13
# | End of List
4
13
5
9
# | End of List
*store_elements
CMC_Flesh
all_visible
*store_nodes
CMC_Flesh_nodes
all_visible
*invisible_set CMC_Flesh *redraw
*af_planar_quadmesh
7
2
11
3
# | End of List
3
12
4
8
# | End of List
11
17
14
# | End of List
14
18
12
# | End of List
*store_elements
CMC_Bone
all_visible
*store_nodes
CMC_Bone_nodes
all_visible
*invisible_set CMC_Bone *redraw

*remove_curves
all_visible
*add_curves
6
9
6
23
23
4
4
22
22
5
4
42
42
36
4
7
9
26
26
7
7
25
25
8
5
8
*set_curve_type bezier
*add_curves
6
35
36
# | End of List
36
37
5
# | End of List
42
43
22
# | End of List
23
41
42
# | End of List
9
50
51
# | End of List
26
56
57
# | End of List
57
58
25
# | End of List
51
52
8
# | End of List
*set_curve_type line
*add_curves
23
26
7
57
57
51
22
25
*apply_curve_divisions
all_visible

*af_planar_quadmesh
2
1
9
22
# | End of List
9
18
24
19
# | End of List
24
21
12
20
# | End of List
25
12
13
5
# | End of List
7
16
5
15
# | End of List
14
2
17
7
# | End of List
*store_elements
PP_Flesh
all_visible
*store_nodes
PP_Flesh_nodes
all_visible
*invisible_set PP_Flesh *redraw
*af_planar_quadmesh
17
3
6
# | End of List
6
4
16
# | End of List
4
8
11
25
# | End of List
8
10
22
3
# | End of List
10
19
23
# | End of List
23
20
11
# | End of List
*store_elements
PP_Bone
all_visible
*store_nodes
PP_Bone_nodes
all_visible
*invisible_set PP_Bone *redraw

*remove_curves
all_visible
*add_curves
9
12
26
29
7
10
25
28
8
11
48
54
54
7
10
69
69
63
9
26
26
7
7
25
25
8
12
29
29
10
10
28
28
11
*set_curve_type bezier
*add_curves
12
62
63
# | End of List
63
64
11
# | End of List
29
68
69
# | End of List
69
70
28
# | End of List
25
55
54
# | End of List
26
53
54
# | End of List
9
47
48
# | End of List
48
49
8
# | End of List
*apply_curve_divisions
all_visible
*af_planar_quadmesh
10
1
14
2
# | End of List
14
18
9
20
# | End of List
21
9
19
17
# | End of List
4
17
5
13
# | End of List
24
10
23
6
# | End of List
6
22
13
25
# | End of List
*store_elements
MP_Flesh
all_visible
*store_nodes
MP_Flesh_nodes
all_visible
*invisible_set MP_Flesh *redraw
*af_planar_quadmesh
11
2
15
3
# | End of List
15
20
8
# | End of List
8
21
16
# | End of List
3
16
4
12
# | End of List
23
11
7
# | End of List
7
12
22
# | End of List
*store_elements
MP_Bone
all_visible
*store_nodes
MP_Bone_nodes
all_visible
*invisible_set MP_Bone *redraw
*remove_curves
all_visible

*set_curve_type line
*add_curves
30
31
30
32
30
33
30
10
12
29
29
10
10
28
28
11
10
66
66
60
31
14
32
15
33
16
*set_curve_type bezier
*add_curves
12
17
15
# | End of List
15
71
16
# | End of List
16
72
14
# | End of List
32
73
33
# | End of List
33
74
31
# | End of List
29
34
32
# | End of List
12
59
60
# | End of List
29
65
66
# | End of List
60
61
11
# | End of List
66
67
28
# | End of List
*set_curve_type line
*add_curves
28
31
11
14
*apply_curve_divisions
all_visible
*af_planar_quadmesh
5
14
12
19
# | End of List
12
15
13
17
# | End of List
13
16
11
18
# | End of List
24
11
25
8
# | End of List
10
23
8
22
# | End of List
20
5
21
10
# | End of List
*store_elements
DP_Flesh
all_visible
*store_nodes
DP_Flesh_nodes
all_visible
*invisible_set DP_Flesh *redraw
*af_planar_quadmesh
6
19
2
4
# | End of List
2
17
3
# | End of List
3
18
1
# | End of List
4
1
24
# | End of List
4
1
24
7
# | End of List
9
7
23
# | End of List
21
6
9
# | End of List
*store_elements
DP_Bone
all_visible
*store_nodes
DP_Bone_nodes
all_visible
*remove_curves
all_visible
*invisible_set DP_Bone *redraw

*visible_set CMC_Flesh *redraw
*visible_set CMC_Bone *redraw
*sweep_nodes
all_visible
*renumber_nodes
*renumber_elements
*store_elements
CMC
all_visible
*invisible_set CMC *redraw
*visible_set PP_Flesh *redraw
*visible_set PP_Bone *redraw
*sweep_nodes
all_visible
*renumber_nodes
*renumber_elements
*store_elements
PP
all_visible
*invisible_set PP *redraw
*visible_set MP_Flesh *redraw
*visible_set MP_Bone *redraw
*sweep_nodes
all_visible
*renumber_nodes
*renumber_elements
*store_elements
MP
all_visible
*invisible_set MP *redraw
*visible_set DP_Bone *redraw
*visible_set DP_Flesh *redraw
*sweep_nodes
all_visible
*renumber_nodes
*renumber_elements
*store_elements
DP
all_visible
*invisible_set DP *redraw
*select_clear
*sweep_elements
Actuator
#
"""

# %% [markdown]
# # Defines fingers and bones

# %%
Def_Fing = """
*visible_set CMC_Bone
*visible_set PP_Bone
*visible_set MP_Bone
*visible_set DP_Bone
*redraw
*store_elements
Bones
all_visible
*invisible_elements
all_existing
*redraw
*visible_set CMC_Flesh
*visible_set PP_Flesh
*visible_set MP_Flesh
*visible_set DP_Flesh
*redraw
*store_elements
Flesh
all_visible
*invisible_elements
all_existing
*redraw
*visible_set Flesh
*visible_set Bones
*store_elements
Finger
all_visible
*redraw
*invisible_elements
all_existing
*redraw
*visible_set Finger
*redraw
*store_nodes
Finger_nodes
all_visible
*invisible_elements
all_existing
*redraw
"""

# %% [markdown]
# # Selects finger side to be fixed
# Also selects the centers for joints into a set

# %%
finger_fixed = """
*select_method_user_box
*select_filter_none
*select_mode_and
*select_elements
*select_nodes 
"""+ str(round(-file[1][0]-cmc_offset-paper_width/2,6))+" " + str(round(-file[1][0]-cmc_offset+0.000001,6))+""" 
"""+ str(round(R_d-xFlex_height-(Fing_MCP_T+Fing_MCP_B)-paper_width/2,6))+" " + str(round(R_d-xFlex_height+paper_width/2,6))+""" 
"""+ str(round(-1,6))+" "+str(round(1,6))+"""
*select_mode_except
*select_sets Actuator_nodes
*select_mode_and
*store_nodes
Finger_side_fix_nodes
all_selected
*select_clear
*reset


*select_method_user_box
*select_filter_none
*select_mode_and
*select_elements
*select_nodes 
"""+ str(round(-file[1][9]-0.000001,7))+" " + str(round(-file[1][9]+0.000001,7))+""" 
"""+ str(round(MOS+file[2][9]-0.000001,7))+" " + str(round(MOS+file[2][9]+0.000001,7))+""" 
"""+ str(round(-1,7))+" "+str(round(1,7))+"""
*select_nodes 
"""+ str(round(-file[1][6]-0.000001,7))+" " + str(round(-file[1][6]+0.000001,7))+""" 
"""+ str(round(MOS+file[2][6]-0.000001,7))+" " + str(round(MOS+file[2][6]+0.000001,7))+""" 
"""+ str(round(-1,7))+" "+str(round(1,7))+"""
*select_nodes 
"""+ str(round(-file[1][3]-0.000001,7))+" " + str(round(-file[1][3]+0.000001,7))+""" 
"""+ str(round(MOS+file[2][3]-0.000001,7))+" " + str(round(MOS+file[2][3]+0.000001,7))+""" 
"""+ str(round(-1,7))+" "+str(round(1,7))+"""
*store_nodes
Joint_centers
all_selected
*select_clear
*reset
"""

# %% [markdown]
# # Setting up the model to be run

# %%
setup = """"""

setup = setup + """

*new_pre_defined_table linear_ramp_time
*table_name linear_ramp
*new_pre_defined_table linear_ramp_up_down_time
*table_name linear_ramp_up_down
"""

if Moon_or_Ogden == 1:
    setup = setup +"""*new_mater standard *mater_option general:state:solid *mater_option general:skip_structural:off
*mater_option structural:type:mooney
*mater_name """+Sil_name+"""
*mater_param structural:mooney_c10 """+str(Sil_Mooney_C10)+"""
*mater_param structural:mooney_c01 """+str(Sil_Mooney_C01)+"""
*mater_param structural:mooney_c20 """+str(Sil_Mooney_C20)+"""
*mater_param general:mass_density 2000
*mater_option structural:bulk_modulus:user
*mater_param structural:bulk_modulus """+str(bulk)+"""
*add_mater_elements
all_visible
# | End of List
*edit_mater """+Sil_name+"""
*add_mater_elements
Actuator_top
Actuator_bot
#
"""
else: 
    setup = setup +"""*new_mater standard *mater_option general:state:solid *mater_option general:skip_structural:off
*mater_option structural:type:ogden
*mater_name """+Sil_name+"""
*mater_param structural:ogden_nterm 3
*mater_param structural:ogden_modulus_1 """+str(Sil_Ogden_M1)+"""
*mater_param structural:ogden_exp_1 """+str(Sil_Ogden_E1)+"""
*mater_param structural:ogden_modulus_2 """+str(Sil_Ogden_M2)+"""
*mater_param structural:ogden_exp_2 """+str(Sil_Ogden_E2)+"""
*mater_param structural:ogden_modulus_3 """+str(Sil_Ogden_M3)+"""
*mater_param structural:ogden_exp_3 """+str(Sil_Ogden_E3)+"""
*mater_param general:mass_density 2000
*mater_option structural:bulk_modulus:user
*mater_param structural:bulk_modulus """+str(bulk)+"""
*add_mater_elements
all_visible
# | End of List
*edit_mater """+Sil_name+"""
*add_mater_elements
Actuator_top
Actuator_bot
#
"""    

setup = setup+"""*new_mater standard *mater_option general:state:solid *mater_option general:skip_structural:off
*mater_name Mat_Bone
*mater_param general:mass_density 2000
*mater_param structural:youngs_modulus 1.75e10
*mater_param structural:poissons_ratio 0.3
*edit_mater Mat_Bone
*add_mater_elements
CMC_Bone
PP_Bone
MP_Bone
DP_Bone
#
"""
if flesh_nonlinear_flag == 1:
    setup = setup + """
*new_mater standard *mater_option general:state:solid *mater_option general:skip_structural:off
*mater_name Mat_Flesh_DP
*mater_param general:mass_density 2000
*mater_option structural:type:mooney
*mater_param structural:mooney_c10 1704
*mater_param structural:mooney_c01 8160

*edit_mater Mat_Flesh_DP
*add_mater_elements
DP_Flesh
#

*new_mater standard *mater_option general:state:solid *mater_option general:skip_structural:off
*mater_name Mat_Flesh_MP
*mater_param general:mass_density 1500
*mater_option structural:type:mooney
*mater_param structural:mooney_c10 1278
*mater_param structural:mooney_c01 6120

*edit_mater Mat_Flesh_MP
*add_mater_elements
MP_Flesh
#
 
*new_mater standard *mater_option general:state:solid *mater_option general:skip_structural:off
*mater_name Mat_Flesh_PP
*mater_param general:mass_density 4000
*mater_option structural:type:mooney
*mater_param structural:mooney_c10 1278
*mater_param structural:mooney_c01 6120

*edit_mater Mat_Flesh_PP
*add_mater_elements
PP_Flesh
CMC_Flesh
#

"""
else:
    setup = setup + """
*new_mater standard *mater_option general:state:solid *mater_option general:skip_structural:off
*mater_name Mat_Flesh_DP
*mater_param general:mass_density 2000
*mater_param structural:youngs_modulus 24e3
*mater_param structural:poissons_ratio 0.4

*edit_mater Mat_Flesh_DP
*add_mater_elements
DP_Flesh
#

*new_mater standard *mater_option general:state:solid *mater_option general:skip_structural:off
*mater_name Mat_Flesh_MP
*mater_param general:mass_density 1500
*mater_param structural:youngs_modulus 24e3
*mater_param structural:poissons_ratio 0.4

*edit_mater Mat_Flesh_MP
*add_mater_elements
MP_Flesh
#
 
*new_mater standard *mater_option general:state:solid *mater_option general:skip_structural:off
*mater_name Mat_Flesh_PP
*mater_param general:mass_density 4000
*mater_param structural:youngs_modulus 24e3
*mater_param structural:poissons_ratio 0.4

*edit_mater Mat_Flesh_PP
*add_mater_elements
PP_Flesh
CMC_Flesh
#    
"""    
    
setup = setup + """        

*new_mater standard *mater_option general:state:solid *mater_option general:skip_structural:off
*mater_name Mat_Paper
*mater_param structural:youngs_modulus 0.3e9
*mater_param structural:poissons_ratio 0.33
*mater_param general:mass_density 800

*edit_mater Mat_Paper
*add_mater_elements
Paper
#

*new_cbody mesh *contact_option state:solid *contact_option skip_structural:off
*contact_body_name Con_Actuator
*edit_contact_body Con_Actuator
*add_contact_body_elements
Actuator
#

*new_cbody mesh *contact_option state:solid *contact_option skip_structural:off
*contact_body_name Con_CMC
*edit_contact_body Con_CMC
*add_contact_body_elements
CMC
#

*new_cbody mesh *contact_option state:solid *contact_option skip_structural:off
*contact_body_name Con_PP
*edit_contact_body Con_PP
*add_contact_body_elements
PP
#

*new_cbody mesh *contact_option state:solid *contact_option skip_structural:off
*contact_body_name Con_MP
*edit_contact_body Con_MP
*add_contact_body_elements
MP
#

*new_cbody mesh *contact_option state:solid *contact_option skip_structural:off
*contact_body_name Con_DP
*edit_contact_body Con_DP
*add_contact_body_elements
DP
#

*new_interact mesh:mesh *interact_option state_1:solid *interact_option state_2:solid
*interact_name interact_MD_to_MD_Glued
*interact_option contact_type:glue
*interact_option delay_slide_off:on
*interact_option project_stress_free:on
*new_interact mesh:mesh *interact_option state_1:solid *interact_option state_2:solid
*interact_name interact_MD_to_MD_Touch
*new_contact_table

*ctable_entry Con_Actuator Con_Actuator
*contact_table_option Con_Actuator Con_Actuator contact:on
*prog_string ctable:old_interact interact_MD_to_MD_Touch *ctable_entry_interact Con_Actuator Con_Actuator
*edit_contact_table ctable1

*ctable_entry Con_Actuator Con_CMC
*contact_table_option Con_Actuator Con_CMC contact:on
*prog_string ctable:old_interact interact_MD_to_MD_Touch *ctable_entry_interact Con_Actuator Con_CMC
*ctable_entry Con_Actuator Con_PP
*contact_table_option Con_Actuator Con_PP contact:on
*prog_string ctable:old_interact interact_MD_to_MD_Touch *ctable_entry_interact Con_Actuator Con_PP
*ctable_entry Con_Actuator Con_MP
*contact_table_option Con_Actuator Con_MP contact:on
*prog_string ctable:old_interact interact_MD_to_MD_Touch *ctable_entry_interact Con_Actuator Con_MP
*ctable_entry Con_Actuator Con_DP
*contact_table_option Con_Actuator Con_DP contact:on
*prog_string ctable:old_interact interact_MD_to_MD_Touch *ctable_entry_interact Con_Actuator Con_DP



*new_apply *apply_type fixed_displacement
*apply_name Fixed_side
*apply_dof x *apply_dof_value x
*apply_dof y *apply_dof_value y
*edit_apply Fixed_side
*add_apply_nodes
Finger_side_fix_nodes
#

*new_apply *apply_type fixed_displacement
*apply_name Sliding_actuator_side
*apply_dof y *apply_dof_value y
*edit_apply Sliding_actuator_side
*add_apply_nodes
Actuator_side_fix_nodes
#

*auto_arrow_length 0.01
*arrows_solid
*redraw

*new_apply *apply_type edge_load *apply_option edge_load_mode:area
*apply_name
Pressure_ch1top
*apply_dof p *apply_dof_value p """+str(pressure_ch1top)+"""
*edit_apply Pressure_ch1top
*apply_dof_table p
linear_ramp
*add_apply_edges
Ch1_top
#

*new_apply *apply_type edge_load *apply_option edge_load_mode:area
*apply_name
Pressure_ch2top
*apply_dof p *apply_dof_value p """+str(pressure_ch2top)+"""
*edit_apply Pressure_ch2top
*apply_dof_table p
linear_ramp
*add_apply_edges
Ch2_top
#

*new_apply *apply_type edge_load *apply_option edge_load_mode:area
*apply_name
Pressure_ch3top
*apply_dof p *apply_dof_value p """+str(pressure_ch3top)+"""
*edit_apply Pressure_ch3top
*apply_dof_table p
linear_ramp
*add_apply_edges
Ch3_top
#

*new_apply *apply_type edge_load *apply_option edge_load_mode:area
*apply_name
Pressure_ch1bot
*apply_dof p *apply_dof_value p """+str(pressure_ch1bot)+"""
*edit_apply Pressure_ch1bot
*apply_dof_table p
linear_ramp
*add_apply_edges
Ch1_bot
#

*new_apply *apply_type edge_load *apply_option edge_load_mode:area
*apply_name
Pressure_ch2bot
*apply_dof p *apply_dof_value p """+str(pressure_ch2bot)+"""
*edit_apply Pressure_ch2bot
*apply_dof_table p
linear_ramp
*add_apply_edges
Ch2_bot
#

*new_apply *apply_type edge_load *apply_option edge_load_mode:area
*apply_name
Pressure_ch3bot
*apply_dof p *apply_dof_value p """+str(pressure_ch3bot)+"""
*edit_apply Pressure_ch3bot
*apply_dof_table p
linear_ramp
*add_apply_edges
Ch3_bot
#
"""
if remove_cmc_flag == 0:
    setup = setup + """
*new_apply *apply_type edge_load *apply_option edge_load_mode:area
*apply_name
Pressure_ch4top
*apply_dof p *apply_dof_value p """+str(pressure_ch4top)+"""
*edit_apply Pressure_ch4top
*apply_dof_table p
linear_ramp
*add_apply_edges
Ch4_top
#

*new_apply *apply_type edge_load *apply_option edge_load_mode:area
*apply_name
Pressure_ch4bot
*apply_dof p *apply_dof_value p """+str(pressure_ch4bot)+"""
*edit_apply Pressure_ch4bot
*apply_dof_table p
linear_ramp
*add_apply_edges
Ch4_bot
#
"""

setup = setup + """
*new_loadcase *loadcase_type struc:static
*loadcase_ctable
ctable1
*edit_loadcase lcase1
*loadcase_option stepping:multicriteria
*loadcase_value desired 30

*prog_use_current_job on *new_job structural
*add_job_loadcases lcase1
*job_contact_table
ctable1
*job_option follow:on
*job_option follow:stiffness

*point_display_on
*node_display_on
*redraw
*invisible_elements
all_existing
*redraw

*reset

*point_display_on
*node_display_on
*redraw

*reset

*add_nodes
""" + str(round(-file[1][3],10))+" "+str(round( MOS+file[2][3],10))+" "+str(round(0,10))+"""
*select_mode_and
*select_method_user_box
*select_filter_none
*select_nodes """+str(round(-file[1][3]-1e-5,6))+" "+str(round(-file[1][3]+1e-5,6))+" "+str( round(MOS+file[2][3]-1e-5,6))+" "+str( round(MOS+file[2][3]+1e-5,6))+" -0.500000000000e-03 0.500000000000e-03"+"""

*select_mode_except
*select_method_single
*select_filter_none
*select_sets Finger_nodes

*select_mode_and
*select_method_user_box
*select_filter_none

*add_apply_nodes
all_selected
# | End of List

*store_nodes
G0
all_selected
*select_clear


*add_nodes
"""+str(round(-file[1][3],10))+" "+str(round( MOS+file[2][3],10))+" "+str(round(0,10))+"""

*select_mode_and
*select_method_user_box
*select_filter_none
*select_nodes """+str(round(-file[1][3]-1e-5,6))+" "+str(round(-file[1][3]+1e-5,6))+" "+str( round(MOS+file[2][3]-1e-5,6))+" "+str( round(MOS+file[2][3]+1e-5,6))+" -0.500000000000e-03 0.500000000000e-03"+"""

*select_mode_except
*select_method_single
*select_filter_none
*select_sets Finger_nodes

*select_mode_and
*select_method_user_box
*select_filter_none

*select_mode_except
*select_sets G0
*store_nodes
G1
all_selected
*select_clear


*add_nodes
"""+str(round(-file[1][6],10))+" "+str(round( MOS+file[2][6],10))+" "+str(round(0,10))+""" 

*select_mode_and
*select_method_user_box
*select_filter_none
*select_nodes """+str(round(-file[1][6]-1e-5,6))+" "+str(round(-file[1][6]+1e-5,6))+" "+str( round(MOS+file[2][6]-1e-5,6))+" "+str( round(MOS+file[2][6]+1e-5,6))+" -0.500000000000e-03 0.500000000000e-03"+"""


*select_mode_except
*select_method_single
*select_filter_none
*select_sets Finger_nodes

*select_mode_and
*select_method_user_box
*select_filter_none

*add_apply_nodes
all_selected
# | End of List
*store_nodes
G2
all_selected
*select_clear

*add_nodes
"""+str(round(-file[1][6],10))+" "+str(round( MOS+file[2][6],10))+" "+str(round(0,10))+"""

*select_mode_and
*select_method_user_box
*select_filter_none
*select_nodes """+str(round(-file[1][6]-1e-5,6))+" "+str(round(-file[1][6]+1e-5,6))+" "+str( round(MOS+file[2][6]-1e-5,6))+" "+str( round(MOS+file[2][6]+1e-5,6))+" -0.500000000000e-03 0.500000000000e-03"+"""

*select_mode_except
*select_method_single
*select_filter_none
*select_sets Finger_nodes

*select_mode_and
*select_method_user_box
*select_filter_none

*select_mode_except
*select_sets G2
*store_nodes
G3
all_selected
*select_clear

*add_nodes
"""+str(round(-file[1][9],10))+" "+str(round( MOS+file[2][9],10))+" "+str(round(0,10))+"""

*select_mode_and
*select_method_user_box
*select_filter_none
*select_nodes """+str(round(-file[1][9]-1e-5,6))+" "+str(round(-file[1][9]+1e-5,6))+" "+str( round(MOS+file[2][9]-1e-5,6))+" "+str( round(MOS+file[2][9]+1e-5,6))+" -0.500000000000e-03 0.500000000000e-03"+"""

*select_mode_except
*select_method_single
*select_filter_none
*select_sets Finger_nodes

*select_mode_and
*select_method_user_box
*select_filter_none

*add_apply_nodes
all_selected
# | End of List
*store_nodes
G4
all_selected
*select_clear

*add_nodes
"""+str(round(-file[1][9],10))+" "+str(round( MOS+file[2][9],10))+" "+str(round(0,10))+"""

*select_mode_and
*select_method_user_box
*select_filter_none
*select_nodes """+str(round(-file[1][9]-1e-5,6))+" "+str(round(-file[1][9]+1e-5,6))+" "+str( round(MOS+file[2][9]-1e-5,6))+" "+str( round(MOS+file[2][9]+1e-5,6))+" -0.500000000000e-03 0.500000000000e-03"+"""

*select_mode_except
*select_method_single
*select_filter_none
*select_sets Finger_nodes

*select_mode_and
*select_method_user_box
*select_filter_none

*select_mode_except
*select_sets G4
*store_nodes
G5
all_selected
*select_clear
*reset

*reset
*select_method_user_box
*select_filter_none
*select_mode_and
*select_nodes 
"""+ str(round(-file[1][3]-0.000001,7))+" " + str(round(-file[1][3]+0.000001,7))+""" 
"""+ str(round(MOS+file[2][3]-Bone_MCP_B,7))+" " + str(round(MOS+file[2][3]+Bone_MCP_T,7))+""" 
"""+ str(round(-1,7))+" "+str(round(1,7))+"""
*select_mode_except
*select_sets PP_Bone_nodes
*select_sets PP_Flesh_nodes
*select_sets G0
*select_sets G1
*select_sets G2
*select_sets G3
*select_sets G4
*select_sets G5
*select_mode_and
*store_nodes
Joint_MCP_CMC_side_nodes
all_selected
*select_clear
*reset

*reset
*select_method_user_box
*select_filter_none
*select_mode_and
*select_nodes 
"""+ str(round(-file[1][3]-0.000001,7))+" " + str(round(-file[1][3]+0.000001,7))+""" 
"""+ str(round(MOS+file[2][3]-Bone_MCP_B,7))+" " + str(round(MOS+file[2][3]+Bone_MCP_T,7))+""" 
"""+ str(round(-1,7))+" "+str(round(1,7))+"""
*select_mode_except
*select_sets CMC_Bone_nodes
*select_sets CMC_Flesh_nodes
*select_sets G0
*select_sets G1
*select_sets G2
*select_sets G3
*select_sets G4
*select_sets G5
*select_mode_and
*store_nodes
Joint_MCP_PP_side_nodes
all_selected
*select_clear
*reset

*reset
*select_method_user_box
*select_filter_none
*select_mode_and
*select_nodes 
"""+ str(round(-file[1][6]-0.000001,7))+" " + str(round(-file[1][6]+0.000001,7))+""" 
"""+ str(round(MOS+file[2][6]-Bone_PIP_B,7))+" " + str(round(MOS+file[2][6]+Bone_PIP_T,7))+""" 
"""+ str(round(-1,7))+" "+str(round(1,7))+"""
*select_mode_except
*select_sets PP_Bone_nodes
*select_sets PP_Flesh_nodes
*select_sets G0
*select_sets G1
*select_sets G2
*select_sets G3
*select_sets G4
*select_sets G5
*select_mode_and
*store_nodes
Joint_PIP_MP_side_nodes
all_selected
*select_clear
*reset

*reset
*select_method_user_box
*select_filter_none
*select_mode_and
*select_nodes 
"""+ str(round(-file[1][6]-0.000001,7))+" " + str(round(-file[1][6]+0.000001,7))+""" 
"""+ str(round(MOS+file[2][6]-Bone_PIP_B,7))+" " + str(round(MOS+file[2][6]+Bone_PIP_T,7))+""" 
"""+ str(round(-1,7))+" "+str(round(1,7))+"""
*select_mode_except
*select_sets MP_Bone_nodes
*select_sets MP_Flesh_nodes
*select_sets G0
*select_sets G1
*select_sets G2
*select_sets G3
*select_sets G4
*select_sets G5
*select_mode_and
*store_nodes
Joint_PIP_PP_side_nodes
all_selected
*select_clear
*reset

*reset
*select_method_user_box
*select_filter_none
*select_mode_and
*select_nodes 
"""+ str(round(-file[1][9]-0.000001,7))+" " + str(round(-file[1][9]+0.000001,7))+""" 
"""+ str(round(MOS+file[2][9]-Bone_DIP_B,7))+" " + str(round(MOS+file[2][9]+Bone_DIP_T,7))+""" 
"""+ str(round(-1,7))+" "+str(round(1,7))+"""
*select_mode_except
*select_sets MP_Bone_nodes
*select_sets MP_Flesh_nodes
*select_sets G0
*select_sets G1
*select_sets G2
*select_sets G3
*select_sets G4
*select_sets G5
*select_mode_and
*store_nodes
Joint_DIP_DP_side_nodes
all_selected
*select_clear
*reset

*reset
*select_method_user_box
*select_filter_none
*select_mode_and
*select_nodes 
"""+ str(round(-file[1][9]-0.000001,7))+" " + str(round(-file[1][9]+0.000001,7))+""" 
"""+ str(round(MOS+file[2][9]-Bone_DIP_B,7))+" " + str(round(MOS+file[2][9]+Bone_DIP_T,7))+""" 
"""+ str(round(-1,7))+" "+str(round(1,7))+"""
*select_mode_except
*select_sets DP_Bone_nodes
*select_sets DP_Flesh_nodes
*select_sets G0
*select_sets G1
*select_sets G2
*select_sets G3
*select_sets G4
*select_sets G5
*select_mode_and
*store_nodes
Joint_DIP_MP_side_nodes
all_selected
*select_clear
*reset

*reset
*new_rbe2
*rbe2_name MCP_Joint_CMC_side
*rbe2_ret_node
node_id(-6)
*select_clear
*select_sets Joint_MCP_CMC_side_nodes
*select_mode_except
*select_sets Joint_centers
*select_mode_and
*add_rbe2_tied_nodes
all_selected
#
*select_clear
*edit_rbe2 MCP_Joint_CMC_side
*rbe2_tied_dof x
*rbe2_tied_dof y


*reset
*new_rbe2
*rbe2_name MCP_Joint_PP_side
*rbe2_ret_node
node_id(-5)
*select_clear
*select_sets Joint_MCP_PP_side_nodes
*select_mode_except
*select_sets Joint_centers
*select_mode_and
*add_rbe2_tied_nodes
all_selected
#
*select_clear
*edit_rbe2 MCP_Joint_PP_side
*rbe2_tied_dof x
*rbe2_tied_dof y


*reset
*new_rbe2
*rbe2_name PIP_Joint_PP_side
*rbe2_ret_node
node_id(-4)
*select_clear
*select_sets Joint_PIP_PP_side_nodes
*select_mode_except
*select_sets Joint_centers
*select_mode_and
*add_rbe2_tied_nodes
all_selected
#
*select_clear
*edit_rbe2 PIP_Joint_PP_side
*rbe2_tied_dof x
*rbe2_tied_dof y


*reset
*new_rbe2
*rbe2_name PIP_Joint_MP_side
*rbe2_ret_node
node_id(-3)
*select_clear
*select_sets Joint_PIP_MP_side_nodes
*select_mode_except
*select_sets Joint_centers
*select_mode_and
*add_rbe2_tied_nodes
all_selected
#
*select_clear
*edit_rbe2 PIP_Joint_MP_side
*rbe2_tied_dof x
*rbe2_tied_dof y

*reset
*new_rbe2
*rbe2_name DIP_Joint_MP_side
*rbe2_ret_node
node_id(-2)
*select_clear
*select_sets Joint_DIP_MP_side_nodes
*select_mode_except
*select_sets Joint_centers
*select_mode_and
*add_rbe2_tied_nodes
all_selected
#
*select_clear
*edit_rbe2 DIP_Joint_MP_side
*rbe2_tied_dof x
*rbe2_tied_dof y

*reset
*new_rbe2
*rbe2_name DIP_Joint_DP_side
*rbe2_ret_node
node_id(-1)
*select_clear
*select_sets Joint_DIP_DP_side_nodes
*select_mode_except
*select_sets Joint_centers
*select_mode_and
*add_rbe2_tied_nodes
all_selected
#
*select_clear
*edit_rbe2 DIP_Joint_DP_side
*rbe2_tied_dof x
*rbe2_tied_dof y
"""

if rbe_joint_flag == 1:
    setup = setup + """
*new_rbe2
*rbe2_name link1
*rbe2_ret_node
node_id(-6)
*select_clear
*select_sets G1
*add_rbe2_tied_nodes
all_selected
#
*select_clear

*new_rbe2
*rbe2_name link2
*rbe2_ret_node
node_id(-4)
*select_clear
*select_sets G3
*add_rbe2_tied_nodes
all_selected
#
*select_clear

*new_rbe2
*rbe2_name link3
*rbe2_ret_node
node_id(-2)
*select_clear
*select_sets G5
*add_rbe2_tied_nodes
all_selected
#
*select_clear

*edit_rbe2 link1
*rbe2_tied_dof x
*rbe2_tied_dof y


*edit_rbe2 link2
*rbe2_tied_dof x
*rbe2_tied_dof y


*edit_rbe2 link3
*rbe2_tied_dof x
*rbe2_tied_dof y
"""
else:
    setup = setup + """
*new_link *link_class spring *spring_option spring_type:fixed_dof
*link_class spring *spring_beg_dof x
*link_class spring *spring_end_dof x
*link_name Spring_MCP_Tx
*link_class spring *spring_option static_type:stiffness
*spring_param stiffness """+str(round(  joint_spring_stiffness  ,3))+"""
*link_class spring *spring_node 0
node_id(-6)
*link_class spring *spring_node 1
node_id(-5)

*new_link *link_class spring *spring_option spring_type:fixed_dof
*link_class spring *spring_beg_dof y
*link_class spring *spring_end_dof y
*link_name Spring_MCP_Ty
*link_class spring *spring_option static_type:stiffness
*spring_param stiffness """+str(round(  joint_spring_stiffness  ,3))+"""
*link_class spring *spring_node 0
node_id(-6)
*link_class spring *spring_node 1
node_id(-5)

*new_link *link_class spring *spring_option spring_type:fixed_dof
*link_class spring *spring_beg_dof x
*link_class spring *spring_end_dof x
*link_name Spring_PIP_Tx
*link_class spring *spring_option static_type:stiffness
*spring_param stiffness """+str(round(  joint_spring_stiffness  ,3))+"""
*link_class spring *spring_node 0
node_id(-4)
*link_class spring *spring_node 1
node_id(-3)

*new_link *link_class spring *spring_option spring_type:fixed_dof
*link_class spring *spring_beg_dof y
*link_class spring *spring_end_dof y
*link_name Spring_PIP_Ty
*link_class spring *spring_option static_type:stiffness
*spring_param stiffness """+str(round(  joint_spring_stiffness  ,3))+"""
*link_class spring *spring_node 0
node_id(-4)
*link_class spring *spring_node 1
node_id(-3)

*new_link *link_class spring *spring_option spring_type:fixed_dof
*link_class spring *spring_beg_dof x
*link_class spring *spring_end_dof x
*link_name Spring_DIP_Tx
*link_class spring *spring_option static_type:stiffness
*spring_param stiffness """+str(round(  joint_spring_stiffness  ,3))+"""
*link_class spring *spring_node 0
node_id(-2)
*link_class spring *spring_node 1
node_id(-1)

*new_link *link_class spring *spring_option spring_type:fixed_dof
*link_class spring *spring_beg_dof y
*link_class spring *spring_end_dof y
*link_name Spring_DIP_Ty
*link_class spring *spring_option static_type:stiffness
*spring_param stiffness """+str(round(  joint_spring_stiffness  ,3))+"""
*link_class spring *spring_node 0
node_id(-2)
*link_class spring *spring_node 1
node_id(-1)
"""

if spring_tab_flag == 1:
    setup = setup + """
*md_table_read_any """+MCP_spring_table+"""
*edit_table NR_MCP_line_Ends_rev
*set_md_table_type 1
rotation

*md_table_read_any """+PIP_spring_table+"""
*edit_table NR_PIP_line_Ends
*set_md_table_type 1
rotation

*md_table_read_any """+DIP_spring_table+"""
*edit_table NR_DIP_line_Ends
*set_md_table_type 1
rotation
"""

elif spring_tab_flag == 2:
    setup = setup + """
*new_md_table 1 1
*edit_table table3

*table_name NR_MCP_line_Ends_rev
*set_md_table_type 1
rotation
*table_add
V1	F
1.5708 	0.0975*1.5
7.8540000000000e-01	3.2500000000000e-02
0	0
-1.5708000000000e+00	 -4.4390000000000e-02
-3.14	 -0.13317*1.5
*table_fit


*new_md_table 1 1
*edit_table table4

*table_name NR_PIP_line_Ends
*set_md_table_type 1
rotation
*table_add
V1	F
-1.74533*2	-2.4520000000000e-02*4.5
-1.7453300000000e+00	-2.4520000000000e-02
-0	-0
1.7453300000000e+00	2.4520000000000e-02*4.5

*new_md_table 1 1
*edit_table table5

*table_name NR_DIP_line_Ends
*set_md_table_type 1
rotation
*table_add
V1	F
-1.3962600000000e+00*2	-3.0700000000000e-03*4.5
-1.3962600000000e+00	-3.0700000000000e-03
-0	-0
1.3962600000000e+00	3.0700000000000e-03*4.5
"""
else:
    setup = setup + """
*new_md_table 1 1
*edit_table table3

*table_name NR_MCP_line_Ends_rev
*set_md_table_type 1
rotation
*table_add
V1	F
1.5708 	50
7.8540000000000e-01	"""+str(round(mcp_sp*0.7854/1.5708,7))+"""
0	0
-1.5708000000000e+00	 """+str(round(-mcp_sp,7))+"""
-3.14	 -50
*table_fit


*new_md_table 1 1
*edit_table table4

*table_name NR_PIP_line_Ends
*set_md_table_type 1
rotation
*table_add
V1	F
-1.74533*2	-50
-1.7453300000000e+00	"""+str(round(-pip_sp,7))+"""
-0	-0
1.7453300000000e+00	50
*table_fit

*new_md_table 1 1
*edit_table table5

*table_name NR_DIP_line_Ends
*set_md_table_type 1
rotation
*table_add
V1	F
-1.3962600000000e+00*2	-50
-1.3962600000000e+00	"""+str(round(-dip_sp,7))+"""
-0	-0
1.3962600000000e+00	50
*table_fit
"""

# *new_md_table 1 1
# *edit_table table3

# *table_name NR_MCP_line_Ends_rev
# *set_md_table_type 1
# rotation
# *table_add
# V1	F
# 1.5708 	50
# 7.8540000000000e-01	3.2500000000000e-02
# 0	0
# -1.5708000000000e+00	 -4.4390000000000e-02
# -3.14	 -50
# *table_fit


# *new_md_table 1 1
# *edit_table table4

# *table_name NR_PIP_line_Ends
# *set_md_table_type 1
# rotation
# *table_add
# V1	F
# -1.74533*2	-50
# -1.7453300000000e+00	-2.4520000000000e-02
# -0	-0
# 1.7453300000000e+00	50
# *table_fit

# *new_md_table 1 1
# *edit_table table5

# *table_name NR_DIP_line_Ends
# *set_md_table_type 1
# rotation
# *table_add
# V1	F
# -1.3962600000000e+00*2	-50
# -1.3962600000000e+00	-3.0700000000000e-03
# -0	-0
# 1.3962600000000e+00	50
# *table_fit
    
    
setup = setup + """
*element_type 118
Actuator

*element_type 115
Finger

*element_type 115
Paper

*element_type 11
Bones

*new_link *link_class spring *spring_option spring_type:fixed_dof
*link_class spring *spring_beg_dof rz
*link_class spring *spring_end_dof rz
*link_name Spring_MCP
*link_class spring *spring_option static_type:force
*spring_param rot_stiff_moment 1
*spring_param_table rot_stiff_moment NR_MCP_line_Ends_rev
*link_class spring *spring_node 0
node_id(-6)
*link_class spring *spring_node 1
node_id(-5)

*new_link *link_class spring *spring_option spring_type:fixed_dof
*link_class spring *spring_beg_dof rz
*link_class spring *spring_end_dof rz
*link_name Spring_PIP
*link_class spring *spring_option static_type:force
*spring_param rot_stiff_moment 1
*spring_param_table rot_stiff_moment NR_PIP_line_Ends
*link_class spring *spring_node 0
node_id(-4)
*link_class spring *spring_node 1
node_id(-3)

*new_link *link_class spring *spring_option spring_type:fixed_dof
*link_class spring *spring_beg_dof rz
*link_class spring *spring_end_dof rz
*link_name Spring_DIP
*link_class spring *spring_option static_type:force
*spring_param rot_stiff_moment 1
*spring_param_table rot_stiff_moment NR_DIP_line_Ends
*link_class spring *spring_node 0
node_id(-2)
*link_class spring *spring_node 1
node_id(-1)


*add_job_applys Finger_fixed
*add_loadcase_loads Finger_fixed
*job_option contact_method:segment_segment
*edit_job job1

*edit_mater Mooney
*mater_param general:mass_density """+str(density)+"""
*mater_option structural:bulk_modulus:user
*mater_param structural:bulk_modulus """+ str(bulk) + """
*loadcase_option converge:resid_"""+res_disp_and_or+"""_disp
*loadcase_value force """+str(round(con_tol_res,6))+"""
*loadcase_value displacement """+str(round(con_tol_dis,6))+"""
*loadcase_value maxfraction """+ str(round(max_load_case,6) )+"""

*edit_loadcase lcase1
*loadcase_value minfraction """+ str(round(min_load_case,6) )+"""

*loadcase_option residual_nodal_equilibrium:on
*loadcase_option residual_nodal_equilibrium_level:mild
"""
if rot_mom_yes_flag == 1:
    setup = setup + """
*loadcase_option converge_moment:on
*loadcase_option converge_rotat:on
*loadcase_value rotation """+str(round(con_tol_rot,6))+"""
*loadcase_value moment """+str(round(con_tol_mom,6))+"""

"""
    
setup = setup +"""
*edit_loadcase lcase1
*loadcase_value maxrec 60 
*add_loadcase_loads Pressure_ch1top
*add_loadcase_loads Pressure_ch2top
*add_loadcase_loads Pressure_ch3top
*add_loadcase_loads Pressure_ch1bot
*add_loadcase_loads Pressure_ch2bot
*add_loadcase_loads Pressure_ch3bot
*add_loadcase_loads Pressure_ch4top
*add_loadcase_loads Pressure_ch4bot
*add_loadcase_loads Sliding_actuator_side
*add_loadcase_loads Fixed_side

*edit_job job1
*add_job_applys Pressure_ch1top
*add_job_applys Pressure_ch2top
*add_job_applys Pressure_ch3top
*add_job_applys Pressure_ch1bot
*add_job_applys Pressure_ch2bot
*add_job_applys Pressure_ch3bot
*add_job_applys Pressure_ch4top
*add_job_applys Pressure_ch4bot
*add_job_applys Fixed_side
*add_job_applys Sliding_actuator_side

*update_job
*job_option assem_recov_multi_threading:on
*job_option nsolver_procs_serial:on
*job_option solver:"""+solver+"""
*job_option solver_nonsym:on
*job_param assem_recov_nthreads """+str(core_thread)+ """
*job_option pardiso_multi_threading:on
*job_param nthreads """+str(round(core_thread,6))+ """


*job_option seg_seg_contact_presets:version_2
*job_option friction:off
*job_param contact_tol_scale_factor """+str(contact_tol_scale_factor)+"""
*job_param penalty_scale_factor_norm """+str(penalty_scale_factor)+"""
*job_submit_reset|
"""

# This is additional code to setup the gravity and additional springs
setup = setup + """

*new_link *link_class spring *spring_option spring_type:true_dir
*link_name MP_PIP_fix
*spring_param stiffness 1e7

*new_link *link_class spring *spring_option spring_type:true_dir
*link_name MP_DIP_fix
*spring_param stiffness 1e7

*new_apply *apply_type gravity_load
*apply_name Gravity_load
*apply_dof y *apply_dof_value y
*apply_dof_value y -9.81
*add_apply_elements
Actuator
#
"""
if use_gravity_flag == 1:
    setup = setup + """
*edit_loadcase lcase1

*add_loadcase_loads Gravity_load
*edit_job job1

*add_job_applys Gravity_load
"""

setup = setup + """
*auto_arrow_length 0.01
*arrows_solid

*mater_option structural:bulk_modulus:automatic
"""
if cut_contact_ends_flag == 1:
    setup = setup + """
*reset
*select_method_user_box
*select_filter_none
*select_mode_and
*select_elements 
"""+ str(round(-1,7))+" " + str(round(-file[1][3] + Fing_MCP_T,7))+""" 
"""+ str(round(-1,7))+" " + str(round(1,7))+""" 
"""+ str(round(-1,7))+" "+str(round(1,7))+"""
*edit_contact_body Con_PP
*remove_contact_body_elem
all_selected
#
*select_clear
*reset

*reset
*select_method_user_box
*select_filter_none
*select_mode_and
*select_elements 
"""+ str(round(-1,7))+" " + str(round(-file[1][6] + Fing_PIP_T,7))+""" 
"""+ str(round(-1,7))+" " + str(round(1,7))+""" 
"""+ str(round(-1,7))+" "+str(round(1,7))+"""
*edit_contact_body Con_MP
*remove_contact_body_elem
all_selected
#
*select_clear
*reset

*reset
*select_method_user_box
*select_filter_none
*select_mode_and
*select_elements 
"""+ str(round(-1,7))+" " + str(round(-file[1][9] + Fing_DIP_T,7))+""" 
"""+ str(round(-1,7))+" " + str(round(1,7))+""" 
"""+ str(round(-1,7))+" "+str(round(1,7))+"""
*edit_contact_body Con_DP
*remove_contact_body_elem
all_selected
#
*select_clear
*reset    
"""

# %% [markdown]
# # need to stop the actuator

# %%
# This code is to add block to stop the actuator
stop = """
*reset
*remove_points
all_existing
*remove_curves
all_existing
*set_curve_type line
*prog_option geometry_and_mesh:mesh_cv_div_uniform:target_length
*prog_param geometry_and_mesh:mesh_cv_div_target_length """+str(round(meshing_size,10))+"""
*add_points
""" + str(round(-file[1][4]-Fing_MCP_T,10))+" "+str(round(MOS+file[2][4],10))+" "+str(round(0,10))+"""
""" + str(round(-file[1][4],10))+" "+str(round(MOS+file[2][4],10))+" "+str(round(0,10))+"""
""" + str(round(-file[1][4]-Fing_MCP_T,10))+" "+str(round(MOS+file[2][4]-R_d+xFlex_height+height,10))+" "+str(round(0,10))+"""
""" + str(round(-file[1][4],10))+" "+str(round(MOS+file[2][4]-R_d+xFlex_height+height,10))+" "+str(round(0,10))+"""

*add_curves
1 2 3 4 1 3 2 4

*apply_curve_divisions
1 2 3 4
#

*af_planar_quadmesh
1 4 2 3
#

*remove_curves
all_existing
*remove_points
all_existing

*remove_points
all_existing
*remove_curves
all_existing
*select_clear
*select_method_user_box
*select_filter_none
*select_mode_and
*select_elements
"""+ str(round(-file[1][4]-Fing_MCP_T-0.000001,7))+" " + str(round(-file[1][4]+0.000001,7))+""" 
"""+ str(round(MOS+file[2][4]-0.000001,7))+" " + str(round(MOS+file[2][4]-R_d+xFlex_height+height+0.000001,7))+""" 
"""+ str(round(-1,7))+" "+str(round(1,7))+"""
*select_mode_except
*select_sets Actuator
*select_sets Finger
*store_elements
Stop
all_selected

*select_clear
*select_mode_and
*select_nodes 
"""+ str(round(-file[1][4]-0.000001,7))+" " + str(round(-file[1][4]+0.000001,7))+""" 
"""+ str(round(MOS+file[2][4]-0.000001,7))+" " + str(round(MOS+file[2][4]-R_d+xFlex_height+height+0.000001,7))+""" 
"""+ str(round(-1,7))+" "+str(round(1,7))+"""
*select_mode_except
*select_sets Actuator_nodes
*select_sets Finger_nodes
*store_nodes
Stop_nodes
all_selected
*select_clear
*reset

*select_method_user_box
*select_filter_none
*select_mode_and
*select_elements
"""+ str(round(L0-ends_ext-0.000001,7))+" " + str(round(L0+block_more+0.000001,7))+""" 
"""+ str(round(MOS+file[2][4]-0.000001,7))+" " + str(round(MOS+file[2][4]-R_d+xFlex_height+height+0.000001,7))+""" 
"""+ str(round(-1,7))+" "+str(round(1,7))+"""
*select_mode_except
*select_sets Finger
*store_elements
Actuator_End
all_selected
*select_clear
*reset

*select_sets Stop
*edit_mater Mat_Bone
*add_mater_elements
all_selected

*new_cbody mesh *contact_option state:solid *contact_option skip_structural:off
*contact_body_name Stop_BD
*add_contact_body_elements
all_selected

*select_clear
*select_sets Actuator_End
*new_cbody mesh *contact_option state:solid *contact_option skip_structural:off
*contact_body_name Stop_AC
*add_contact_body_elements
all_selected
*select_clear

*edit_contact_table ctable1
*ctable_entry Stop_BD Stop_AC
*contact_table_option Stop_BD Stop_AC contact:on
*prog_string ctable:old_interact interact_MD_to_MD_Touch *ctable_entry_interact Stop_BD Stop_AC

*reset
*select_clear
*select_sets Stop_nodes
*edit_apply Fixed_side
*add_apply_nodes
all_selected
*select_clear

*select_clear
*select_sets Stop
*element_type 11
all_selected

*edit_adapt adapt1
*add_adapt_elements
all_selected
*select_clear
*invisible_set Stop *redraw
"""

if use_gravity_flag == 1:
    stop = stop + """
*edit_table linear_ramp
*table_add
2
1
*table_edit
2
1
0

*table_fit
*edit_table linear_ramp *copy_table
*edit_table linear_ramp(1)
*table_name
table_gravity
*edit_table table_gravity
*table_edit
2
1
1

*edit_apply Gravity_load
*apply_dof_table y table_gravity

*new_loadcase *loadcase_type struc:static
*edit_loadcase lcase2
*loadcase_value nsteps 10
*loadcase_ctable
ctable1
*loadcase_option converge:resid_"""+res_disp_and_or+"""_disp
*loadcase_option converge_moment:on
*loadcase_option residual_nodal_equilibrium:on
*loadcase_option residual_nodal_equilibrium_level:mild
*loadcase_option converge_rotat:on
*loadcase_value force """+str(round(con_tol_res,6))+"""
*loadcase_value moment """+str(round(con_tol_res,6))+"""
*loadcase_value displacement """+str(round(con_tol_dis,6))+"""
*loadcase_value rotation """+ str(round(con_tol_dis,6) )+"""
*add_job_loadcases lcase2
*job_loadcase_move_up lcase2
*edit_apply Gravity_load
*add_apply_elements
Finger
"""

if auto_contact == 1:
    stop = stop + """
*edit_contact_table ctable1
*ctable_entry Con_Actuator Con_CMC
*contact_table_option Con_Actuator Con_CMC detection:automatic
*ctable_entry Con_Actuator Con_PP
*contact_table_option Con_Actuator Con_PP detection:automatic
*ctable_entry Con_Actuator Con_MP
*contact_table_option Con_Actuator Con_MP detection:automatic
*ctable_entry Con_Actuator Con_DP
*contact_table_option Con_Actuator Con_DP detection:automatic
*ctable_entry Stop_BD Stop_AC
*contact_table_option Stop_BD Stop_AC detection:automatic
"""
if extra_ac_start_straight == 1:
    stop = stop + """
*reset
*select_clear
*select_method_user_box
*select_nodes
"""+ str(round(L0-ends_ext-paper_width/2,6))+" " + str(round(L0-paper_width/2+block_more,6))+"""
"""+ str(round(R_d-xFlex_height-paper_width/2,6))+" " + str(round(height+paper_width/2,6))+"""
"""+ str(round(-1,6))+" "+str(round(1,6))+"""
*select_mode_except
*select_method_user_single
*select_elements
*select_sets Finger_nodes
*select_method_user_box
*select_nodes
"""+ str(round(L0+paper_width/2,6))+" " + str(round(L0-paper_width/2+block_more-ends_ext,6))+"""
"""+ str(round(R_d-xFlex_height-paper_width/2,6))+" " + str(round(height+paper_width/2,6))+"""
"""+ str(round(-1,6))+" "+str(round(1,6))+"""
*store_nodes
Extra_AC_fix_nodes
all_selected
*select_clear
*reset
*edit_apply Sliding_actuator_side
*add_apply_nodes
Extra_AC_fix_nodes
"""
if elastic_wrist == 1:
    stop = stop + """
*new_link *link_class spring *spring_option spring_type:to_ground
*spring_param stiffness 120
*spring_node 0
106
"""

# %%
# Write the code to a proc file
part_end = """
*set_undo on
*set_update on
*model_navigator_update on
*fill_view
*visible_set Actuator *redraw
*visible_set Finger *redraw
*edit_apply Fixed_side
*identify_contact *redraw
*invisible_set PP *redraw
*invisible_set DP *redraw
*invisible_set Flesh *redraw
*edit_spring MP_PIP_fix
@popup(selection_control_pm,0)
*edit_spring MP_PIP_fix
@popup(link_spring_pm,0)
*edit_apply Gravity_load
*remove_apply_elements
Finger

*edit_job job1
*job_option contact_augmentation:automatic

*edit_spring link6
*edit_spring MP_DIP_fix
*edit_spring MP_DIP_fix *remove_current_link
*edit_spring MP_PIP_fix *remove_current_link
*edit_spring link6

*spring_param stiffness 312
@popup(n_to_n_springs_dashpots_pm,0)
*spring_multi_option spring_type:true_dir
*prog_param multi_spring:stiff 240799
*edit_job job1

*job_option contact_augmentation:none
*job_param penalty_scale_factor_norm 1

*edit_loadcase lcase1
*loadcase_option converge_rotat:off
*loadcase_option converge_moment:off
*loadcase_option residual_nodal_equilibrium:off
"""

# now create the proc file
with open(root_dir+"\\"+"testing.proc", 'w') as f:
    f.write(final+Ch_def+Actuator_set+Fing_points+Create_finger+Def_Fing+finger_fixed+setup+stop+part_end)
    f.close()

print('Directory which contains the proc file:', root_dir)
# Out:
# C:\Users\18507522\FinalSBSpring\CODE\testing.txt

# %% [markdown]
# Note: just run -> mentat -pr testing.proc -bg
